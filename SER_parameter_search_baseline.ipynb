# %%
import os
import glob

import math
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from tqdm import tqdm
from torch.autograd import Variable
from torch.utils.data import TensorDataset, DataLoader
from preprocessing import preprocessing, convert_spectrograms, convert_tensor
from model_ae import Encoder
from utils.optimization import WarmupLinearSchedule

# %%
class SELayer(nn.Module):
    def __init__(self, channel, reduction=4):
        super(SELayer, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Sequential(
            nn.Linear(channel, channel // reduction, bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(channel // reduction, channel, bias=False),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        b, c, _, _ = x.size()
        y = self.avg_pool(x).view(b, c)
        y = self.fc(y).view(b, c, 1, 1)
        return x * y.expand_as(x)

# %%
class MultiHeadedAttention(nn.Module):
    def __init__(self, num_attn_heads, attn_hidden_size, dropout_prob, with_focus_attn, with_se):
        super(MultiHeadedAttention, self).__init__()
        self.num_attn_heads = num_attn_heads
        self.hidden_size = attn_hidden_size
        self.dropout_prob = dropout_prob
        self.with_focus_attn = with_focus_attn
        self.with_se = with_se
        
        self.attn_head_size = int(self.hidden_size / self.num_attn_heads)
        self.all_head_size = self.num_attn_heads * self.attn_head_size

        self.query = nn.Linear(self.hidden_size, self.all_head_size)
        self.key = nn.Linear(self.hidden_size, self.all_head_size)
        self.value = nn.Linear(self.hidden_size, self.all_head_size)

        self.o_proj = nn.Linear(self.hidden_size, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_prob)

        self.softmax = nn.Softmax(dim=-1)
        
        if(with_focus_attn == True):
            self.tanh = nn.Tanh()
            self.sigmoid = nn.Sigmoid()
            
            self.linear_focus_query = nn.Linear(num_attn_heads * self.attn_head_size, 
                                                num_attn_heads * self.attn_head_size)
            self.linear_focus_global = nn.Linear(num_attn_heads * self.attn_head_size, 
                                                 num_attn_heads * self.attn_head_size)
            
            up = torch.randn(num_attn_heads, 1, self.attn_head_size)
            self.up = Variable(up, requires_grad=True).cuda()
            torch.nn.init.xavier_uniform_(self.up)
            
            uz = torch.randn(num_attn_heads, 1, self.attn_head_size)
            self.uz = Variable(uz, requires_grad=True).cuda()
            torch.nn.init.xavier_uniform_(self.uz)
            
        if(with_se == True):
            self.se = SELayer(8)

    def transpose_for_scores(self, x):
        new_x_shape = x.size()[:-1] + (self.num_attn_heads, self.attn_head_size)
        x = x.view(*new_x_shape)
        return x.permute(0, 2, 1, 3)

    def forward(self, hidden_states):
        key_len = hidden_states.size(1)
        mixed_query_layer = self.query(hidden_states)
        mixed_key_layer = self.key(hidden_states)
        mixed_value_layer = self.value(hidden_states)
        
        if(self.with_focus_attn == True):
            glo = torch.mean(mixed_query_layer, dim=1, keepdim=True)
            
            c = self.tanh(self.linear_focus_query(mixed_query_layer) + self.linear_focus_global(glo))
            c = self.transpose_for_scores(c)
            
            p = c * self.up
            p = p.sum(3).squeeze()
            z = c * self.uz
            z = z.sum(3).squeeze()
            
            P = self.sigmoid(p) * key_len
            Z = self.sigmoid(z) * key_len
            
            j = torch.arange(start=0, end=key_len, dtype=P.dtype).unsqueeze(0).unsqueeze(0).unsqueeze(0).to('cuda')
            P = P.unsqueeze(-1)
            Z = Z.unsqueeze(-1)
            
            G = -(j - P)**2 * 2 / (Z**2)

        query_layer = self.transpose_for_scores(mixed_query_layer)
        key_layer = self.transpose_for_scores(mixed_key_layer)
        value_layer = self.transpose_for_scores(mixed_value_layer)

        attention_scores = torch.matmul(query_layer, key_layer.transpose(-1, -2))
        attention_scores = attention_scores / math.sqrt(self.attn_head_size)
        
        if(self.with_focus_attn == True):
            attention_scores = attention_scores + G
            
        attention_probs = self.softmax(attention_scores)
        
        if(self.with_se == True):
            attention_probs = self.se(attention_probs)
            
        attention_probs = self.dropout(attention_probs)

        context_layer = torch.matmul(attention_probs, value_layer)
        context_layer = context_layer.permute(0, 2, 1, 3).contiguous()
        new_context_layer_shape = context_layer.size()[:-2] + (self.all_head_size,)
        context_layer = context_layer.view(*new_context_layer_shape)
        attention_output = self.o_proj(context_layer)

        return attention_output

# %% [markdown]
# class CLDNN(nn.Module):
#     def __init__(self, conv_dim, checkpoint=None, hidden_size=60, num_layers=2,
#                  bidirectional=True, with_focus_attn=False):
#         super(CLDNN, self).__init__()
#         self.conv_dim = conv_dim
#         if(conv_dim == '2d'):
#             self.conv1 = nn.Sequential(
#                 nn.Conv2d(1, 64, (3, 3)), # (1, 128, 50) -> (64, 126, 48)
#                 nn.BatchNorm2d(64),
#                 nn.ReLU(),
#                 nn.MaxPool2d(3, 3)  # (64, 126, 48) -> (64, 42, 16)
#             )
#             self.conv2 = nn.Sequential(
#                 nn.Conv2d(64, 64, (3, 3)), # (64, 42, 16) -> (64, 40, 14)
#                 nn.BatchNorm2d(64),
#                 nn.ReLU(),
#                 nn.MaxPool2d(3, 3)  # (64, 40, 14) -> (64, 13, 4)
#             )
#             self.lstm = nn.LSTM(832, hidden_size=hidden_size, num_layers=num_layers, bidirectional=bidirectional)
#             self.tanh = nn.Tanh()
#             self.dropout = nn.Dropout(0.5)
#             self.attn = MultiHeadedAttention(num_attn_heads=8, attn_hidden_size=120, dropout_prob=0.1,
#                                              with_focus_attn=with_focus_attn)
#             self.fc = nn.Sequential(
#                 nn.Linear(4*2*hidden_size if bidirectional else hidden_size, 4)
#             )
#         else:
#             raise ValueError("Convolution dimension not found: %s" % (conv_dim))
#
#     def forward(self, x):
#         if(self.conv_dim == '2d'):
#             out = self.conv1(x)  # (batch, 1, 128, 50) -> (batch, 64, 42, 16)
#             out = self.conv2(out)  # (batch, 64, 42, 16) -> (batch, 64, 13, 4)
#             new_out_shape = out.size()[:1] + (out.size()[1] * out.size()[2], out.size()[3])
#             out = out.reshape(*new_out_shape)  # (batch, 64, 13, 4) -> (batch, 832, 4)
#             out = out.permute(2, 0, 1)  # (batch, 832, 4) -> (4, batch, 832)
#             self.lstm.flatten_parameters()
#             out, _ = self.lstm(out)  # (4, batch, 832) -> (4, batch, 2*60)
#             out = self.tanh(out)
#             out = self.dropout(out)
#             out = out.permute(1, 0, 2)  # (4, batch, 2*60) -> (batch, 4, 2*60)
#             out = self.attn(out)  # (batch, 4, 2*60) -> (batch, 4, 2*60)
#             new_out_shape = out.size()[:1] + (out.size()[1] * out.size()[2],)
#             out = out.view(*new_out_shape)  # (batch, 4, 2*60) -> (batch, 4*2*60)
#             out = self.fc(out)  # (batch, 4*2*60) -> (batch, 4)
#         return out

# %%
# CNN -> LSTM -> self-attention -> DNN
class CLDNN(nn.Module):
    def __init__(self, conv_dim, checkpoint=None, hidden_size=64, num_layers=2,
                 bidirectional=True, with_focus_attn=False, with_se=False):
        super(CLDNN, self).__init__()
        self.conv_dim = conv_dim
        if(conv_dim == '1d'):
            self.conv1 = nn.Sequential(
                nn.Conv1d(1, 64, (3, 1)), # (1, 40, 100) -> (64, 38, 100)
                nn.BatchNorm2d(64),
                nn.ReLU(),
                nn.MaxPool2d((2, 1), (2, 1))  # (64, 38, 100) -> (64, 19, 100)
            )
            self.conv2 = nn.Sequential(
                nn.Conv1d(64, 64, (3, 1)), # (64, 19, 100) -> (64, 17, 100)
                nn.BatchNorm2d(64),
                nn.ReLU(),
                nn.MaxPool2d((2, 1), (2, 1))  # (64, 17, 100) -> (64, 8, 100)
            )
            self.lstm = nn.LSTM(512, hidden_size=hidden_size, num_layers=num_layers, bidirectional=bidirectional)
            self.tanh = nn.Tanh()
            self.dropout = nn.Dropout(0.5)
            self.attn = MultiHeadedAttention(num_attn_heads=8, attn_hidden_size=128, dropout_prob=0.1,
                                             with_focus_attn=with_focus_attn, with_se=with_se)
            self.fc1 = nn.Linear(100*2*hidden_size if bidirectional else hidden_size, 128)
            self.relu = nn.ReLU()
            self.fc2 = nn.Linear(128, 4)
            '''self.fc = nn.Sequential(
                nn.Linear(50*2*hidden_size if bidirectional else hidden_size, 128),
                nn.ReLU(),
                nn.Linear(128, 4)
            )'''
        else:
            raise ValueError("Convolution dimension not found: %s" % (conv_dim))
            
    def forward(self, x):
        if(self.conv_dim == '1d'):
            out = self.conv1(x)  # (batch, 1, 40, 100) -> (batch, 64, 19, 100)
            out = self.conv2(out)  # (batch, 64, 19, 100) -> (batch, 64, 8, 100)
            out = out.contiguous()
            new_out_shape = out.size()[:1] + (out.size()[1] * out.size()[2], out.size()[3])
            out = out.view(*new_out_shape)  # (batch, 64, 8, 100) -> (batch, 512, 100)
            out = out.permute(2, 0, 1)  # (batch, 512, 100) -> (100, batch, 512)
            self.lstm.flatten_parameters()
            out, _ = self.lstm(out)  # (100, batch, 512) -> (100, batch, 2*64)
            out = self.tanh(out)
            out = self.dropout(out)
            out = out.permute(1, 0, 2)  # (100, batch, 2*64) -> (batch, 100, 2*64)
            out = self.attn(out)  # (batch, 100, 2*64) -> (batch, 100, 2*64)
            new_out_shape = out.size()[:1] + (out.size()[1] * out.size()[2],)
            out = out.view(*new_out_shape)  # (batch, 100, 2*64) -> (batch, 100*2*64)
            out_fc1 = self.fc1(out)  # (batch, 100*2*64) -> (batch, 128)
            out_relu = self.relu(out_fc1)
            out_fc2 = self.fc2(out_relu)  # (batch, 128) -> (batch, 4)
        return out_fc2

# %% [markdown]
# # CNN -> self-attention -> LSTM -> DNN
# class CLDNN(nn.Module):
#     def __init__(self, conv_dim, checkpoint=None, hidden_size=64, num_layers=2,
#                  bidirectional=True, with_focus_attn=False):
#         super(CLDNN, self).__init__()
#         self.conv_dim = conv_dim
#         if(conv_dim == '1d'):
#             self.conv1 = nn.Sequential(
#                 nn.Conv1d(1, 64, (3, 1)), # (1, 40, 50) -> (64, 38, 50)
#                 nn.BatchNorm2d(64),
#                 nn.ReLU(),
#                 nn.MaxPool2d((2, 1), (2, 1))  # (64, 38, 50) -> (64, 19, 50)
#             )
#             self.conv2 = nn.Sequential(
#                 nn.Conv1d(64, 64, (3, 1)), # (64, 19, 50) -> (64, 17, 50)
#                 nn.BatchNorm2d(64),
#                 nn.ReLU(),
#                 nn.MaxPool2d((2, 1), (2, 1))  # (64, 17, 50) -> (64, 8, 50)
#             )
#             self.attn = MultiHeadedAttention(num_attn_heads=8, attn_hidden_size=512, dropout_prob=0.1,
#                                              with_focus_attn=with_focus_attn)
#             self.lstm = nn.LSTM(512, hidden_size=hidden_size, num_layers=num_layers, bidirectional=bidirectional)
#             self.tanh = nn.Tanh()
#             self.dropout = nn.Dropout(0.5)
#             self.fc = nn.Sequential(
#                 nn.Linear(50*2*hidden_size if bidirectional else hidden_size, 128),
#                 nn.ReLU(),
#                 nn.Linear(128, 4)
#             )
#         else:
#             raise ValueError("Convolution dimension not found: %s" % (conv_dim))
#
#     def forward(self, x):
#         if(self.conv_dim == '1d'):
#             out = self.conv1(x)  # (batch, 1, 40, 50) -> (batch, 64, 19, 50)
#             out = self.conv2(out)  # (batch, 64, 19, 50) -> (batch, 64, 8, 50)
#             new_out_shape = out.size()[:1] + (out.size()[1] * out.size()[2], out.size()[3])
#             out = out.reshape(*new_out_shape)  # (batch, 64, 8, 50) -> (batch, 512, 50)
#             out = out.permute(0, 2, 1)  # (batch, 512, 50) -> (batch, 50, 512)
#             h = out
#             out = self.attn(out)  # (batch, 50, 512) -> (batch, 50, 512)
#             out = h + out
#             out = out.permute(1, 0, 2)  # (batch, 50, 512) -> (50, batch, 512)
#             self.lstm.flatten_parameters()
#             out, _ = self.lstm(out)  # (50, batch, 512) -> (50, batch, 2*64)
#             #out = out[-1]  # (50, batch, 2*64) -> (batch, num_directions*hidden_size)
#             out = self.tanh(out)
#             out = self.dropout(out)
#             out = out.permute(1, 0, 2)  # (50, batch, 2*64) -> (batch, 50, 2*64)
#             new_out_shape = out.size()[:1] + (out.size()[1] * out.size()[2],)
#             out = out.view(*new_out_shape)  # (batch, 50, 2*64) -> (batch, 50*2*64)
#             out = self.fc(out)  # (batch, 50*2*64) -> (batch, 4)
#         return out

# %%
class CLDNN_G(nn.Module):
    def __init__(self, conv_dim, checkpoint=None, hidden_size=64, num_layers=2,
                 bidirectional=True, with_focus_attn=False):
        super(CLDNN_G, self).__init__()
        self.conv_dim = conv_dim
        if(conv_dim == '1d'):
            self.encoder = Encoder(conv_dim)
            if checkpoint:
                self.encoder.load_state_dict(torch.load(checkpoint))
            self.attn = MultiHeadedAttention(num_attn_heads=4, attn_hidden_size=8, dropout_prob=0.1,
                                             with_focus_attn=with_focus_attn)
            self.lstm = nn.LSTM(8, hidden_size=hidden_size, num_layers=num_layers, bidirectional=bidirectional)
            self.fc = nn.Sequential(
                nn.Linear(hidden_size*2 if bidirectional else hidden_size, 1),
                nn.Sigmoid()
            )
        elif(conv_dim == '2d'):
            self.encoder = Encoder(conv_dim)
            if checkpoint:
                self.encoder.load_state_dict(torch.load(checkpoint))
            self.attn = MultiHeadedAttention(num_attn_heads=4, attn_hidden_size=176, dropout_prob=0.1, 
                                             with_focus_attn=with_focus_attn)
            self.gap = nn.AdaptiveAvgPool2d((1, 11))
            self.lstm = nn.LSTM(11, hidden_size=hidden_size, num_layers=num_layers, bidirectional=bidirectional)
            self.fc = nn.Sequential(
                nn.Linear(hidden_size*2 if bidirectional else hidden_size, 1),
                nn.Sigmoid()
            )
        else:
            raise ValueError("Convolution dimension not found: %s" % (conv_dim))
            
    def forward(self, x):
        if(self.conv_dim == '1d'):
            out = self.encoder(x)  # (batch, 1, 40, 100) -> (batch, 8, 1, 100)
            out = torch.squeeze(out, 2)  # (batch, 8, 1, 100) -> (batch, 8, 100)
            out = out.permute(0, 2, 1)  # (batch, 8, 100) -> (batch, 100, 8)
            h = out
            out = self.attn(out)  # (batch, 100, 8) -> (batch, 100, 8)
            out = h + out
            out = out.permute(1, 0, 2)  # (batch, 100, 8) -> (100, batch, 8)
            self.lstm.flatten_parameters()
            out, _ = self.lstm(out)  # (100, batch, 8) -> (100, batch, num_directions*hidden_size)
            out = out[-1]  # (100, batch, num_directions*hidden_size) -> (batch, num_directions*hidden_size)
            out = self.fc(out)  # (batch, num_directions*hidden_size) -> (batch, 1)
        elif(self.conv_dim == '2d'):
            out = self.encoder(x)  # (batch, 1, 128, 100) -> (batch, 16, 11, 8)
            out = out.permute(0, 3, 1, 2)  # (batch, 16, 11, 8) -> (batch, 8, 16, 11)
            h = out
            new_out_shape = out.size()[:2] + (out.size()[2] * out.size()[3],)
            out = out.view(*new_out_shape)  # (batch, 8, 16, 11) -> (batch, 8, 176)
            out = self.attn(out)  # (batch, 8, 176) -> (batch, 8, 176)
            out = out.view(h.size())  # (batch, 8, 176) -> (batch, 8, 16, 11)
            out = h + out
            out = self.gap(out)  # (batch, 8, 16, 11) -> (batch, 8, 1, 11)
            out = torch.squeeze(out, 2)  # (batch, 8, 1, 11) -> (batch, 8, 11)
            out = out.permute(1, 0, 2)  # (batch, 8, 11) -> (8, batch, 11)
            self.lstm.flatten_parameters()
            out, _ = self.lstm(out)  # (8, batch, 11) -> (8, batch, num_directions*hidden_size)
            out = out[-1]  # (8, batch, num_directions*hidden_size) -> (batch, num_directions*hidden_size)
            out = self.fc(out)  # (batch, num_directions*hidden_size) -> (batch, 1)
        return out

# %%
def train(train_dataloader, eval_dataloader, epochs):
    print('Start training')
    max_acc = 0
    acc_list = []
    softmax = nn.Softmax(dim=1)
    for epoch in range(epochs):
        model.train()
        train_loss = 0
        nb_train_steps = 0
        correct = 0
        num_samples = 0

        if(multi_task == 'true'):
            for X_batch, y_batch, y_g_batch in train_dataloader:
                X_batch = X_batch.to(device)
                y_batch = y_batch.to(device)
                y_g_batch = y_g_batch.to(device)

                optimizer.zero_grad()

                outputs = model(X_batch)
                outputs_g = model_g(X_batch)

                loss_1 = loss_func(outputs, y_batch)
                loss_2 = loss_func_g(outputs_g, y_g_batch)
                loss = loss_1 + 0.8 * loss_2
                loss.backward(retain_graph=True)

                optimizer.step()
                opt_scheduler.step()

                train_loss += loss.mean().item()
                nb_train_steps += 1

                outputs = softmax(outputs)
                outputs = torch.argmax(outputs, dim=1)
                correct += (outputs == y_batch).float().sum()
                num_samples += len(X_batch)

            train_loss = train_loss / nb_train_steps
            train_accuracy = correct / num_samples

            model.eval()
            eval_loss = 0
            nb_eval_steps = 0
            correct = 0
            num_samples = 0

            for X_batch, y_batch, y_g_batch in eval_dataloader:
                X_batch = X_batch.to(device)
                y_batch = y_batch.to(device)
                y_g_batch = y_g_batch.to(device)
                with torch.no_grad():
                    outputs = model(X_batch)
                    outputs_g = model_g(X_batch)

                tmp_eval_loss_1 = loss_func(outputs, y_batch)
                tmp_eval_loss_2 = loss_func_g(outputs_g, y_g_batch)
                tmp_eval_loss = tmp_eval_loss_1 + 0.8 * tmp_eval_loss_2
                eval_loss += tmp_eval_loss.mean().item()
                nb_eval_steps += 1

                outputs = softmax(outputs)
                outputs = torch.argmax(outputs, dim=1)
                correct += (outputs == y_batch).float().sum()
                num_samples += len(X_batch)

            eval_loss = eval_loss / nb_eval_steps
            eval_accuracy = correct / num_samples
        else:
            for X_batch, y_batch in train_dataloader:
                X_batch = X_batch.to(device)
                y_batch = y_batch.to(device)

                optimizer.zero_grad()

                outputs = model(X_batch)

                loss = loss_func(outputs, y_batch)
                loss.backward()

                optimizer.step()
                if(use_warmup == 'true'):
                    opt_scheduler.step()

                train_loss += loss.mean().item()
                nb_train_steps += 1

                outputs = softmax(outputs)
                outputs = torch.argmax(outputs, dim=1)
                correct += (outputs == y_batch).float().sum()
                num_samples += len(X_batch)

            train_loss = train_loss / nb_train_steps
            train_accuracy = correct / num_samples

            model.eval()
            eval_loss = 0
            nb_eval_steps = 0
            correct = 0
            num_samples = 0

            for X_batch, y_batch in eval_dataloader:
                X_batch = X_batch.to(device)
                y_batch = y_batch.to(device)
                with torch.no_grad():
                    outputs = model(X_batch)

                tmp_eval_loss = loss_func(outputs, y_batch)
                eval_loss += tmp_eval_loss.mean().item()
                nb_eval_steps += 1

                outputs = softmax(outputs)
                outputs = torch.argmax(outputs, dim=1)
                correct += (outputs == y_batch).float().sum()
                num_samples += len(X_batch)

            eval_loss = eval_loss / nb_eval_steps
            eval_accuracy = correct / num_samples

        for param_group in optimizer.param_groups:
            lr = param_group['lr']
        print('epoch: {:3d},    lr={:6f},    loss={:5f},    train_acc={:5f},    eval_loss={:5f},    eval_acc={:5f}'
              .format(epoch+1, lr, train_loss, train_accuracy, eval_loss, eval_accuracy))

        if((epoch+1) % save_checkpoint_steps == 0):
            '''
            correct = 0
            n = 0
            for i in range(len(eval_samples)):
                try:
                    X_new = preprocessing(eval_samples[i], method='mfcc', sr=16000, n_mfcc=n_mfcc)
                    X_new = convert_tensor(X_new).to(device)
                    y_new = model(X_new)
                    y_new = torch.argmax(torch.mean(nn.Softmax(dim=-1)(y_new), dim=0))
                    #y_new = torch.argmax(nn.Softmax(dim=-1)(torch.mean(y_new, dim=0)))
                    #y_new = sorted(dict(collections.Counter(torch.argmax(nn.Softmax(dim=-1)(y_new), dim=1).cpu().numpy()))
                    #               .items(), key=(lambda x: x[1]), reverse=True)[0][0]
                    y_new = 1 if (y_new.item() == np.array(eval_label)[i]) else 0
                    correct += y_new
                    n += 1
                except:
                    pass
            acc = correct / n
            acc_list.append(acc)
            print('Test accuray:', round(acc, 5))
            '''
            
            model_checkpoint = "CLDNN_cv%d_step%d_epoch%d.pt" % (cv_iter, en+1, epoch+1)
            output_model_file = os.path.join(output_dir, model_checkpoint)
            torch.save(model.state_dict(), output_model_file)
            print("Saving checkpoint %s" % output_model_file)
            #if(acc > max_acc):
            #    max_acc =acc
            #    torch.save(model.state_dict(), output_model_file)
            #    print("Saving checkpoint %s" % output_model_file)
    #return max(acc_list)

# %%
focus_attn_list = [True]

# %%
df = pd.read_csv('IEMOCAP_sub_label.csv')
di = {'neu': 0, 'hap': 1, 'ang': 2, 'sad': 3}
df = df.replace({'sample_label': di})

# %%
from sklearn.model_selection import StratifiedKFold, train_test_split

skf = StratifiedKFold(n_splits=10)

# %%
for with_focus_attn in focus_attn_list:
    cv_eval = []
    cv_iter = 0
    #with_focus_attn = True if(with_focus_attn == 'true') else False
    for train_index, test_index in skf.split(df['sample_name'], df['sample_label']):
        '''
    for ses_num in range(1, 6):
        eval_ses = 'Ses0' + str(ses_num)
        train_index = []
        eval_index = []
        for i, sample_name in enumerate(df['sample_name']):
            if eval_ses in sample_name:
                eval_index.append(i)
            else:
                train_index.append(i)
        '''
        cv_iter += 1
        conv_dim = '1d'
        checkpoint = ''
        hidden_size = 64
        num_layers = 2
        bidirectional = 'true'
        with_se = False

        batch_size = 128
        num_epochs = 30
        learning_rate = 0.0003

        use_warmup = 'false'
        data_dir = './wav_data/pretrain/IEMOCAP_sub/'
        multi_task = 'false'
        augmentation = 'false'
        
        save_checkpoint_steps = 5
        output_dir = './model'
        #label_path = './wav_data/pretrain/IEMOCAP_vad/'

        bidirectional = True if(bidirectional == 'true') else False  
        n_mfcc = 40 if(conv_dim == '1d') else 128

        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        
        df_train = df.loc[train_index, :]
        
        train_samples, eval_samples, train_label, eval_label = train_test_split(df_train['sample_name'], df_train['sample_label'],
                                                                                test_size=0.1, random_state=42, 
                                                                                stratify=df_train['sample_label'])
        
        test_samples = df['sample_name'][test_index]
        test_label = df['sample_label'][test_index]
        
        train_samples = [data_dir + train_sample + '.wav' for train_sample in train_samples]
        eval_samples = [data_dir + eval_sample + '.wav' for eval_sample in eval_samples]
        test_samples = [data_dir + test_sample + '.wav' for test_sample in test_samples]

        y_train = np.array(train_label)
        y_eval = np.array(eval_label)
        y_test = np.array(test_label)
        
        #train_vad_list = []
        #for i in range(len(train_vad)):
        #    vad = np.load(train_vad[i])
        #    train_vad_list.append(vad)
        #vad_train = np.concatenate(train_vad_list)

        #eval_vad_list = []
        #for i in range(len(eval_vad)):
        #    vad = np.load(eval_vad[i])
        #    eval_vad_list.append(vad)
        #vad_eval = np.concatenate(eval_vad_list)

        if(multi_task == 'true'):
            speaker = np.array(list(map(lambda x: int(x.split('/')[-1].split('-')[-1].split('.')[0]), sample_datas)))
            y_gender = np.array(list(map(lambda x: 1 if x % 2 ==0 else 0, speaker)))

            y_g_train = y_gender[train_idx]
            y_g_eval = y_gender[eval_idx]

        X_train, y_train = convert_spectrograms(train_samples, conv_dim=conv_dim, method='mfcc', sr=16000, labels=y_train)
        X_eval, y_eval = convert_spectrograms(eval_samples, conv_dim=conv_dim, method='mfcc', sr=16000, labels=y_eval)
        X_test, y_test = convert_spectrograms(test_samples, conv_dim=conv_dim, method='mfcc', sr=16000, labels=y_test)
        print(X_train.shape, y_train.shape, X_eval.shape, y_eval.shape, X_test.shape, y_test.shape)
        
        #X_train = X_train[vad_train]
        #y_train = y_train[vad_train]
        #X_eval = X_eval[vad_eval]
        #y_eval = y_eval[vad_eval]
        #print(X_train.shape, y_train.shape, X_eval.shape, y_eval.shape)

        if(augmentation == 'true'):
            X_train_flip = X_train[:, :, :, ::-1]
            y_train_flip = y_train.copy()

            X_train = np.concatenate((X_train, X_train_flip), axis=0)
            y_train = np.concatenate((y_train, y_train_flip), axis=0)

        X_train, y_train = convert_tensor(X_train, y_train)
        X_eval, y_eval = convert_tensor(X_eval, y_eval)

        y_train = y_train.long()
        y_eval = y_eval.long()

        if(multi_task == 'true'):
            _, y_g_train = convert_spectrograms(train_samples, conv_dim=conv_dim, method='mfcc', sr=16000, labels=y_g_train)
            _, y_g_eval = convert_spectrograms(eval_samples, conv_dim=conv_dim, method='mfcc', sr=16000, labels=y_g_eval)

            if(augmentation == 'true'):
                y_g_train_flip = y_g_train.copy()
                y_g_train = np.concatenate((y_g_train, y_g_train_flip))

            y_g_train = torch.tensor(y_g_train).float()
            y_g_eval = torch.tensor(y_g_eval).float()

            y_g_train = y_g_train.unsqueeze(-1)
            y_g_eval = y_g_eval.unsqueeze(-1)

        if(multi_task == 'true'):
            train_ds = TensorDataset(X_train, y_train, y_g_train)
            eval_ds = TensorDataset(X_eval, y_eval, y_g_eval)
        else:
            train_ds = TensorDataset(X_train, y_train)
            eval_ds = TensorDataset(X_eval, y_eval)

        train_dataloader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=0, drop_last=True)
        eval_dataloader = DataLoader(eval_ds, batch_size=batch_size, num_workers=0)

        for en in range(5):
            model = CLDNN(conv_dim=conv_dim, checkpoint=checkpoint, hidden_size=hidden_size,
                          num_layers=num_layers, bidirectional=bidirectional,
                          with_focus_attn=with_focus_attn, with_se=with_se).to(device)

            if(multi_task == 'true'):
                model_g = CLDNN_G(conv_dim=conv_dim, checkpoint=checkpoint, hidden_size=hidden_size,
                                    num_layers=num_layers, bidirectional=bidirectional,
                                    with_focus_attn=with_focus_attn).to(device)

            if(multi_task == 'true'):
                loss_func = nn.CrossEntropyLoss()
                loss_func_g = nn.BCELoss()
                optimizer = optim.Adam(list(model.parameters()) + list(model_g.parameters()), lr=learning_rate)
            else:
                loss_func = nn.CrossEntropyLoss()
                optimizer = optim.Adam(model.parameters(), lr=learning_rate)

            if(use_warmup == 'true'):
                t_total = len(train_dataloader) // 1 * num_epochs
                opt_scheduler = WarmupLinearSchedule(optimizer, warmup_steps=t_total * 0.1, t_total=t_total)

            eval_acc = train(train_dataloader, eval_dataloader, num_epochs)
            cv_eval.append(eval_acc)

    print('conv_dim:', conv_dim, '\twith_focus_attn:', with_focus_attn)
    print('Test accuray:', cv_eval)
    print()
# Out:
# 4479it [00:44, 100.34it/s]
# 498it [00:04, 109.27it/s]
# 554it [00:05, 103.24it/s]
# (160630, 40, 100, 1) (160630,) (17768, 40, 100, 1) (17768,) (20737, 40, 100, 1) (20737,)
# Start training
# epoch:   1,    lr=0.000300,    loss=0.968906,    train_acc=0.586062,    eval_loss=0.977303,    eval_acc=0.595284
# epoch:   2,    lr=0.000300,    loss=0.806898,    train_acc=0.670448,    eval_loss=1.017592,    eval_acc=0.591119
# epoch:   3,    lr=0.000300,    loss=0.669759,    train_acc=0.733983,    eval_loss=1.108711,    eval_acc=0.583408
# epoch:   4,    lr=0.000300,    loss=0.531951,    train_acc=0.792333,    eval_loss=1.260493,    eval_acc=0.573784
# epoch:   5,    lr=0.000300,    loss=0.421197,    train_acc=0.837869,    eval_loss=1.333626,    eval_acc=0.593483
# Saving checkpoint ./model/CLDNN_cv1_step1_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.328759,    train_acc=0.875006,    eval_loss=1.493588,    eval_acc=0.586110
# epoch:   7,    lr=0.000300,    loss=0.265370,    train_acc=0.900468,    eval_loss=1.804505,    eval_acc=0.595621
# epoch:   8,    lr=0.000300,    loss=0.221045,    train_acc=0.916854,    eval_loss=1.764109,    eval_acc=0.598773
# epoch:   9,    lr=0.000300,    loss=0.185893,    train_acc=0.930871,    eval_loss=2.026055,    eval_acc=0.592807
# epoch:  10,    lr=0.000300,    loss=0.159675,    train_acc=0.940522,    eval_loss=2.066237,    eval_acc=0.580144
# Saving checkpoint ./model/CLDNN_cv1_step1_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.142386,    train_acc=0.948091,    eval_loss=2.084017,    eval_acc=0.581270
# epoch:  12,    lr=0.000300,    loss=0.127561,    train_acc=0.953106,    eval_loss=2.198360,    eval_acc=0.595846
# epoch:  13,    lr=0.000300,    loss=0.117063,    train_acc=0.957829,    eval_loss=2.204119,    eval_acc=0.583915
# epoch:  14,    lr=0.000300,    loss=0.105714,    train_acc=0.961473,    eval_loss=2.555590,    eval_acc=0.579638
# epoch:  15,    lr=0.000300,    loss=0.096317,    train_acc=0.964881,    eval_loss=2.571124,    eval_acc=0.591907
# Saving checkpoint ./model/CLDNN_cv1_step1_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.090726,    train_acc=0.967168,    eval_loss=2.505840,    eval_acc=0.587911
# epoch:  17,    lr=0.000300,    loss=0.082939,    train_acc=0.970058,    eval_loss=2.479473,    eval_acc=0.597929
# epoch:  18,    lr=0.000300,    loss=0.077495,    train_acc=0.972189,    eval_loss=2.615906,    eval_acc=0.587911
# epoch:  19,    lr=0.000300,    loss=0.070052,    train_acc=0.975460,    eval_loss=2.698967,    eval_acc=0.597254
# epoch:  20,    lr=0.000300,    loss=0.070917,    train_acc=0.974905,    eval_loss=2.552998,    eval_acc=0.592807
# Saving checkpoint ./model/CLDNN_cv1_step1_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.061113,    train_acc=0.978207,    eval_loss=2.774623,    eval_acc=0.596803
# epoch:  22,    lr=0.000300,    loss=0.057892,    train_acc=0.979472,    eval_loss=2.993151,    eval_acc=0.580876
# epoch:  23,    lr=0.000300,    loss=0.055038,    train_acc=0.980406,    eval_loss=2.856726,    eval_acc=0.592526
# epoch:  24,    lr=0.000300,    loss=0.053547,    train_acc=0.981166,    eval_loss=2.987948,    eval_acc=0.576373
# epoch:  25,    lr=0.000300,    loss=0.050709,    train_acc=0.982076,    eval_loss=2.776123,    eval_acc=0.586954
# Saving checkpoint ./model/CLDNN_cv1_step1_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.047342,    train_acc=0.982911,    eval_loss=2.748738,    eval_acc=0.592920
# epoch:  27,    lr=0.000300,    loss=0.045997,    train_acc=0.983534,    eval_loss=2.887331,    eval_acc=0.603388
# epoch:  28,    lr=0.000300,    loss=0.041641,    train_acc=0.985285,    eval_loss=2.921967,    eval_acc=0.597591
# epoch:  29,    lr=0.000300,    loss=0.041695,    train_acc=0.985677,    eval_loss=2.773785,    eval_acc=0.593314
# epoch:  30,    lr=0.000300,    loss=0.038639,    train_acc=0.986512,    eval_loss=2.792640,    eval_acc=0.596240
# Saving checkpoint ./model/CLDNN_cv1_step1_epoch30.pt
# Start training
# epoch:   1,    lr=0.000300,    loss=0.968348,    train_acc=0.584287,    eval_loss=0.981022,    eval_acc=0.584084
# epoch:   2,    lr=0.000300,    loss=0.803701,    train_acc=0.672965,    eval_loss=1.013383,    eval_acc=0.599674
# epoch:   3,    lr=0.000300,    loss=0.668401,    train_acc=0.733721,    eval_loss=1.009454,    eval_acc=0.608059
# epoch:   4,    lr=0.000300,    loss=0.541192,    train_acc=0.788639,    eval_loss=1.231224,    eval_acc=0.589430
# epoch:   5,    lr=0.000300,    loss=0.433958,    train_acc=0.834044,    eval_loss=1.329457,    eval_acc=0.588192
# Saving checkpoint ./model/CLDNN_cv1_step2_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.349327,    train_acc=0.867462,    eval_loss=1.468248,    eval_acc=0.598379
# epoch:   7,    lr=0.000300,    loss=0.283938,    train_acc=0.892949,    eval_loss=1.670152,    eval_acc=0.592245
# epoch:   8,    lr=0.000300,    loss=0.239487,    train_acc=0.910412,    eval_loss=1.827210,    eval_acc=0.604683
# epoch:   9,    lr=0.000300,    loss=0.202144,    train_acc=0.924598,    eval_loss=1.980814,    eval_acc=0.590443
# epoch:  10,    lr=0.000300,    loss=0.180466,    train_acc=0.933426,    eval_loss=1.987993,    eval_acc=0.579806
# Saving checkpoint ./model/CLDNN_cv1_step2_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.156717,    train_acc=0.941917,    eval_loss=1.992953,    eval_acc=0.597816
# epoch:  12,    lr=0.000300,    loss=0.139657,    train_acc=0.948770,    eval_loss=2.250752,    eval_acc=0.597310
# epoch:  13,    lr=0.000300,    loss=0.128606,    train_acc=0.952826,    eval_loss=2.109393,    eval_acc=0.605189
# epoch:  14,    lr=0.000300,    loss=0.113925,    train_acc=0.958502,    eval_loss=2.481217,    eval_acc=0.583183
# epoch:  15,    lr=0.000300,    loss=0.105939,    train_acc=0.961149,    eval_loss=2.367321,    eval_acc=0.590106
# Saving checkpoint ./model/CLDNN_cv1_step2_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.096644,    train_acc=0.964557,    eval_loss=2.531532,    eval_acc=0.592920
# epoch:  17,    lr=0.000300,    loss=0.090938,    train_acc=0.966700,    eval_loss=2.388030,    eval_acc=0.596916
# epoch:  18,    lr=0.000300,    loss=0.084351,    train_acc=0.969741,    eval_loss=2.416259,    eval_acc=0.598492
# epoch:  19,    lr=0.000300,    loss=0.079878,    train_acc=0.970582,    eval_loss=2.610010,    eval_acc=0.589318
# epoch:  20,    lr=0.000300,    loss=0.077494,    train_acc=0.971952,    eval_loss=2.738925,    eval_acc=0.588023
# Saving checkpoint ./model/CLDNN_cv1_step2_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.068341,    train_acc=0.975933,    eval_loss=2.660506,    eval_acc=0.593820
# epoch:  22,    lr=0.000300,    loss=0.065676,    train_acc=0.976319,    eval_loss=2.598019,    eval_acc=0.596240
# epoch:  23,    lr=0.000300,    loss=0.059556,    train_acc=0.979192,    eval_loss=2.697339,    eval_acc=0.586673
# epoch:  24,    lr=0.000300,    loss=0.056819,    train_acc=0.979927,    eval_loss=3.048871,    eval_acc=0.575473
# epoch:  25,    lr=0.000300,    loss=0.057503,    train_acc=0.979921,    eval_loss=2.613739,    eval_acc=0.589543
# Saving checkpoint ./model/CLDNN_cv1_step2_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.051463,    train_acc=0.982008,    eval_loss=2.784563,    eval_acc=0.586504
# epoch:  27,    lr=0.000300,    loss=0.048961,    train_acc=0.982886,    eval_loss=2.705241,    eval_acc=0.592019
# epoch:  28,    lr=0.000300,    loss=0.048211,    train_acc=0.983098,    eval_loss=2.712422,    eval_acc=0.604007
# epoch:  29,    lr=0.000300,    loss=0.044611,    train_acc=0.984450,    eval_loss=2.942616,    eval_acc=0.576092
# epoch:  30,    lr=0.000300,    loss=0.044504,    train_acc=0.984543,    eval_loss=2.736807,    eval_acc=0.573278
# Saving checkpoint ./model/CLDNN_cv1_step2_epoch30.pt
# Start training
# epoch:   1,    lr=0.000300,    loss=0.971624,    train_acc=0.582704,    eval_loss=0.995451,    eval_acc=0.596409
# epoch:   2,    lr=0.000300,    loss=0.806697,    train_acc=0.670261,    eval_loss=0.984446,    eval_acc=0.592807
# epoch:   3,    lr=0.000300,    loss=0.664067,    train_acc=0.733883,    eval_loss=1.080448,    eval_acc=0.594439
# epoch:   4,    lr=0.000300,    loss=0.529031,    train_acc=0.792589,    eval_loss=1.227712,    eval_acc=0.593764
# epoch:   5,    lr=0.000300,    loss=0.417834,    train_acc=0.837414,    eval_loss=1.333476,    eval_acc=0.606146
# Saving checkpoint ./model/CLDNN_cv1_step3_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.329361,    train_acc=0.873941,    eval_loss=1.514875,    eval_acc=0.589430
# epoch:   7,    lr=0.000300,    loss=0.262078,    train_acc=0.900562,    eval_loss=1.715315,    eval_acc=0.596128
# epoch:   8,    lr=0.000300,    loss=0.223845,    train_acc=0.915794,    eval_loss=1.963054,    eval_acc=0.589824
# epoch:   9,    lr=0.000300,    loss=0.188988,    train_acc=0.928952,    eval_loss=1.898271,    eval_acc=0.601024
# epoch:  10,    lr=0.000300,    loss=0.163958,    train_acc=0.939494,    eval_loss=2.235737,    eval_acc=0.581664
# Saving checkpoint ./model/CLDNN_cv1_step3_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.145780,    train_acc=0.945786,    eval_loss=2.317862,    eval_acc=0.577330
# epoch:  12,    lr=0.000300,    loss=0.133252,    train_acc=0.951138,    eval_loss=2.246335,    eval_acc=0.587911
# epoch:  13,    lr=0.000300,    loss=0.117980,    train_acc=0.956601,    eval_loss=2.528128,    eval_acc=0.593314
# epoch:  14,    lr=0.000300,    loss=0.107323,    train_acc=0.960819,    eval_loss=2.660305,    eval_acc=0.587911
# epoch:  15,    lr=0.000300,    loss=0.099753,    train_acc=0.963753,    eval_loss=2.448193,    eval_acc=0.602431
# Saving checkpoint ./model/CLDNN_cv1_step3_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.091793,    train_acc=0.966912,    eval_loss=2.551224,    eval_acc=0.584253
# epoch:  17,    lr=0.000300,    loss=0.085242,    train_acc=0.969167,    eval_loss=2.594192,    eval_acc=0.590612
# epoch:  18,    lr=0.000300,    loss=0.078323,    train_acc=0.972089,    eval_loss=2.529865,    eval_acc=0.597704
# epoch:  19,    lr=0.000300,    loss=0.074646,    train_acc=0.973186,    eval_loss=2.830613,    eval_acc=0.584365
# epoch:  20,    lr=0.000300,    loss=0.070085,    train_acc=0.974880,    eval_loss=2.766137,    eval_acc=0.591119
# Saving checkpoint ./model/CLDNN_cv1_step3_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.063025,    train_acc=0.977728,    eval_loss=2.869090,    eval_acc=0.586785
# epoch:  22,    lr=0.000300,    loss=0.060034,    train_acc=0.978394,    eval_loss=2.838204,    eval_acc=0.580426
# epoch:  23,    lr=0.000300,    loss=0.058389,    train_acc=0.979615,    eval_loss=2.797860,    eval_acc=0.600968
# epoch:  24,    lr=0.000300,    loss=0.054079,    train_acc=0.980911,    eval_loss=2.953575,    eval_acc=0.599392
# epoch:  25,    lr=0.000300,    loss=0.051284,    train_acc=0.982294,    eval_loss=3.019270,    eval_acc=0.601925
# Saving checkpoint ./model/CLDNN_cv1_step3_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.050131,    train_acc=0.982251,    eval_loss=2.687412,    eval_acc=0.598435
# epoch:  27,    lr=0.000300,    loss=0.044476,    train_acc=0.984468,    eval_loss=2.999851,    eval_acc=0.585491
# epoch:  28,    lr=0.000300,    loss=0.044302,    train_acc=0.984886,    eval_loss=2.995182,    eval_acc=0.585547
# epoch:  29,    lr=0.000300,    loss=0.042921,    train_acc=0.984929,    eval_loss=2.949813,    eval_acc=0.602319
# epoch:  30,    lr=0.000300,    loss=0.039177,    train_acc=0.986599,    eval_loss=3.193327,    eval_acc=0.580088
# Saving checkpoint ./model/CLDNN_cv1_step3_epoch30.pt
# Start training
# epoch:   1,    lr=0.000300,    loss=0.980005,    train_acc=0.575839,    eval_loss=1.052056,    eval_acc=0.569732
# epoch:   2,    lr=0.000300,    loss=0.816773,    train_acc=0.665340,    eval_loss=1.097335,    eval_acc=0.562078
# epoch:   3,    lr=0.000300,    loss=0.688894,    train_acc=0.724064,    eval_loss=1.061152,    eval_acc=0.591907
# epoch:   4,    lr=0.000300,    loss=0.568248,    train_acc=0.776914,    eval_loss=1.185444,    eval_acc=0.597704
# epoch:   5,    lr=0.000300,    loss=0.454879,    train_acc=0.824100,    eval_loss=1.245198,    eval_acc=0.585716
# Saving checkpoint ./model/CLDNN_cv1_step4_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.367818,    train_acc=0.858796,    eval_loss=1.419777,    eval_acc=0.582283
# epoch:   7,    lr=0.000300,    loss=0.297794,    train_acc=0.887666,    eval_loss=1.610644,    eval_acc=0.585491
# epoch:   8,    lr=0.000300,    loss=0.249029,    train_acc=0.905851,    eval_loss=1.891405,    eval_acc=0.578681
# epoch:   9,    lr=0.000300,    loss=0.210173,    train_acc=0.921171,    eval_loss=1.847648,    eval_acc=0.561740
# epoch:  10,    lr=0.000300,    loss=0.182693,    train_acc=0.931874,    eval_loss=2.170662,    eval_acc=0.583465
# Saving checkpoint ./model/CLDNN_cv1_step4_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.164086,    train_acc=0.939151,    eval_loss=2.175630,    eval_acc=0.562528
# epoch:  12,    lr=0.000300,    loss=0.142748,    train_acc=0.947319,    eval_loss=2.353812,    eval_acc=0.572828
# epoch:  13,    lr=0.000300,    loss=0.129989,    train_acc=0.952521,    eval_loss=2.403229,    eval_acc=0.576373
# epoch:  14,    lr=0.000300,    loss=0.118216,    train_acc=0.956838,    eval_loss=2.560765,    eval_acc=0.591231
# epoch:  15,    lr=0.000300,    loss=0.108281,    train_acc=0.960290,    eval_loss=2.509187,    eval_acc=0.585660
# Saving checkpoint ./model/CLDNN_cv1_step4_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.098883,    train_acc=0.963753,    eval_loss=2.772125,    eval_acc=0.571421
# epoch:  17,    lr=0.000300,    loss=0.092071,    train_acc=0.966569,    eval_loss=2.740307,    eval_acc=0.574066
# epoch:  18,    lr=0.000300,    loss=0.086849,    train_acc=0.968289,    eval_loss=2.784389,    eval_acc=0.563598
# epoch:  19,    lr=0.000300,    loss=0.080856,    train_acc=0.970993,    eval_loss=2.799303,    eval_acc=0.583465
# epoch:  20,    lr=0.000300,    loss=0.073593,    train_acc=0.973155,    eval_loss=2.820527,    eval_acc=0.573165
# Saving checkpoint ./model/CLDNN_cv1_step4_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.072103,    train_acc=0.973709,    eval_loss=2.524764,    eval_acc=0.570801
# epoch:  22,    lr=0.000300,    loss=0.065672,    train_acc=0.976731,    eval_loss=2.803236,    eval_acc=0.578568
# epoch:  23,    lr=0.000300,    loss=0.061266,    train_acc=0.978164,    eval_loss=2.875171,    eval_acc=0.595903
# epoch:  24,    lr=0.000300,    loss=0.058649,    train_acc=0.979453,    eval_loss=2.655212,    eval_acc=0.590106
# epoch:  25,    lr=0.000300,    loss=0.058634,    train_acc=0.979136,    eval_loss=2.810840,    eval_acc=0.594777
# Saving checkpoint ./model/CLDNN_cv1_step4_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.051270,    train_acc=0.982076,    eval_loss=2.861596,    eval_acc=0.595734
# epoch:  27,    lr=0.000300,    loss=0.049794,    train_acc=0.982556,    eval_loss=2.859766,    eval_acc=0.582114
# epoch:  28,    lr=0.000300,    loss=0.048350,    train_acc=0.982811,    eval_loss=2.883617,    eval_acc=0.592301
# epoch:  29,    lr=0.000300,    loss=0.046770,    train_acc=0.983752,    eval_loss=3.028152,    eval_acc=0.587517
# epoch:  30,    lr=0.000300,    loss=0.044451,    train_acc=0.984518,    eval_loss=2.959938,    eval_acc=0.596691
# Saving checkpoint ./model/CLDNN_cv1_step4_epoch30.pt
# Start training
# epoch:   1,    lr=0.000300,    loss=0.972038,    train_acc=0.581950,    eval_loss=0.989467,    eval_acc=0.587517
# epoch:   2,    lr=0.000300,    loss=0.811196,    train_acc=0.667533,    eval_loss=1.050376,    eval_acc=0.589093
# epoch:   3,    lr=0.000300,    loss=0.683743,    train_acc=0.726650,    eval_loss=1.151589,    eval_acc=0.588586
# epoch:   4,    lr=0.000300,    loss=0.554746,    train_acc=0.781861,    eval_loss=1.141424,    eval_acc=0.595452
# epoch:   5,    lr=0.000300,    loss=0.439731,    train_acc=0.830418,    eval_loss=1.293327,    eval_acc=0.582846
# Saving checkpoint ./model/CLDNN_cv1_step5_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.351714,    train_acc=0.865885,    eval_loss=1.605740,    eval_acc=0.578512
# epoch:   7,    lr=0.000300,    loss=0.293461,    train_acc=0.889435,    eval_loss=1.678871,    eval_acc=0.580369
# epoch:   8,    lr=0.000300,    loss=0.244441,    train_acc=0.908356,    eval_loss=1.783009,    eval_acc=0.589824
# epoch:   9,    lr=0.000300,    loss=0.212933,    train_acc=0.920180,    eval_loss=1.975966,    eval_acc=0.586785
# epoch:  10,    lr=0.000300,    loss=0.181710,    train_acc=0.932105,    eval_loss=2.172169,    eval_acc=0.576880
# Saving checkpoint ./model/CLDNN_cv1_step5_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.162276,    train_acc=0.939662,    eval_loss=2.077418,    eval_acc=0.593258
# epoch:  12,    lr=0.000300,    loss=0.149583,    train_acc=0.944066,    eval_loss=2.209447,    eval_acc=0.578681
# epoch:  13,    lr=0.000300,    loss=0.132413,    train_acc=0.950795,    eval_loss=2.347761,    eval_acc=0.576936
# epoch:  14,    lr=0.000300,    loss=0.121710,    train_acc=0.955156,    eval_loss=2.509588,    eval_acc=0.570464
# epoch:  15,    lr=0.000300,    loss=0.114566,    train_acc=0.958308,    eval_loss=2.345054,    eval_acc=0.593145
# Saving checkpoint ./model/CLDNN_cv1_step5_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.106815,    train_acc=0.960638,    eval_loss=2.588459,    eval_acc=0.567931
# epoch:  17,    lr=0.000300,    loss=0.098365,    train_acc=0.963361,    eval_loss=2.467973,    eval_acc=0.570689
# epoch:  18,    lr=0.000300,    loss=0.090904,    train_acc=0.966551,    eval_loss=2.561226,    eval_acc=0.582620
# epoch:  19,    lr=0.000300,    loss=0.086401,    train_acc=0.968015,    eval_loss=2.740087,    eval_acc=0.590556
# epoch:  20,    lr=0.000300,    loss=0.080336,    train_acc=0.970345,    eval_loss=2.875748,    eval_acc=0.576542
# Saving checkpoint ./model/CLDNN_cv1_step5_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.074371,    train_acc=0.972712,    eval_loss=2.833510,    eval_acc=0.572152
# epoch:  22,    lr=0.000300,    loss=0.072272,    train_acc=0.973765,    eval_loss=2.762076,    eval_acc=0.581157
# epoch:  23,    lr=0.000300,    loss=0.069737,    train_acc=0.975204,    eval_loss=2.644901,    eval_acc=0.565173
# epoch:  24,    lr=0.000300,    loss=0.065549,    train_acc=0.976338,    eval_loss=2.823358,    eval_acc=0.580032
# epoch:  25,    lr=0.000300,    loss=0.058690,    train_acc=0.979073,    eval_loss=2.835807,    eval_acc=0.585772
# Saving checkpoint ./model/CLDNN_cv1_step5_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.059098,    train_acc=0.978980,    eval_loss=2.926078,    eval_acc=0.576992
# epoch:  27,    lr=0.000300,    loss=0.052475,    train_acc=0.981241,    eval_loss=2.948190,    eval_acc=0.585097
# epoch:  28,    lr=0.000300,    loss=0.051401,    train_acc=0.981490,    eval_loss=3.003407,    eval_acc=0.586391
# epoch:  29,    lr=0.000300,    loss=0.047623,    train_acc=0.983347,    eval_loss=3.194920,    eval_acc=0.580088
# 11it [00:00, 107.47it/s]
# epoch:  30,    lr=0.000300,    loss=0.049010,    train_acc=0.982917,    eval_loss=2.527106,    eval_acc=0.579300
# Saving checkpoint ./model/CLDNN_cv1_step5_epoch30.pt
# 4480it [00:42, 106.37it/s]
# 498it [00:04, 107.69it/s]
# 553it [00:05, 104.45it/s]
# (160266, 40, 100, 1) (160266,) (16965, 40, 100, 1) (16965,) (21904, 40, 100, 1) (21904,)
# Start training
# epoch:   1,    lr=0.000300,    loss=0.962321,    train_acc=0.583616,    eval_loss=0.982573,    eval_acc=0.601474
# epoch:   2,    lr=0.000300,    loss=0.796606,    train_acc=0.672206,    eval_loss=1.036447,    eval_acc=0.594813
# epoch:   3,    lr=0.000300,    loss=0.650585,    train_acc=0.738837,    eval_loss=1.120555,    eval_acc=0.595933
# epoch:   4,    lr=0.000300,    loss=0.517913,    train_acc=0.796288,    eval_loss=1.202750,    eval_acc=0.607899
# epoch:   5,    lr=0.000300,    loss=0.406772,    train_acc=0.842128,    eval_loss=1.499162,    eval_acc=0.593752
# Saving checkpoint ./model/CLDNN_cv2_step1_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.318030,    train_acc=0.878544,    eval_loss=1.678538,    eval_acc=0.594400
# epoch:   7,    lr=0.000300,    loss=0.255488,    train_acc=0.903018,    eval_loss=1.895443,    eval_acc=0.585087
# epoch:   8,    lr=0.000300,    loss=0.212603,    train_acc=0.920203,    eval_loss=2.035322,    eval_acc=0.585441
# epoch:   9,    lr=0.000300,    loss=0.180758,    train_acc=0.932545,    eval_loss=2.238413,    eval_acc=0.587563
# epoch:  10,    lr=0.000300,    loss=0.158627,    train_acc=0.940920,    eval_loss=2.259313,    eval_acc=0.595638
# Saving checkpoint ./model/CLDNN_cv2_step1_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.136978,    train_acc=0.949768,    eval_loss=2.366251,    eval_acc=0.600236
# epoch:  12,    lr=0.000300,    loss=0.122676,    train_acc=0.955172,    eval_loss=2.510846,    eval_acc=0.586325
# epoch:  13,    lr=0.000300,    loss=0.108786,    train_acc=0.960089,    eval_loss=2.554337,    eval_acc=0.577247
# epoch:  14,    lr=0.000300,    loss=0.101696,    train_acc=0.963047,    eval_loss=2.457304,    eval_acc=0.589095
# epoch:  15,    lr=0.000300,    loss=0.090473,    train_acc=0.966666,    eval_loss=2.604885,    eval_acc=0.604362
# Saving checkpoint ./model/CLDNN_cv2_step1_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.086906,    train_acc=0.969193,    eval_loss=2.429677,    eval_acc=0.602888
# epoch:  17,    lr=0.000300,    loss=0.077798,    train_acc=0.971957,    eval_loss=2.682613,    eval_acc=0.591335
# epoch:  18,    lr=0.000300,    loss=0.075012,    train_acc=0.972650,    eval_loss=2.605707,    eval_acc=0.605953
# epoch:  19,    lr=0.000300,    loss=0.068986,    train_acc=0.975527,    eval_loss=2.632227,    eval_acc=0.607014
# epoch:  20,    lr=0.000300,    loss=0.062988,    train_acc=0.977342,    eval_loss=2.743323,    eval_acc=0.598703
# Saving checkpoint ./model/CLDNN_cv2_step1_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.061141,    train_acc=0.977885,    eval_loss=2.645027,    eval_acc=0.603890
# epoch:  22,    lr=0.000300,    loss=0.054713,    train_acc=0.980475,    eval_loss=2.907693,    eval_acc=0.591630
# epoch:  23,    lr=0.000300,    loss=0.054554,    train_acc=0.980675,    eval_loss=2.999904,    eval_acc=0.590981
# epoch:  24,    lr=0.000300,    loss=0.050407,    train_acc=0.982147,    eval_loss=3.281616,    eval_acc=0.575302
# epoch:  25,    lr=0.000300,    loss=0.048428,    train_acc=0.983083,    eval_loss=2.921944,    eval_acc=0.600884
# Saving checkpoint ./model/CLDNN_cv2_step1_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.045611,    train_acc=0.984026,    eval_loss=3.116033,    eval_acc=0.587916
# epoch:  27,    lr=0.000300,    loss=0.043096,    train_acc=0.984799,    eval_loss=2.997857,    eval_acc=0.601709
# epoch:  28,    lr=0.000300,    loss=0.044734,    train_acc=0.984088,    eval_loss=2.830465,    eval_acc=0.596699
# epoch:  29,    lr=0.000300,    loss=0.038890,    train_acc=0.986746,    eval_loss=2.836914,    eval_acc=0.607604
# epoch:  30,    lr=0.000300,    loss=0.037821,    train_acc=0.986609,    eval_loss=2.944268,    eval_acc=0.604421
# Saving checkpoint ./model/CLDNN_cv2_step1_epoch30.pt
# Start training
# epoch:   1,    lr=0.000300,    loss=0.963905,    train_acc=0.582474,    eval_loss=0.981368,    eval_acc=0.597289
# epoch:   2,    lr=0.000300,    loss=0.801280,    train_acc=0.670072,    eval_loss=1.053705,    eval_acc=0.586914
# epoch:   3,    lr=0.000300,    loss=0.664204,    train_acc=0.732971,    eval_loss=1.067056,    eval_acc=0.617683
# epoch:   4,    lr=0.000300,    loss=0.534483,    train_acc=0.788632,    eval_loss=1.206114,    eval_acc=0.600472
# epoch:   5,    lr=0.000300,    loss=0.423152,    train_acc=0.835438,    eval_loss=1.486595,    eval_acc=0.576245
# Saving checkpoint ./model/CLDNN_cv2_step2_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.337911,    train_acc=0.870339,    eval_loss=1.557261,    eval_acc=0.604362
# epoch:   7,    lr=0.000300,    loss=0.274204,    train_acc=0.895935,    eval_loss=1.538260,    eval_acc=0.596522
# epoch:   8,    lr=0.000300,    loss=0.223549,    train_acc=0.915242,    eval_loss=1.693461,    eval_acc=0.598703
# epoch:   9,    lr=0.000300,    loss=0.189341,    train_acc=0.928489,    eval_loss=2.032710,    eval_acc=0.592632
# epoch:  10,    lr=0.000300,    loss=0.163169,    train_acc=0.939066,    eval_loss=2.159327,    eval_acc=0.600648
# Saving checkpoint ./model/CLDNN_cv2_step2_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.144927,    train_acc=0.945624,    eval_loss=2.042027,    eval_acc=0.601474
# epoch:  12,    lr=0.000300,    loss=0.129515,    train_acc=0.951883,    eval_loss=2.328183,    eval_acc=0.598880
# epoch:  13,    lr=0.000300,    loss=0.117673,    train_acc=0.956875,    eval_loss=2.338087,    eval_acc=0.593988
# epoch:  14,    lr=0.000300,    loss=0.106710,    train_acc=0.960831,    eval_loss=2.443235,    eval_acc=0.599941
# epoch:  15,    lr=0.000300,    loss=0.101816,    train_acc=0.962766,    eval_loss=2.371999,    eval_acc=0.585205
# Saving checkpoint ./model/CLDNN_cv2_step2_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.088561,    train_acc=0.967365,    eval_loss=2.691854,    eval_acc=0.587975
# epoch:  17,    lr=0.000300,    loss=0.084383,    train_acc=0.969499,    eval_loss=2.411055,    eval_acc=0.586384
# epoch:  18,    lr=0.000300,    loss=0.080045,    train_acc=0.971021,    eval_loss=2.502630,    eval_acc=0.597996
# epoch:  19,    lr=0.000300,    loss=0.073545,    train_acc=0.973374,    eval_loss=2.625730,    eval_acc=0.586973
# epoch:  20,    lr=0.000300,    loss=0.067000,    train_acc=0.975957,    eval_loss=2.673340,    eval_acc=0.596228
# Saving checkpoint ./model/CLDNN_cv2_step2_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.064947,    train_acc=0.976500,    eval_loss=2.755738,    eval_acc=0.597524
# epoch:  22,    lr=0.000300,    loss=0.059224,    train_acc=0.978254,    eval_loss=2.928061,    eval_acc=0.585853
# epoch:  23,    lr=0.000300,    loss=0.057903,    train_acc=0.979458,    eval_loss=2.833188,    eval_acc=0.592986
# epoch:  24,    lr=0.000300,    loss=0.054404,    train_acc=0.980413,    eval_loss=2.901461,    eval_acc=0.579841
# epoch:  25,    lr=0.000300,    loss=0.051122,    train_acc=0.981985,    eval_loss=2.950672,    eval_acc=0.591983
# Saving checkpoint ./model/CLDNN_cv2_step2_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.047879,    train_acc=0.982647,    eval_loss=2.947981,    eval_acc=0.579310
# epoch:  27,    lr=0.000300,    loss=0.049111,    train_acc=0.982759,    eval_loss=2.669349,    eval_acc=0.595933
# epoch:  28,    lr=0.000300,    loss=0.043576,    train_acc=0.984469,    eval_loss=2.838392,    eval_acc=0.595402
# epoch:  29,    lr=0.000300,    loss=0.041518,    train_acc=0.985342,    eval_loss=3.276461,    eval_acc=0.574064
# epoch:  30,    lr=0.000300,    loss=0.040883,    train_acc=0.985479,    eval_loss=2.989157,    eval_acc=0.594813
# Saving checkpoint ./model/CLDNN_cv2_step2_epoch30.pt
# Start training
# epoch:   1,    lr=0.000300,    loss=0.957896,    train_acc=0.584889,    eval_loss=0.973495,    eval_acc=0.590687
# epoch:   2,    lr=0.000300,    loss=0.793683,    train_acc=0.672905,    eval_loss=1.001174,    eval_acc=0.616387
# epoch:   3,    lr=0.000300,    loss=0.659253,    train_acc=0.735211,    eval_loss=1.119117,    eval_acc=0.606779
# epoch:   4,    lr=0.000300,    loss=0.539324,    train_acc=0.786741,    eval_loss=1.251058,    eval_acc=0.600825
# epoch:   5,    lr=0.000300,    loss=0.431529,    train_acc=0.831282,    eval_loss=1.503445,    eval_acc=0.588800
# Saving checkpoint ./model/CLDNN_cv2_step3_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.345034,    train_acc=0.867237,    eval_loss=1.586580,    eval_acc=0.587681
# epoch:   7,    lr=0.000300,    loss=0.279483,    train_acc=0.893158,    eval_loss=1.731427,    eval_acc=0.598408
# epoch:   8,    lr=0.000300,    loss=0.228523,    train_acc=0.913526,    eval_loss=1.868662,    eval_acc=0.597760
# epoch:   9,    lr=0.000300,    loss=0.194556,    train_acc=0.926549,    eval_loss=1.964434,    eval_acc=0.594695
# epoch:  10,    lr=0.000300,    loss=0.169577,    train_acc=0.936857,    eval_loss=2.133591,    eval_acc=0.607132
# Saving checkpoint ./model/CLDNN_cv2_step3_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.150659,    train_acc=0.944252,    eval_loss=2.169638,    eval_acc=0.588800
# epoch:  12,    lr=0.000300,    loss=0.128213,    train_acc=0.952757,    eval_loss=2.392945,    eval_acc=0.583672
# epoch:  13,    lr=0.000300,    loss=0.121096,    train_acc=0.955914,    eval_loss=2.318557,    eval_acc=0.594636
# epoch:  14,    lr=0.000300,    loss=0.107647,    train_acc=0.960869,    eval_loss=2.410387,    eval_acc=0.592750
# epoch:  15,    lr=0.000300,    loss=0.101864,    train_acc=0.962847,    eval_loss=2.467334,    eval_acc=0.597406
# Saving checkpoint ./model/CLDNN_cv2_step3_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.095266,    train_acc=0.965468,    eval_loss=2.508442,    eval_acc=0.575774
# epoch:  17,    lr=0.000300,    loss=0.082989,    train_acc=0.970198,    eval_loss=2.686757,    eval_acc=0.569525
# epoch:  18,    lr=0.000300,    loss=0.077266,    train_acc=0.972288,    eval_loss=2.447722,    eval_acc=0.601415
# epoch:  19,    lr=0.000300,    loss=0.072930,    train_acc=0.973973,    eval_loss=2.557617,    eval_acc=0.591158
# epoch:  20,    lr=0.000300,    loss=0.070611,    train_acc=0.974890,    eval_loss=2.439167,    eval_acc=0.603419
# Saving checkpoint ./model/CLDNN_cv2_step3_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.063545,    train_acc=0.977455,    eval_loss=2.738205,    eval_acc=0.602240
# epoch:  22,    lr=0.000300,    loss=0.060512,    train_acc=0.978634,    eval_loss=2.710058,    eval_acc=0.599941
# epoch:  23,    lr=0.000300,    loss=0.057114,    train_acc=0.979976,    eval_loss=2.559120,    eval_acc=0.607486
# epoch:  24,    lr=0.000300,    loss=0.055562,    train_acc=0.980438,    eval_loss=2.784026,    eval_acc=0.606543
# epoch:  25,    lr=0.000300,    loss=0.052083,    train_acc=0.981686,    eval_loss=2.733809,    eval_acc=0.606189
# Saving checkpoint ./model/CLDNN_cv2_step3_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.048041,    train_acc=0.983077,    eval_loss=3.003320,    eval_acc=0.604833
# epoch:  27,    lr=0.000300,    loss=0.043912,    train_acc=0.984618,    eval_loss=2.996621,    eval_acc=0.588388
# epoch:  28,    lr=0.000300,    loss=0.043251,    train_acc=0.984855,    eval_loss=2.831118,    eval_acc=0.602299
# epoch:  29,    lr=0.000300,    loss=0.045924,    train_acc=0.983576,    eval_loss=2.855839,    eval_acc=0.607191
# epoch:  30,    lr=0.000300,    loss=0.038354,    train_acc=0.986590,    eval_loss=2.990746,    eval_acc=0.602181
# Saving checkpoint ./model/CLDNN_cv2_step3_epoch30.pt
# Start training
# epoch:   1,    lr=0.000300,    loss=0.961204,    train_acc=0.582649,    eval_loss=1.005827,    eval_acc=0.565223
# epoch:   2,    lr=0.000300,    loss=0.796949,    train_acc=0.671501,    eval_loss=0.979359,    eval_acc=0.608016
# epoch:   3,    lr=0.000300,    loss=0.658177,    train_acc=0.735592,    eval_loss=1.096798,    eval_acc=0.613734
# epoch:   4,    lr=0.000300,    loss=0.535624,    train_acc=0.787790,    eval_loss=1.240748,    eval_acc=0.601356
# epoch:   5,    lr=0.000300,    loss=0.421722,    train_acc=0.835700,    eval_loss=1.405383,    eval_acc=0.622399
# Saving checkpoint ./model/CLDNN_cv2_step4_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.335818,    train_acc=0.871793,    eval_loss=1.517933,    eval_acc=0.607545
# epoch:   7,    lr=0.000300,    loss=0.271551,    train_acc=0.897414,    eval_loss=1.763727,    eval_acc=0.598880
# epoch:   8,    lr=0.000300,    loss=0.225615,    train_acc=0.914867,    eval_loss=2.011310,    eval_acc=0.608311
# epoch:   9,    lr=0.000300,    loss=0.191953,    train_acc=0.927903,    eval_loss=2.169625,    eval_acc=0.583319
# epoch:  10,    lr=0.000300,    loss=0.169643,    train_acc=0.936745,    eval_loss=2.172668,    eval_acc=0.607250
# Saving checkpoint ./model/CLDNN_cv2_step4_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.146033,    train_acc=0.946142,    eval_loss=2.264897,    eval_acc=0.591335
# epoch:  12,    lr=0.000300,    loss=0.132404,    train_acc=0.950897,    eval_loss=2.295492,    eval_acc=0.595225
# epoch:  13,    lr=0.000300,    loss=0.114920,    train_acc=0.957443,    eval_loss=2.482787,    eval_acc=0.589803
# epoch:  14,    lr=0.000300,    loss=0.108307,    train_acc=0.960482,    eval_loss=2.379097,    eval_acc=0.599764
# epoch:  15,    lr=0.000300,    loss=0.100492,    train_acc=0.963103,    eval_loss=2.423256,    eval_acc=0.611141
# Saving checkpoint ./model/CLDNN_cv2_step4_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.088955,    train_acc=0.967783,    eval_loss=2.534406,    eval_acc=0.601650
# epoch:  17,    lr=0.000300,    loss=0.084963,    train_acc=0.969368,    eval_loss=2.552959,    eval_acc=0.611494
# epoch:  18,    lr=0.000300,    loss=0.077601,    train_acc=0.971876,    eval_loss=2.518578,    eval_acc=0.598644
# epoch:  19,    lr=0.000300,    loss=0.070059,    train_acc=0.975090,    eval_loss=2.630862,    eval_acc=0.595225
# epoch:  20,    lr=0.000300,    loss=0.066640,    train_acc=0.975901,    eval_loss=2.666450,    eval_acc=0.595520
# Saving checkpoint ./model/CLDNN_cv2_step4_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.065687,    train_acc=0.976619,    eval_loss=2.591218,    eval_acc=0.605482
# epoch:  22,    lr=0.000300,    loss=0.059493,    train_acc=0.978503,    eval_loss=2.959759,    eval_acc=0.594695
# epoch:  23,    lr=0.000300,    loss=0.054687,    train_acc=0.980693,    eval_loss=2.987167,    eval_acc=0.593280
# epoch:  24,    lr=0.000300,    loss=0.053150,    train_acc=0.981417,    eval_loss=2.963216,    eval_acc=0.596286
# epoch:  25,    lr=0.000300,    loss=0.050668,    train_acc=0.982353,    eval_loss=3.087187,    eval_acc=0.601179
# Saving checkpoint ./model/CLDNN_cv2_step4_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.046437,    train_acc=0.983395,    eval_loss=3.145617,    eval_acc=0.606071
# epoch:  27,    lr=0.000300,    loss=0.047876,    train_acc=0.983090,    eval_loss=2.826190,    eval_acc=0.592573
# epoch:  28,    lr=0.000300,    loss=0.044247,    train_acc=0.984163,    eval_loss=2.804535,    eval_acc=0.608429
# epoch:  29,    lr=0.000300,    loss=0.040979,    train_acc=0.986122,    eval_loss=2.804592,    eval_acc=0.614265
# epoch:  30,    lr=0.000300,    loss=0.041384,    train_acc=0.985373,    eval_loss=2.778251,    eval_acc=0.590156
# Saving checkpoint ./model/CLDNN_cv2_step4_epoch30.pt
# Start training
# epoch:   1,    lr=0.000300,    loss=0.962447,    train_acc=0.582493,    eval_loss=0.974857,    eval_acc=0.596994
# epoch:   2,    lr=0.000300,    loss=0.792418,    train_acc=0.675376,    eval_loss=1.152604,    eval_acc=0.565281
# epoch:   3,    lr=0.000300,    loss=0.652916,    train_acc=0.738350,    eval_loss=1.048079,    eval_acc=0.604951
# epoch:   4,    lr=0.000300,    loss=0.526088,    train_acc=0.792962,    eval_loss=1.209869,    eval_acc=0.610374
# epoch:   5,    lr=0.000300,    loss=0.420477,    train_acc=0.836118,    eval_loss=1.413513,    eval_acc=0.605423
# Saving checkpoint ./model/CLDNN_cv2_step5_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.333613,    train_acc=0.872161,    eval_loss=1.721097,    eval_acc=0.600707
# epoch:   7,    lr=0.000300,    loss=0.274170,    train_acc=0.895885,    eval_loss=1.776520,    eval_acc=0.599528
# epoch:   8,    lr=0.000300,    loss=0.230342,    train_acc=0.913270,    eval_loss=1.944823,    eval_acc=0.604775
# epoch:   9,    lr=0.000300,    loss=0.191955,    train_acc=0.928333,    eval_loss=2.133343,    eval_acc=0.598644
# epoch:  10,    lr=0.000300,    loss=0.168137,    train_acc=0.936782,    eval_loss=2.210064,    eval_acc=0.605659
# Saving checkpoint ./model/CLDNN_cv2_step5_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.149397,    train_acc=0.944196,    eval_loss=2.183540,    eval_acc=0.603596
# epoch:  12,    lr=0.000300,    loss=0.131544,    train_acc=0.951128,    eval_loss=2.342651,    eval_acc=0.600943
# epoch:  13,    lr=0.000300,    loss=0.120145,    train_acc=0.955490,    eval_loss=2.458690,    eval_acc=0.606838
# epoch:  14,    lr=0.000300,    loss=0.112065,    train_acc=0.958728,    eval_loss=2.652373,    eval_acc=0.589272
# epoch:  15,    lr=0.000300,    loss=0.100908,    train_acc=0.963783,    eval_loss=2.252653,    eval_acc=0.598939
# Saving checkpoint ./model/CLDNN_cv2_step5_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.092846,    train_acc=0.966142,    eval_loss=2.636539,    eval_acc=0.607427
# epoch:  17,    lr=0.000300,    loss=0.089057,    train_acc=0.967677,    eval_loss=2.765015,    eval_acc=0.578367
# epoch:  18,    lr=0.000300,    loss=0.080456,    train_acc=0.970547,    eval_loss=2.735434,    eval_acc=0.591630
# epoch:  19,    lr=0.000300,    loss=0.075012,    train_acc=0.972918,    eval_loss=2.821199,    eval_acc=0.583672
# epoch:  20,    lr=0.000300,    loss=0.070799,    train_acc=0.974584,    eval_loss=2.649642,    eval_acc=0.606661
# Saving checkpoint ./model/CLDNN_cv2_step5_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.066737,    train_acc=0.976244,    eval_loss=2.846184,    eval_acc=0.593516
# epoch:  22,    lr=0.000300,    loss=0.064427,    train_acc=0.976806,    eval_loss=2.805136,    eval_acc=0.596110
# epoch:  23,    lr=0.000300,    loss=0.057649,    train_acc=0.979551,    eval_loss=2.804640,    eval_acc=0.608960
# epoch:  24,    lr=0.000300,    loss=0.055807,    train_acc=0.980250,    eval_loss=2.808428,    eval_acc=0.606661
# epoch:  25,    lr=0.000300,    loss=0.053839,    train_acc=0.980768,    eval_loss=2.730091,    eval_acc=0.596463
# Saving checkpoint ./model/CLDNN_cv2_step5_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.049343,    train_acc=0.982328,    eval_loss=3.063556,    eval_acc=0.603655
# epoch:  27,    lr=0.000300,    loss=0.051578,    train_acc=0.981885,    eval_loss=2.747538,    eval_acc=0.612143
# epoch:  28,    lr=0.000300,    loss=0.044738,    train_acc=0.983976,    eval_loss=2.899068,    eval_acc=0.605423
# epoch:  29,    lr=0.000300,    loss=0.042639,    train_acc=0.985011,    eval_loss=2.948934,    eval_acc=0.596110
# 12it [00:00, 102.25it/s]
# epoch:  30,    lr=0.000300,    loss=0.042882,    train_acc=0.984962,    eval_loss=3.103189,    eval_acc=0.601356
# Saving checkpoint ./model/CLDNN_cv2_step5_epoch30.pt
# 4480it [00:30, 145.03it/s]
# 498it [00:03, 150.24it/s]
# 553it [00:03, 152.95it/s]
# (161435, 40, 100, 1) (161435,) (17358, 40, 100, 1) (17358,) (20342, 40, 100, 1) (20342,)
# Start training
# epoch:   1,    lr=0.000300,    loss=0.958633,    train_acc=0.588837,    eval_loss=1.045775,    eval_acc=0.564984
# epoch:   2,    lr=0.000300,    loss=0.807971,    train_acc=0.668833,    eval_loss=0.937292,    eval_acc=0.618216
# epoch:   3,    lr=0.000300,    loss=0.676733,    train_acc=0.727913,    eval_loss=0.994456,    eval_acc=0.627319
# epoch:   4,    lr=0.000300,    loss=0.551192,    train_acc=0.782923,    eval_loss=1.031934,    eval_acc=0.632158
# epoch:   5,    lr=0.000300,    loss=0.440615,    train_acc=0.829098,    eval_loss=1.296534,    eval_acc=0.614068
# Saving checkpoint ./model/CLDNN_cv3_step1_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.354628,    train_acc=0.863774,    eval_loss=1.448912,    eval_acc=0.617237
# epoch:   7,    lr=0.000300,    loss=0.291904,    train_acc=0.888184,    eval_loss=1.443621,    eval_acc=0.628586
# epoch:   8,    lr=0.000300,    loss=0.242955,    train_acc=0.907867,    eval_loss=1.726339,    eval_acc=0.625360
# epoch:   9,    lr=0.000300,    loss=0.204136,    train_acc=0.922464,    eval_loss=1.758478,    eval_acc=0.631582
# epoch:  10,    lr=0.000300,    loss=0.178934,    train_acc=0.933721,    eval_loss=1.803316,    eval_acc=0.623862
# Saving checkpoint ./model/CLDNN_cv3_step1_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.158154,    train_acc=0.940988,    eval_loss=1.862368,    eval_acc=0.626109
# epoch:  12,    lr=0.000300,    loss=0.139261,    train_acc=0.948175,    eval_loss=2.003752,    eval_acc=0.609632
# epoch:  13,    lr=0.000300,    loss=0.126030,    train_acc=0.953540,    eval_loss=2.203438,    eval_acc=0.631467
# epoch:  14,    lr=0.000300,    loss=0.117767,    train_acc=0.956675,    eval_loss=2.218907,    eval_acc=0.617007
# epoch:  15,    lr=0.000300,    loss=0.108373,    train_acc=0.960250,    eval_loss=2.106901,    eval_acc=0.620406
# Saving checkpoint ./model/CLDNN_cv3_step1_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.099729,    train_acc=0.963608,    eval_loss=2.268547,    eval_acc=0.608135
# epoch:  17,    lr=0.000300,    loss=0.093294,    train_acc=0.965881,    eval_loss=2.318537,    eval_acc=0.608884
# epoch:  18,    lr=0.000300,    loss=0.088237,    train_acc=0.968267,    eval_loss=2.328634,    eval_acc=0.614702
# epoch:  19,    lr=0.000300,    loss=0.080143,    train_acc=0.970813,    eval_loss=2.438560,    eval_acc=0.615048
# epoch:  20,    lr=0.000300,    loss=0.073676,    train_acc=0.973397,    eval_loss=2.620020,    eval_acc=0.607789
# Saving checkpoint ./model/CLDNN_cv3_step1_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.071461,    train_acc=0.974190,    eval_loss=2.472905,    eval_acc=0.612455
# epoch:  22,    lr=0.000300,    loss=0.063793,    train_acc=0.977201,    eval_loss=2.712904,    eval_acc=0.627031
# epoch:  23,    lr=0.000300,    loss=0.063217,    train_acc=0.977833,    eval_loss=2.531501,    eval_acc=0.615854
# epoch:  24,    lr=0.000300,    loss=0.057642,    train_acc=0.979542,    eval_loss=2.552827,    eval_acc=0.601221
# epoch:  25,    lr=0.000300,    loss=0.055891,    train_acc=0.979995,    eval_loss=2.596720,    eval_acc=0.607731
# Saving checkpoint ./model/CLDNN_cv3_step1_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.051956,    train_acc=0.981655,    eval_loss=2.718812,    eval_acc=0.616430
# epoch:  27,    lr=0.000300,    loss=0.047647,    train_acc=0.983563,    eval_loss=2.541911,    eval_acc=0.616488
# epoch:  28,    lr=0.000300,    loss=0.046883,    train_acc=0.983439,    eval_loss=2.910327,    eval_acc=0.608999
# epoch:  29,    lr=0.000300,    loss=0.043526,    train_acc=0.984765,    eval_loss=2.822439,    eval_acc=0.610785
# epoch:  30,    lr=0.000300,    loss=0.043705,    train_acc=0.984617,    eval_loss=2.997463,    eval_acc=0.614990
# Saving checkpoint ./model/CLDNN_cv3_step1_epoch30.pt
# Start training
# epoch:   1,    lr=0.000300,    loss=0.957788,    train_acc=0.588763,    eval_loss=0.959262,    eval_acc=0.602201
# epoch:   2,    lr=0.000300,    loss=0.799921,    train_acc=0.671045,    eval_loss=0.934936,    eval_acc=0.627261
# epoch:   3,    lr=0.000300,    loss=0.666121,    train_acc=0.732739,    eval_loss=1.025124,    eval_acc=0.605139
# epoch:   4,    lr=0.000300,    loss=0.539364,    train_acc=0.787638,    eval_loss=1.103570,    eval_acc=0.622191
# epoch:   5,    lr=0.000300,    loss=0.431365,    train_acc=0.833360,    eval_loss=1.247143,    eval_acc=0.627895
# Saving checkpoint ./model/CLDNN_cv3_step2_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.352549,    train_acc=0.864709,    eval_loss=1.449837,    eval_acc=0.625360
# epoch:   7,    lr=0.000300,    loss=0.285317,    train_acc=0.892031,    eval_loss=1.597449,    eval_acc=0.612167
# epoch:   8,    lr=0.000300,    loss=0.241032,    train_acc=0.909788,    eval_loss=1.712243,    eval_acc=0.618908
# epoch:   9,    lr=0.000300,    loss=0.207329,    train_acc=0.922333,    eval_loss=1.800395,    eval_acc=0.617007
# epoch:  10,    lr=0.000300,    loss=0.181377,    train_acc=0.933014,    eval_loss=1.752365,    eval_acc=0.616315
# Saving checkpoint ./model/CLDNN_cv3_step2_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.161621,    train_acc=0.940672,    eval_loss=1.959036,    eval_acc=0.612686
# epoch:  12,    lr=0.000300,    loss=0.141958,    train_acc=0.947784,    eval_loss=1.990551,    eval_acc=0.617179
# epoch:  13,    lr=0.000300,    loss=0.129944,    train_acc=0.952227,    eval_loss=2.074291,    eval_acc=0.625418
# epoch:  14,    lr=0.000300,    loss=0.116847,    train_acc=0.957177,    eval_loss=2.349703,    eval_acc=0.611188
# epoch:  15,    lr=0.000300,    loss=0.107757,    train_acc=0.960950,    eval_loss=2.186136,    eval_acc=0.624093
# Saving checkpoint ./model/CLDNN_cv3_step2_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.103883,    train_acc=0.962567,    eval_loss=2.101407,    eval_acc=0.620578
# epoch:  17,    lr=0.000300,    loss=0.091674,    train_acc=0.966433,    eval_loss=2.264099,    eval_acc=0.617813
# epoch:  18,    lr=0.000300,    loss=0.086219,    train_acc=0.968880,    eval_loss=2.177342,    eval_acc=0.625245
# epoch:  19,    lr=0.000300,    loss=0.081625,    train_acc=0.971371,    eval_loss=2.516081,    eval_acc=0.618159
# epoch:  20,    lr=0.000300,    loss=0.075549,    train_acc=0.972151,    eval_loss=2.390797,    eval_acc=0.630142
# Saving checkpoint ./model/CLDNN_cv3_step2_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.068988,    train_acc=0.975435,    eval_loss=2.515102,    eval_acc=0.613031
# epoch:  22,    lr=0.000300,    loss=0.068809,    train_acc=0.975361,    eval_loss=2.455682,    eval_acc=0.621443
# epoch:  23,    lr=0.000300,    loss=0.063719,    train_acc=0.977114,    eval_loss=2.273181,    eval_acc=0.620866
# epoch:  24,    lr=0.000300,    loss=0.060291,    train_acc=0.979090,    eval_loss=2.447170,    eval_acc=0.619772
# epoch:  25,    lr=0.000300,    loss=0.058588,    train_acc=0.979152,    eval_loss=2.692736,    eval_acc=0.605600
# Saving checkpoint ./model/CLDNN_cv3_step2_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.054655,    train_acc=0.980800,    eval_loss=2.663952,    eval_acc=0.616027
# epoch:  27,    lr=0.000300,    loss=0.049519,    train_acc=0.982845,    eval_loss=2.550436,    eval_acc=0.609402
# epoch:  28,    lr=0.000300,    loss=0.048170,    train_acc=0.983031,    eval_loss=2.792722,    eval_acc=0.611015
# epoch:  29,    lr=0.000300,    loss=0.045982,    train_acc=0.983997,    eval_loss=2.590422,    eval_acc=0.634808
# epoch:  30,    lr=0.000300,    loss=0.046954,    train_acc=0.983706,    eval_loss=2.488134,    eval_acc=0.618044
# Saving checkpoint ./model/CLDNN_cv3_step2_epoch30.pt
# Start training
# epoch:   1,    lr=0.000300,    loss=0.963027,    train_acc=0.585343,    eval_loss=0.902762,    eval_acc=0.630430
# epoch:   2,    lr=0.000300,    loss=0.804422,    train_acc=0.667643,    eval_loss=0.948454,    eval_acc=0.617295
# epoch:   3,    lr=0.000300,    loss=0.668997,    train_acc=0.731922,    eval_loss=0.986403,    eval_acc=0.624150
# epoch:   4,    lr=0.000300,    loss=0.541949,    train_acc=0.786076,    eval_loss=1.185552,    eval_acc=0.619023
# epoch:   5,    lr=0.000300,    loss=0.438565,    train_acc=0.829036,    eval_loss=1.276282,    eval_acc=0.617064
# Saving checkpoint ./model/CLDNN_cv3_step3_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.348368,    train_acc=0.866060,    eval_loss=1.541618,    eval_acc=0.620578
# epoch:   7,    lr=0.000300,    loss=0.291693,    train_acc=0.888977,    eval_loss=1.573533,    eval_acc=0.619253
# epoch:   8,    lr=0.000300,    loss=0.241088,    train_acc=0.909013,    eval_loss=1.649671,    eval_acc=0.617525
# epoch:   9,    lr=0.000300,    loss=0.206471,    train_acc=0.922674,    eval_loss=1.952673,    eval_acc=0.619657
# epoch:  10,    lr=0.000300,    loss=0.178618,    train_acc=0.932773,    eval_loss=2.049126,    eval_acc=0.612801
# Saving checkpoint ./model/CLDNN_cv3_step3_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.160473,    train_acc=0.940313,    eval_loss=1.903753,    eval_acc=0.604851
# epoch:  12,    lr=0.000300,    loss=0.140044,    train_acc=0.948231,    eval_loss=2.123794,    eval_acc=0.608307
# epoch:  13,    lr=0.000300,    loss=0.126931,    train_acc=0.952970,    eval_loss=2.266547,    eval_acc=0.615970
# epoch:  14,    lr=0.000300,    loss=0.118139,    train_acc=0.956669,    eval_loss=2.108441,    eval_acc=0.601049
# epoch:  15,    lr=0.000300,    loss=0.108839,    train_acc=0.960101,    eval_loss=2.359160,    eval_acc=0.611188
# Saving checkpoint ./model/CLDNN_cv3_step3_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.096977,    train_acc=0.964456,    eval_loss=2.389085,    eval_acc=0.611591
# epoch:  17,    lr=0.000300,    loss=0.089309,    train_acc=0.967152,    eval_loss=2.292566,    eval_acc=0.627895
# epoch:  18,    lr=0.000300,    loss=0.082073,    train_acc=0.969871,    eval_loss=2.499596,    eval_acc=0.609575
# epoch:  19,    lr=0.000300,    loss=0.077563,    train_acc=0.971749,    eval_loss=2.533480,    eval_acc=0.612859
# epoch:  20,    lr=0.000300,    loss=0.072329,    train_acc=0.974326,    eval_loss=2.383389,    eval_acc=0.618216
# Saving checkpoint ./model/CLDNN_cv3_step3_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.067201,    train_acc=0.975912,    eval_loss=2.456859,    eval_acc=0.620348
# epoch:  22,    lr=0.000300,    loss=0.064654,    train_acc=0.976897,    eval_loss=2.637548,    eval_acc=0.616430
# epoch:  23,    lr=0.000300,    loss=0.058835,    train_acc=0.979059,    eval_loss=2.581863,    eval_acc=0.603987
# epoch:  24,    lr=0.000300,    loss=0.057203,    train_acc=0.979889,    eval_loss=2.636342,    eval_acc=0.614068
# epoch:  25,    lr=0.000300,    loss=0.051404,    train_acc=0.981816,    eval_loss=2.868068,    eval_acc=0.611073
# Saving checkpoint ./model/CLDNN_cv3_step3_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.050858,    train_acc=0.982182,    eval_loss=2.730735,    eval_acc=0.613435
# epoch:  27,    lr=0.000300,    loss=0.049849,    train_acc=0.982764,    eval_loss=2.495326,    eval_acc=0.615509
# epoch:  28,    lr=0.000300,    loss=0.045904,    train_acc=0.984251,    eval_loss=2.637086,    eval_acc=0.630603
# epoch:  29,    lr=0.000300,    loss=0.042633,    train_acc=0.985273,    eval_loss=2.835585,    eval_acc=0.611476
# epoch:  30,    lr=0.000300,    loss=0.039549,    train_acc=0.986450,    eval_loss=2.750446,    eval_acc=0.619311
# Saving checkpoint ./model/CLDNN_cv3_step3_epoch30.pt
# Start training
# epoch:   1,    lr=0.000300,    loss=0.955254,    train_acc=0.590312,    eval_loss=0.968019,    eval_acc=0.600069
# epoch:   2,    lr=0.000300,    loss=0.790727,    train_acc=0.678548,    eval_loss=0.954556,    eval_acc=0.621270
# epoch:   3,    lr=0.000300,    loss=0.650719,    train_acc=0.741072,    eval_loss=0.999271,    eval_acc=0.620521
# epoch:   4,    lr=0.000300,    loss=0.522074,    train_acc=0.796039,    eval_loss=1.053637,    eval_acc=0.628298
# epoch:   5,    lr=0.000300,    loss=0.409138,    train_acc=0.842003,    eval_loss=1.230081,    eval_acc=0.618504
# Saving checkpoint ./model/CLDNN_cv3_step4_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.327801,    train_acc=0.873817,    eval_loss=1.395800,    eval_acc=0.612974
# epoch:   7,    lr=0.000300,    loss=0.263490,    train_acc=0.899131,    eval_loss=1.549886,    eval_acc=0.628471
# epoch:   8,    lr=0.000300,    loss=0.224580,    train_acc=0.914372,    eval_loss=1.859523,    eval_acc=0.583593
# epoch:   9,    lr=0.000300,    loss=0.188392,    train_acc=0.929328,    eval_loss=1.808017,    eval_acc=0.610785
# epoch:  10,    lr=0.000300,    loss=0.169093,    train_acc=0.936620,    eval_loss=2.047981,    eval_acc=0.608595
# Saving checkpoint ./model/CLDNN_cv3_step4_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.148304,    train_acc=0.945021,    eval_loss=1.973169,    eval_acc=0.625648
# epoch:  12,    lr=0.000300,    loss=0.130913,    train_acc=0.951409,    eval_loss=1.996854,    eval_acc=0.616085
# epoch:  13,    lr=0.000300,    loss=0.119555,    train_acc=0.955888,    eval_loss=2.246062,    eval_acc=0.612628
# epoch:  14,    lr=0.000300,    loss=0.108898,    train_acc=0.960312,    eval_loss=2.178525,    eval_acc=0.621270
# epoch:  15,    lr=0.000300,    loss=0.099478,    train_acc=0.963205,    eval_loss=2.098959,    eval_acc=0.623344
# Saving checkpoint ./model/CLDNN_cv3_step4_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.094688,    train_acc=0.964946,    eval_loss=2.308444,    eval_acc=0.611361
# epoch:  17,    lr=0.000300,    loss=0.083441,    train_acc=0.969816,    eval_loss=2.262674,    eval_acc=0.618274
# epoch:  18,    lr=0.000300,    loss=0.076971,    train_acc=0.971804,    eval_loss=2.470611,    eval_acc=0.627664
# epoch:  19,    lr=0.000300,    loss=0.076226,    train_acc=0.972381,    eval_loss=2.356485,    eval_acc=0.620175
# epoch:  20,    lr=0.000300,    loss=0.067176,    train_acc=0.975559,    eval_loss=2.529281,    eval_acc=0.614126
# Saving checkpoint ./model/CLDNN_cv3_step4_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.065229,    train_acc=0.976538,    eval_loss=2.422326,    eval_acc=0.606579
# epoch:  22,    lr=0.000300,    loss=0.060130,    train_acc=0.978911,    eval_loss=2.524462,    eval_acc=0.600357
# epoch:  23,    lr=0.000300,    loss=0.057216,    train_acc=0.979196,    eval_loss=2.818273,    eval_acc=0.597361
# epoch:  24,    lr=0.000300,    loss=0.053261,    train_acc=0.980899,    eval_loss=2.467653,    eval_acc=0.630718
# epoch:  25,    lr=0.000300,    loss=0.050991,    train_acc=0.981661,    eval_loss=2.508584,    eval_acc=0.605657
# Saving checkpoint ./model/CLDNN_cv3_step4_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.047624,    train_acc=0.983291,    eval_loss=2.662201,    eval_acc=0.604736
# epoch:  27,    lr=0.000300,    loss=0.048224,    train_acc=0.983229,    eval_loss=2.516456,    eval_acc=0.618216
# epoch:  28,    lr=0.000300,    loss=0.041437,    train_acc=0.985304,    eval_loss=2.597288,    eval_acc=0.612686
# epoch:  29,    lr=0.000300,    loss=0.042542,    train_acc=0.985131,    eval_loss=2.697282,    eval_acc=0.615105
# epoch:  30,    lr=0.000300,    loss=0.039475,    train_acc=0.986283,    eval_loss=2.553275,    eval_acc=0.609402
# Saving checkpoint ./model/CLDNN_cv3_step4_epoch30.pt
# Start training
# epoch:   1,    lr=0.000300,    loss=0.968293,    train_acc=0.582734,    eval_loss=0.946588,    eval_acc=0.604447
# epoch:   2,    lr=0.000300,    loss=0.807830,    train_acc=0.667389,    eval_loss=0.947884,    eval_acc=0.622191
# epoch:   3,    lr=0.000300,    loss=0.668832,    train_acc=0.731841,    eval_loss=1.007143,    eval_acc=0.612340
# epoch:   4,    lr=0.000300,    loss=0.541715,    train_acc=0.788424,    eval_loss=1.130135,    eval_acc=0.614933
# epoch:   5,    lr=0.000300,    loss=0.430955,    train_acc=0.832945,    eval_loss=1.349250,    eval_acc=0.597592
# Saving checkpoint ./model/CLDNN_cv3_step5_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.353834,    train_acc=0.863873,    eval_loss=1.307399,    eval_acc=0.618101
# epoch:   7,    lr=0.000300,    loss=0.289109,    train_acc=0.889727,    eval_loss=1.621950,    eval_acc=0.603699
# epoch:   8,    lr=0.000300,    loss=0.245118,    train_acc=0.907440,    eval_loss=1.775098,    eval_acc=0.581403
# epoch:   9,    lr=0.000300,    loss=0.210544,    train_acc=0.920896,    eval_loss=1.880065,    eval_acc=0.605139
# epoch:  10,    lr=0.000300,    loss=0.183999,    train_acc=0.930958,    eval_loss=1.816263,    eval_acc=0.622191
# Saving checkpoint ./model/CLDNN_cv3_step5_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.161539,    train_acc=0.940071,    eval_loss=1.944612,    eval_acc=0.605369
# epoch:  12,    lr=0.000300,    loss=0.146916,    train_acc=0.945275,    eval_loss=2.107877,    eval_acc=0.604620
# epoch:  13,    lr=0.000300,    loss=0.132826,    train_acc=0.951111,    eval_loss=2.038087,    eval_acc=0.606118
# epoch:  14,    lr=0.000300,    loss=0.120924,    train_acc=0.955603,    eval_loss=2.204106,    eval_acc=0.595345
# epoch:  15,    lr=0.000300,    loss=0.113366,    train_acc=0.958781,    eval_loss=2.156382,    eval_acc=0.613608
# Saving checkpoint ./model/CLDNN_cv3_step5_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.105232,    train_acc=0.961545,    eval_loss=2.250481,    eval_acc=0.605254
# epoch:  17,    lr=0.000300,    loss=0.093378,    train_acc=0.965869,    eval_loss=2.664492,    eval_acc=0.582268
# epoch:  18,    lr=0.000300,    loss=0.090421,    train_acc=0.966693,    eval_loss=2.266664,    eval_acc=0.610209
# epoch:  19,    lr=0.000300,    loss=0.084642,    train_acc=0.969456,    eval_loss=2.279340,    eval_acc=0.620924
# epoch:  20,    lr=0.000300,    loss=0.080031,    train_acc=0.971364,    eval_loss=2.492576,    eval_acc=0.606637
# Saving checkpoint ./model/CLDNN_cv3_step5_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.074307,    train_acc=0.973223,    eval_loss=2.304383,    eval_acc=0.598110
# epoch:  22,    lr=0.000300,    loss=0.069294,    train_acc=0.975286,    eval_loss=2.627570,    eval_acc=0.593732
# epoch:  23,    lr=0.000300,    loss=0.066250,    train_acc=0.976271,    eval_loss=2.558491,    eval_acc=0.600876
# epoch:  24,    lr=0.000300,    loss=0.062881,    train_acc=0.977399,    eval_loss=2.568673,    eval_acc=0.610093
# epoch:  25,    lr=0.000300,    loss=0.060488,    train_acc=0.978434,    eval_loss=2.418464,    eval_acc=0.607213
# Saving checkpoint ./model/CLDNN_cv3_step5_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.056245,    train_acc=0.979790,    eval_loss=2.614940,    eval_acc=0.588374
# epoch:  27,    lr=0.000300,    loss=0.053097,    train_acc=0.981042,    eval_loss=2.632477,    eval_acc=0.606867
# epoch:  28,    lr=0.000300,    loss=0.051822,    train_acc=0.981730,    eval_loss=2.742169,    eval_acc=0.609056
# epoch:  29,    lr=0.000300,    loss=0.047806,    train_acc=0.983024,    eval_loss=2.834101,    eval_acc=0.603641
# 14it [00:00, 133.03it/s]
# epoch:  30,    lr=0.000300,    loss=0.046094,    train_acc=0.983724,    eval_loss=2.680431,    eval_acc=0.612340
# Saving checkpoint ./model/CLDNN_cv3_step5_epoch30.pt
# 4480it [00:30, 148.49it/s]
# 498it [00:03, 159.37it/s]
# 553it [00:03, 159.70it/s]
# (162094, 40, 100, 1) (162094,) (17091, 40, 100, 1) (17091,) (19950, 40, 100, 1) (19950,)
# Start training
# epoch:   1,    lr=0.000300,    loss=0.978721,    train_acc=0.574318,    eval_loss=0.945522,    eval_acc=0.615061
# epoch:   2,    lr=0.000300,    loss=0.825190,    train_acc=0.655565,    eval_loss=1.013548,    eval_acc=0.606108
# epoch:   3,    lr=0.000300,    loss=0.693882,    train_acc=0.717016,    eval_loss=0.989829,    eval_acc=0.630741
# epoch:   4,    lr=0.000300,    loss=0.560266,    train_acc=0.777683,    eval_loss=1.120637,    eval_acc=0.612545
# epoch:   5,    lr=0.000300,    loss=0.445862,    train_acc=0.825823,    eval_loss=1.333178,    eval_acc=0.627465
# Saving checkpoint ./model/CLDNN_cv4_step1_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.359188,    train_acc=0.861887,    eval_loss=1.432594,    eval_acc=0.618571
# epoch:   7,    lr=0.000300,    loss=0.291919,    train_acc=0.888046,    eval_loss=1.439730,    eval_acc=0.620385
# epoch:   8,    lr=0.000300,    loss=0.245504,    train_acc=0.906719,    eval_loss=1.742240,    eval_acc=0.624890
# epoch:   9,    lr=0.000300,    loss=0.205305,    train_acc=0.923134,    eval_loss=1.735704,    eval_acc=0.621497
# epoch:  10,    lr=0.000300,    loss=0.179604,    train_acc=0.933199,    eval_loss=1.940265,    eval_acc=0.616757
# Saving checkpoint ./model/CLDNN_cv4_step1_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.159097,    train_acc=0.940709,    eval_loss=2.006604,    eval_acc=0.620561
# epoch:  12,    lr=0.000300,    loss=0.142493,    train_acc=0.946880,    eval_loss=2.146299,    eval_acc=0.605933
# epoch:  13,    lr=0.000300,    loss=0.127732,    train_acc=0.952088,    eval_loss=2.232347,    eval_acc=0.611725
# epoch:  14,    lr=0.000300,    loss=0.117722,    train_acc=0.956747,    eval_loss=2.248098,    eval_acc=0.618922
# epoch:  15,    lr=0.000300,    loss=0.107563,    train_acc=0.960530,    eval_loss=2.217389,    eval_acc=0.618688
# Saving checkpoint ./model/CLDNN_cv4_step1_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.098382,    train_acc=0.963801,    eval_loss=2.405141,    eval_acc=0.617459
# epoch:  17,    lr=0.000300,    loss=0.090539,    train_acc=0.966880,    eval_loss=2.544699,    eval_acc=0.599204
# epoch:  18,    lr=0.000300,    loss=0.085656,    train_acc=0.968806,    eval_loss=2.482920,    eval_acc=0.613890
# epoch:  19,    lr=0.000300,    loss=0.078005,    train_acc=0.971404,    eval_loss=2.491961,    eval_acc=0.622608
# epoch:  20,    lr=0.000300,    loss=0.076110,    train_acc=0.972724,    eval_loss=2.385840,    eval_acc=0.615763
# Saving checkpoint ./model/CLDNN_cv4_step1_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.067498,    train_acc=0.975359,    eval_loss=2.707187,    eval_acc=0.601603
# epoch:  22,    lr=0.000300,    loss=0.065578,    train_acc=0.976439,    eval_loss=2.529808,    eval_acc=0.618513
# epoch:  23,    lr=0.000300,    loss=0.061214,    train_acc=0.978457,    eval_loss=2.561289,    eval_acc=0.615587
# epoch:  24,    lr=0.000300,    loss=0.056059,    train_acc=0.979981,    eval_loss=2.888869,    eval_acc=0.611316
# epoch:  25,    lr=0.000300,    loss=0.057377,    train_acc=0.979673,    eval_loss=2.644237,    eval_acc=0.622257
# Saving checkpoint ./model/CLDNN_cv4_step1_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.051761,    train_acc=0.982092,    eval_loss=2.607731,    eval_acc=0.617635
# epoch:  27,    lr=0.000300,    loss=0.053100,    train_acc=0.981339,    eval_loss=2.494951,    eval_acc=0.621204
# epoch:  28,    lr=0.000300,    loss=0.046648,    train_acc=0.983394,    eval_loss=2.642195,    eval_acc=0.620034
# epoch:  29,    lr=0.000300,    loss=0.043115,    train_acc=0.985054,    eval_loss=2.839618,    eval_acc=0.602013
# epoch:  30,    lr=0.000300,    loss=0.044273,    train_acc=0.984523,    eval_loss=2.763204,    eval_acc=0.619215
# Saving checkpoint ./model/CLDNN_cv4_step1_epoch30.pt
# Start training
# epoch:   1,    lr=0.000300,    loss=0.975736,    train_acc=0.574589,    eval_loss=0.925854,    eval_acc=0.617576
# epoch:   2,    lr=0.000300,    loss=0.800925,    train_acc=0.669221,    eval_loss=0.951698,    eval_acc=0.635890
# epoch:   3,    lr=0.000300,    loss=0.656841,    train_acc=0.736930,    eval_loss=1.024967,    eval_acc=0.623311
# epoch:   4,    lr=0.000300,    loss=0.528794,    train_acc=0.793092,    eval_loss=1.117598,    eval_acc=0.625300
# epoch:   5,    lr=0.000300,    loss=0.423682,    train_acc=0.836437,    eval_loss=1.332358,    eval_acc=0.618454
# Saving checkpoint ./model/CLDNN_cv4_step2_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.339715,    train_acc=0.871193,    eval_loss=1.559205,    eval_acc=0.614475
# epoch:   7,    lr=0.000300,    loss=0.282506,    train_acc=0.893556,    eval_loss=1.696089,    eval_acc=0.600491
# epoch:   8,    lr=0.000300,    loss=0.234847,    train_acc=0.912051,    eval_loss=1.749622,    eval_acc=0.620912
# epoch:   9,    lr=0.000300,    loss=0.203439,    train_acc=0.923998,    eval_loss=1.943475,    eval_acc=0.606342
# epoch:  10,    lr=0.000300,    loss=0.175862,    train_acc=0.934643,    eval_loss=1.948343,    eval_acc=0.615821
# Saving checkpoint ./model/CLDNN_cv4_step2_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.158060,    train_acc=0.941474,    eval_loss=2.044713,    eval_acc=0.613656
# epoch:  12,    lr=0.000300,    loss=0.139945,    train_acc=0.948460,    eval_loss=2.410941,    eval_acc=0.596454
# epoch:  13,    lr=0.000300,    loss=0.129535,    train_acc=0.952020,    eval_loss=2.076373,    eval_acc=0.616172
# epoch:  14,    lr=0.000300,    loss=0.118683,    train_acc=0.956038,    eval_loss=2.164388,    eval_acc=0.603359
# epoch:  15,    lr=0.000300,    loss=0.107184,    train_acc=0.960765,    eval_loss=2.154508,    eval_acc=0.612077
# Saving checkpoint ./model/CLDNN_cv4_step2_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.099236,    train_acc=0.963480,    eval_loss=2.162947,    eval_acc=0.617401
# epoch:  17,    lr=0.000300,    loss=0.094658,    train_acc=0.965560,    eval_loss=2.336973,    eval_acc=0.624130
# epoch:  18,    lr=0.000300,    loss=0.089062,    train_acc=0.967775,    eval_loss=2.342293,    eval_acc=0.608858
# epoch:  19,    lr=0.000300,    loss=0.081668,    train_acc=0.970811,    eval_loss=2.222557,    eval_acc=0.619332
# epoch:  20,    lr=0.000300,    loss=0.077309,    train_acc=0.972132,    eval_loss=2.433148,    eval_acc=0.602247
# Saving checkpoint ./model/CLDNN_cv4_step2_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.069464,    train_acc=0.974847,    eval_loss=2.677351,    eval_acc=0.609853
# epoch:  22,    lr=0.000300,    loss=0.066058,    train_acc=0.976569,    eval_loss=2.532847,    eval_acc=0.609502
# epoch:  23,    lr=0.000300,    loss=0.063728,    train_acc=0.977297,    eval_loss=2.615424,    eval_acc=0.622140
# epoch:  24,    lr=0.000300,    loss=0.059821,    train_acc=0.978457,    eval_loss=2.692292,    eval_acc=0.599321
# epoch:  25,    lr=0.000300,    loss=0.054651,    train_acc=0.980975,    eval_loss=2.572232,    eval_acc=0.608975
# Saving checkpoint ./model/CLDNN_cv4_step2_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.055845,    train_acc=0.980568,    eval_loss=2.551893,    eval_acc=0.624539
# epoch:  27,    lr=0.000300,    loss=0.052318,    train_acc=0.981475,    eval_loss=2.464095,    eval_acc=0.618805
# epoch:  28,    lr=0.000300,    loss=0.048487,    train_acc=0.982752,    eval_loss=2.702811,    eval_acc=0.611316

# %%
focus_attn_list = [False]

# %%
for with_focus_attn in focus_attn_list:
    cv_eval = []
    cv_iter = 0
    #with_focus_attn = True if(with_focus_attn == 'true') else False
    for train_index, eval_index in skf.split(df['sample_name'], df['sample_label']):
        '''
    for ses_num in range(1, 6):
        eval_ses = 'Ses0' + str(ses_num)
        train_index = []
        eval_index = []
        for i, sample_name in enumerate(df['sample_name']):
            if eval_ses in sample_name:
                eval_index.append(i)
            else:
                train_index.append(i)
        '''
        cv_iter += 1
        conv_dim = '1d'
        checkpoint = ''
        hidden_size = 64
        num_layers = 2
        bidirectional = 'true'

        batch_size = 128
        num_epochs = 30
        learning_rate = 0.0003

        use_warmup = 'false'
        data_dir = './wav_data/pretrain/IEMOCAP_sub/'
        multi_task = 'false'
        augmentation = 'false'
        
        save_checkpoint_steps = 5
        output_dir = './without_fa'
        #label_path = './wav_data/pretrain/IEMOCAP_vad/'

        bidirectional = True if(bidirectional == 'true') else False  
        n_mfcc = 40 if(conv_dim == '1d') else 128

        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        
        train_samples, eval_samples = df['sample_name'][train_index], df['sample_name'][eval_index]
        train_label, eval_label = df['sample_label'][train_index], df['sample_label'][eval_index]
        #train_vad = [label_path + train_sample + '.npy' for train_sample in train_samples]
        #eval_vad = [label_path + eval_sample + '.npy' for eval_sample in eval_samples]
        
        train_samples = [data_dir + train_sample + '.wav' for train_sample in train_samples]
        eval_samples = [data_dir + eval_sample + '.wav' for eval_sample in eval_samples]

        y_train = np.array(train_label)
        y_eval = np.array(eval_label)
        
        #train_vad_list = []
        #for i in range(len(train_vad)):
        #    vad = np.load(train_vad[i])
        #    train_vad_list.append(vad)
        #vad_train = np.concatenate(train_vad_list)

        #eval_vad_list = []
        #for i in range(len(eval_vad)):
        #    vad = np.load(eval_vad[i])
        #    eval_vad_list.append(vad)
        #vad_eval = np.concatenate(eval_vad_list)

        if(multi_task == 'true'):
            speaker = np.array(list(map(lambda x: int(x.split('/')[-1].split('-')[-1].split('.')[0]), sample_datas)))
            y_gender = np.array(list(map(lambda x: 1 if x % 2 ==0 else 0, speaker)))

            y_g_train = y_gender[train_idx]
            y_g_eval = y_gender[eval_idx]

        X_train, y_train = convert_spectrograms(train_samples, conv_dim=conv_dim, sr=16000, labels=y_train)
        X_eval, y_eval = convert_spectrograms(eval_samples, conv_dim=conv_dim, sr=16000, labels=y_eval)
        print(X_train.shape, y_train.shape, X_eval.shape, y_eval.shape)
        
        #X_train = X_train[vad_train]
        #y_train = y_train[vad_train]
        #X_eval = X_eval[vad_eval]
        #y_eval = y_eval[vad_eval]
        #print(X_train.shape, y_train.shape, X_eval.shape, y_eval.shape)

        if(augmentation == 'true'):
            X_train_flip = X_train[:, :, :, ::-1]
            y_train_flip = y_train.copy()

            X_train = np.concatenate((X_train, X_train_flip), axis=0)
            y_train = np.concatenate((y_train, y_train_flip), axis=0)

        X_train, y_train = convert_tensor(X_train, y_train)
        X_eval, y_eval = convert_tensor(X_eval, y_eval)

        y_train = y_train.long()
        y_eval = y_eval.long()

        if(multi_task == 'true'):
            _, y_g_train = convert_spectrograms(train_samples, conv_dim=conv_dim, sr=16000, labels=y_g_train)
            _, y_g_eval = convert_spectrograms(eval_samples, conv_dim=conv_dim, sr=16000, labels=y_g_eval)

            if(augmentation == 'true'):
                y_g_train_flip = y_g_train.copy()
                y_g_train = np.concatenate((y_g_train, y_g_train_flip))

            y_g_train = torch.tensor(y_g_train).float()
            y_g_eval = torch.tensor(y_g_eval).float()

            y_g_train = y_g_train.unsqueeze(-1)
            y_g_eval = y_g_eval.unsqueeze(-1)

        if(multi_task == 'true'):
            train_ds = TensorDataset(X_train, y_train, y_g_train)
            eval_ds = TensorDataset(X_eval, y_eval, y_g_eval)
        else:
            train_ds = TensorDataset(X_train, y_train)
            eval_ds = TensorDataset(X_eval, y_eval)

        train_dataloader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=0, drop_last=True)
        eval_dataloader = DataLoader(eval_ds, batch_size=batch_size, num_workers=0)

        for en in range(2):
            model = CLDNN(conv_dim=conv_dim, checkpoint=checkpoint, hidden_size=hidden_size,
                          num_layers=num_layers, bidirectional=bidirectional,
                          with_focus_attn=with_focus_attn).to(device)

            if(multi_task == 'true'):
                model_g = CLDNN_G(conv_dim=conv_dim, checkpoint=checkpoint, hidden_size=hidden_size,
                                    num_layers=num_layers, bidirectional=bidirectional,
                                    with_focus_attn=with_focus_attn).to(device)

            if(multi_task == 'true'):
                loss_func = nn.CrossEntropyLoss()
                loss_func_g = nn.BCELoss()
                optimizer = optim.Adam(list(model.parameters()) + list(model_g.parameters()), lr=learning_rate)
            else:
                loss_func = nn.CrossEntropyLoss()
                optimizer = optim.Adam(model.parameters(), lr=learning_rate)

            if(use_warmup == 'true'):
                t_total = len(train_dataloader) // 1 * num_epochs
                opt_scheduler = WarmupLinearSchedule(optimizer, warmup_steps=t_total * 0.1, t_total=t_total)

            eval_acc = train(train_dataloader, eval_dataloader, num_epochs)
            cv_eval.append(eval_acc)

    print('conv_dim:', conv_dim, '\twith_focus_attn:', with_focus_attn)
    print('Test accuray:', cv_eval)
    print()
# Out:
# 4041it [00:29, 134.73it/s]
# 449it [00:03, 115.23it/s]
# (163254, 40, 50, 1) (163254,) (18406, 40, 50, 1) (18406,)
# Start training
# epoch:   1,    lr=0.000300,    loss=0.958399,    train_acc=0.608248,    eval_loss=0.885174,    eval_acc=0.621156
# epoch:   2,    lr=0.000300,    loss=0.866098,    train_acc=0.652151,    eval_loss=0.863214,    eval_acc=0.633706
# epoch:   3,    lr=0.000300,    loss=0.805395,    train_acc=0.681691,    eval_loss=0.919529,    eval_acc=0.614202
# epoch:   4,    lr=0.000300,    loss=0.750803,    train_acc=0.704289,    eval_loss=0.906092,    eval_acc=0.638542
# epoch:   5,    lr=0.000300,    loss=0.692407,    train_acc=0.727739,    eval_loss=0.979317,    eval_acc=0.619092
# Saving checkpoint ./without_fa/CLDNN_cv1_step1_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.633242,    train_acc=0.751605,    eval_loss=0.987517,    eval_acc=0.628925
# epoch:   7,    lr=0.000300,    loss=0.580896,    train_acc=0.772935,    eval_loss=1.104126,    eval_acc=0.606270
# epoch:   8,    lr=0.000300,    loss=0.530665,    train_acc=0.793946,    eval_loss=1.137030,    eval_acc=0.621373
# epoch:   9,    lr=0.000300,    loss=0.484462,    train_acc=0.811189,    eval_loss=1.273203,    eval_acc=0.596490
# epoch:  10,    lr=0.000300,    loss=0.443164,    train_acc=0.828039,    eval_loss=1.325611,    eval_acc=0.581224
# Saving checkpoint ./without_fa/CLDNN_cv1_step1_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.405934,    train_acc=0.842947,    eval_loss=1.360718,    eval_acc=0.610453
# epoch:  12,    lr=0.000300,    loss=0.373332,    train_acc=0.855876,    eval_loss=1.419891,    eval_acc=0.584809
# epoch:  13,    lr=0.000300,    loss=0.348246,    train_acc=0.865202,    eval_loss=1.589132,    eval_acc=0.566609
# epoch:  14,    lr=0.000300,    loss=0.319622,    train_acc=0.877721,    eval_loss=1.565850,    eval_acc=0.601108
# epoch:  15,    lr=0.000300,    loss=0.297561,    train_acc=0.885300,    eval_loss=1.834168,    eval_acc=0.590949
# Saving checkpoint ./without_fa/CLDNN_cv1_step1_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.278248,    train_acc=0.893168,    eval_loss=1.832444,    eval_acc=0.580843
# epoch:  17,    lr=0.000300,    loss=0.262070,    train_acc=0.900288,    eval_loss=1.701753,    eval_acc=0.582799
# epoch:  18,    lr=0.000300,    loss=0.244543,    train_acc=0.906183,    eval_loss=1.848215,    eval_acc=0.579865
# epoch:  19,    lr=0.000300,    loss=0.230426,    train_acc=0.911930,    eval_loss=1.913139,    eval_acc=0.581550
# epoch:  20,    lr=0.000300,    loss=0.215327,    train_acc=0.918058,    eval_loss=2.469770,    eval_acc=0.563023
# Saving checkpoint ./without_fa/CLDNN_cv1_step1_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.204777,    train_acc=0.921556,    eval_loss=1.982884,    eval_acc=0.576768
# epoch:  22,    lr=0.000300,    loss=0.194360,    train_acc=0.926397,    eval_loss=2.130609,    eval_acc=0.561773
# epoch:  23,    lr=0.000300,    loss=0.184168,    train_acc=0.929982,    eval_loss=2.196637,    eval_acc=0.575465
# epoch:  24,    lr=0.000300,    loss=0.173404,    train_acc=0.935276,    eval_loss=2.266997,    eval_acc=0.581115
# epoch:  25,    lr=0.000300,    loss=0.166652,    train_acc=0.937065,    eval_loss=2.177789,    eval_acc=0.580572
# Saving checkpoint ./without_fa/CLDNN_cv1_step1_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.155290,    train_acc=0.941556,    eval_loss=2.388392,    eval_acc=0.572476
# epoch:  27,    lr=0.000300,    loss=0.150096,    train_acc=0.942782,    eval_loss=2.497455,    eval_acc=0.571498
# epoch:  28,    lr=0.000300,    loss=0.140425,    train_acc=0.947451,    eval_loss=2.404615,    eval_acc=0.583777
# epoch:  29,    lr=0.000300,    loss=0.135151,    train_acc=0.949424,    eval_loss=2.381793,    eval_acc=0.577909
# epoch:  30,    lr=0.000300,    loss=0.127364,    train_acc=0.952298,    eval_loss=2.485847,    eval_acc=0.595893
# Saving checkpoint ./without_fa/CLDNN_cv1_step1_epoch30.pt
# Start training
# epoch:   1,    lr=0.000300,    loss=0.967196,    train_acc=0.603272,    eval_loss=0.934164,    eval_acc=0.598935
# epoch:   2,    lr=0.000300,    loss=0.875134,    train_acc=0.649498,    eval_loss=0.903454,    eval_acc=0.609693
# epoch:   3,    lr=0.000300,    loss=0.816259,    train_acc=0.675600,    eval_loss=0.911086,    eval_acc=0.630066
# epoch:   4,    lr=0.000300,    loss=0.760450,    train_acc=0.698266,    eval_loss=0.872905,    eval_acc=0.637075
# epoch:   5,    lr=0.000300,    loss=0.704567,    train_acc=0.722457,    eval_loss=0.925142,    eval_acc=0.629360
# Saving checkpoint ./without_fa/CLDNN_cv1_step2_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.650940,    train_acc=0.743971,    eval_loss=1.020494,    eval_acc=0.597142
# epoch:   7,    lr=0.000300,    loss=0.591781,    train_acc=0.767690,    eval_loss=1.060224,    eval_acc=0.607411
# epoch:   8,    lr=0.000300,    loss=0.540860,    train_acc=0.788768,    eval_loss=1.058349,    eval_acc=0.623873
# epoch:   9,    lr=0.000300,    loss=0.493522,    train_acc=0.807089,    eval_loss=1.128897,    eval_acc=0.618114
# epoch:  10,    lr=0.000300,    loss=0.451256,    train_acc=0.824638,    eval_loss=1.290165,    eval_acc=0.608878
# Saving checkpoint ./without_fa/CLDNN_cv1_step2_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.416418,    train_acc=0.837794,    eval_loss=1.394902,    eval_acc=0.598283
# epoch:  12,    lr=0.000300,    loss=0.384169,    train_acc=0.850680,    eval_loss=1.395046,    eval_acc=0.592959
# epoch:  13,    lr=0.000300,    loss=0.354628,    train_acc=0.862874,    eval_loss=1.479939,    eval_acc=0.597849
# epoch:  14,    lr=0.000300,    loss=0.327614,    train_acc=0.873750,    eval_loss=1.584042,    eval_acc=0.608823
# epoch:  15,    lr=0.000300,    loss=0.303701,    train_acc=0.883113,    eval_loss=1.666681,    eval_acc=0.591709
# Saving checkpoint ./without_fa/CLDNN_cv1_step2_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.281539,    train_acc=0.892365,    eval_loss=1.707758,    eval_acc=0.582690
# epoch:  17,    lr=0.000300,    loss=0.264614,    train_acc=0.897800,    eval_loss=1.690963,    eval_acc=0.601760
# epoch:  18,    lr=0.000300,    loss=0.245826,    train_acc=0.905784,    eval_loss=1.727766,    eval_acc=0.590677
# epoch:  19,    lr=0.000300,    loss=0.232787,    train_acc=0.910809,    eval_loss=1.924740,    eval_acc=0.581006
# epoch:  20,    lr=0.000300,    loss=0.218011,    train_acc=0.917960,    eval_loss=1.923178,    eval_acc=0.585570
# Saving checkpoint ./without_fa/CLDNN_cv1_step2_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.205781,    train_acc=0.922279,    eval_loss=2.159206,    eval_acc=0.568184
# epoch:  22,    lr=0.000300,    loss=0.199049,    train_acc=0.924694,    eval_loss=1.919015,    eval_acc=0.584212
# epoch:  23,    lr=0.000300,    loss=0.180226,    train_acc=0.931513,    eval_loss=2.061234,    eval_acc=0.592850
# epoch:  24,    lr=0.000300,    loss=0.177660,    train_acc=0.932947,    eval_loss=2.077778,    eval_acc=0.591383
# epoch:  25,    lr=0.000300,    loss=0.164711,    train_acc=0.937610,    eval_loss=2.263458,    eval_acc=0.581278
# Saving checkpoint ./without_fa/CLDNN_cv1_step2_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.156374,    train_acc=0.941115,    eval_loss=2.310950,    eval_acc=0.590568
# epoch:  27,    lr=0.000300,    loss=0.148189,    train_acc=0.944314,    eval_loss=2.184623,    eval_acc=0.571987
# epoch:  28,    lr=0.000300,    loss=0.139344,    train_acc=0.948162,    eval_loss=2.289561,    eval_acc=0.583397
# epoch:  29,    lr=0.000300,    loss=0.132554,    train_acc=0.950086,    eval_loss=2.271083,    eval_acc=0.583994
# 13it [00:00, 127.98it/s]
# epoch:  30,    lr=0.000300,    loss=0.126366,    train_acc=0.953217,    eval_loss=2.438709,    eval_acc=0.586982
# Saving checkpoint ./without_fa/CLDNN_cv1_step2_epoch30.pt
# 4041it [00:27, 149.25it/s]
# 449it [00:04, 109.34it/s]
# (162195, 40, 50, 1) (162195,) (19465, 40, 50, 1) (19465,)
# Start training
# epoch:   1,    lr=0.000300,    loss=0.963145,    train_acc=0.603585,    eval_loss=1.011702,    eval_acc=0.596866
# epoch:   2,    lr=0.000300,    loss=0.867618,    train_acc=0.649998,    eval_loss=1.030117,    eval_acc=0.587824
# epoch:   3,    lr=0.000300,    loss=0.813730,    train_acc=0.676623,    eval_loss=0.992731,    eval_acc=0.616748
# epoch:   4,    lr=0.000300,    loss=0.761384,    train_acc=0.698667,    eval_loss=1.088680,    eval_acc=0.603545
# epoch:   5,    lr=0.000300,    loss=0.710600,    train_acc=0.721124,    eval_loss=1.135838,    eval_acc=0.611611
# Saving checkpoint ./without_fa/CLDNN_cv2_step1_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.655848,    train_acc=0.743008,    eval_loss=1.143851,    eval_acc=0.606165
# epoch:   7,    lr=0.000300,    loss=0.603269,    train_acc=0.764373,    eval_loss=1.166253,    eval_acc=0.615412
# epoch:   8,    lr=0.000300,    loss=0.555519,    train_acc=0.782970,    eval_loss=1.321497,    eval_acc=0.593784
# epoch:   9,    lr=0.000300,    loss=0.509198,    train_acc=0.801302,    eval_loss=1.434927,    eval_acc=0.601849
# epoch:  10,    lr=0.000300,    loss=0.466834,    train_acc=0.818006,    eval_loss=1.610187,    eval_acc=0.594349
# Saving checkpoint ./without_fa/CLDNN_cv2_step1_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.429511,    train_acc=0.833200,    eval_loss=1.694508,    eval_acc=0.580118
# epoch:  12,    lr=0.000300,    loss=0.395975,    train_acc=0.845742,    eval_loss=1.670074,    eval_acc=0.583201
# epoch:  13,    lr=0.000300,    loss=0.364060,    train_acc=0.859387,    eval_loss=1.878788,    eval_acc=0.568251
# epoch:  14,    lr=0.000300,    loss=0.337620,    train_acc=0.869598,    eval_loss=2.124141,    eval_acc=0.558284
# epoch:  15,    lr=0.000300,    loss=0.312285,    train_acc=0.879828,    eval_loss=2.027263,    eval_acc=0.568662
# Saving checkpoint ./without_fa/CLDNN_cv2_step1_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.294123,    train_acc=0.886407,    eval_loss=2.120266,    eval_acc=0.571744
# epoch:  17,    lr=0.000300,    loss=0.276053,    train_acc=0.894207,    eval_loss=2.207439,    eval_acc=0.566555
# epoch:  18,    lr=0.000300,    loss=0.256034,    train_acc=0.902137,    eval_loss=2.375121,    eval_acc=0.574210
# epoch:  19,    lr=0.000300,    loss=0.241042,    train_acc=0.907292,    eval_loss=2.498475,    eval_acc=0.565579
# epoch:  20,    lr=0.000300,    loss=0.225975,    train_acc=0.914192,    eval_loss=2.436976,    eval_acc=0.566812
# Saving checkpoint ./without_fa/CLDNN_cv2_step1_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.211958,    train_acc=0.919446,    eval_loss=2.535311,    eval_acc=0.575238
# epoch:  22,    lr=0.000300,    loss=0.201137,    train_acc=0.923386,    eval_loss=2.577631,    eval_acc=0.566093
# epoch:  23,    lr=0.000300,    loss=0.189317,    train_acc=0.928090,    eval_loss=2.579861,    eval_acc=0.566607
# epoch:  24,    lr=0.000300,    loss=0.179517,    train_acc=0.931846,    eval_loss=2.721060,    eval_acc=0.537889
# epoch:  25,    lr=0.000300,    loss=0.170437,    train_acc=0.935773,    eval_loss=2.397224,    eval_acc=0.564603
# Saving checkpoint ./without_fa/CLDNN_cv2_step1_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.160713,    train_acc=0.939467,    eval_loss=2.771883,    eval_acc=0.568508
# epoch:  27,    lr=0.000300,    loss=0.152929,    train_acc=0.942784,    eval_loss=2.815704,    eval_acc=0.575905
# epoch:  28,    lr=0.000300,    loss=0.145854,    train_acc=0.945423,    eval_loss=2.832403,    eval_acc=0.561829
# epoch:  29,    lr=0.000300,    loss=0.136067,    train_acc=0.948661,    eval_loss=2.986735,    eval_acc=0.548369
# epoch:  30,    lr=0.000300,    loss=0.130804,    train_acc=0.950899,    eval_loss=3.050033,    eval_acc=0.563678
# Saving checkpoint ./without_fa/CLDNN_cv2_step1_epoch30.pt
# Start training
# epoch:   1,    lr=0.000300,    loss=0.961764,    train_acc=0.606428,    eval_loss=0.972132,    eval_acc=0.611662
# epoch:   2,    lr=0.000300,    loss=0.868673,    train_acc=0.650497,    eval_loss=0.947429,    eval_acc=0.612535
# epoch:   3,    lr=0.000300,    loss=0.806328,    train_acc=0.678886,    eval_loss=0.979461,    eval_acc=0.608374
# epoch:   4,    lr=0.000300,    loss=0.749712,    train_acc=0.702410,    eval_loss=1.018251,    eval_acc=0.620190
# epoch:   5,    lr=0.000300,    loss=0.688897,    train_acc=0.727605,    eval_loss=1.150723,    eval_acc=0.596301
# Saving checkpoint ./without_fa/CLDNN_cv2_step2_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.633889,    train_acc=0.749229,    eval_loss=1.239539,    eval_acc=0.600051
# epoch:   7,    lr=0.000300,    loss=0.578443,    train_acc=0.772587,    eval_loss=1.294629,    eval_acc=0.605343
# epoch:   8,    lr=0.000300,    loss=0.528001,    train_acc=0.790616,    eval_loss=1.397878,    eval_acc=0.589622
# epoch:   9,    lr=0.000300,    loss=0.484127,    train_acc=0.809016,    eval_loss=1.577871,    eval_acc=0.607141
# epoch:  10,    lr=0.000300,    loss=0.444822,    train_acc=0.824900,    eval_loss=1.657958,    eval_acc=0.594195
# Saving checkpoint ./without_fa/CLDNN_cv2_step2_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.414137,    train_acc=0.837350,    eval_loss=1.835155,    eval_acc=0.577909
# epoch:  12,    lr=0.000300,    loss=0.378642,    train_acc=0.852518,    eval_loss=1.768947,    eval_acc=0.604470
# epoch:  13,    lr=0.000300,    loss=0.347734,    train_acc=0.864832,    eval_loss=2.074786,    eval_acc=0.551914
# epoch:  14,    lr=0.000300,    loss=0.321713,    train_acc=0.874439,    eval_loss=2.045170,    eval_acc=0.582379
# epoch:  15,    lr=0.000300,    loss=0.299638,    train_acc=0.883158,    eval_loss=2.136688,    eval_acc=0.561726
# Saving checkpoint ./without_fa/CLDNN_cv2_step2_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.280026,    train_acc=0.891494,    eval_loss=2.302907,    eval_acc=0.561161
# epoch:  17,    lr=0.000300,    loss=0.261242,    train_acc=0.898727,    eval_loss=2.270664,    eval_acc=0.577241
# epoch:  18,    lr=0.000300,    loss=0.242512,    train_acc=0.906324,    eval_loss=2.438539,    eval_acc=0.567480
# epoch:  19,    lr=0.000300,    loss=0.228200,    train_acc=0.912194,    eval_loss=2.555482,    eval_acc=0.570408
# epoch:  20,    lr=0.000300,    loss=0.215460,    train_acc=0.917405,    eval_loss=2.673861,    eval_acc=0.538865
# Saving checkpoint ./without_fa/CLDNN_cv2_step2_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.203515,    train_acc=0.922325,    eval_loss=2.583641,    eval_acc=0.557822
# epoch:  22,    lr=0.000300,    loss=0.192928,    train_acc=0.926987,    eval_loss=2.630580,    eval_acc=0.550886
# epoch:  23,    lr=0.000300,    loss=0.183842,    train_acc=0.930156,    eval_loss=2.706163,    eval_acc=0.565887
# epoch:  24,    lr=0.000300,    loss=0.172151,    train_acc=0.933677,    eval_loss=3.204630,    eval_acc=0.550424
# epoch:  25,    lr=0.000300,    loss=0.165432,    train_acc=0.937315,    eval_loss=2.985513,    eval_acc=0.557411
# Saving checkpoint ./without_fa/CLDNN_cv2_step2_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.156096,    train_acc=0.941243,    eval_loss=2.810883,    eval_acc=0.566453
# epoch:  27,    lr=0.000300,    loss=0.150055,    train_acc=0.943481,    eval_loss=2.829345,    eval_acc=0.561058
# epoch:  28,    lr=0.000300,    loss=0.139356,    train_acc=0.947773,    eval_loss=3.055417,    eval_acc=0.557513
# epoch:  29,    lr=0.000300,    loss=0.131383,    train_acc=0.950535,    eval_loss=3.208643,    eval_acc=0.560904
# 11it [00:00, 101.82it/s]
# epoch:  30,    lr=0.000300,    loss=0.127112,    train_acc=0.952545,    eval_loss=3.079246,    eval_acc=0.552068
# Saving checkpoint ./without_fa/CLDNN_cv2_step2_epoch30.pt
# 4041it [00:27, 147.67it/s]
# 449it [00:03, 145.05it/s]
# (162222, 40, 50, 1) (162222,) (19438, 40, 50, 1) (19438,)
# Start training
# epoch:   1,    lr=0.000300,    loss=0.955991,    train_acc=0.608536,    eval_loss=1.070088,    eval_acc=0.569040
# epoch:   2,    lr=0.000300,    loss=0.862909,    train_acc=0.653099,    eval_loss=1.018291,    eval_acc=0.586789
# epoch:   3,    lr=0.000300,    loss=0.801538,    train_acc=0.680360,    eval_loss=1.099531,    eval_acc=0.568063
# epoch:   4,    lr=0.000300,    loss=0.747105,    train_acc=0.704149,    eval_loss=1.159921,    eval_acc=0.559831
# epoch:   5,    lr=0.000300,    loss=0.689680,    train_acc=0.727531,    eval_loss=1.344985,    eval_acc=0.548873
# Saving checkpoint ./without_fa/CLDNN_cv3_step1_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.635084,    train_acc=0.749427,    eval_loss=1.257525,    eval_acc=0.553812
# epoch:   7,    lr=0.000300,    loss=0.583071,    train_acc=0.770724,    eval_loss=1.439722,    eval_acc=0.562661
# epoch:   8,    lr=0.000300,    loss=0.532597,    train_acc=0.790302,    eval_loss=1.516653,    eval_acc=0.562969
# epoch:   9,    lr=0.000300,    loss=0.487737,    train_acc=0.807857,    eval_loss=1.720787,    eval_acc=0.536784
# epoch:  10,    lr=0.000300,    loss=0.445720,    train_acc=0.826633,    eval_loss=1.708619,    eval_acc=0.547381
# Saving checkpoint ./without_fa/CLDNN_cv3_step1_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.408964,    train_acc=0.840809,    eval_loss=1.905598,    eval_acc=0.554995
# epoch:  12,    lr=0.000300,    loss=0.381014,    train_acc=0.851969,    eval_loss=1.998099,    eval_acc=0.537298
# epoch:  13,    lr=0.000300,    loss=0.355245,    train_acc=0.862187,    eval_loss=2.107663,    eval_acc=0.550828
# epoch:  14,    lr=0.000300,    loss=0.326253,    train_acc=0.873532,    eval_loss=2.142548,    eval_acc=0.548668
# epoch:  15,    lr=0.000300,    loss=0.306900,    train_acc=0.881672,    eval_loss=2.331025,    eval_acc=0.524900
# Saving checkpoint ./without_fa/CLDNN_cv3_step1_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.282752,    train_acc=0.890835,    eval_loss=2.613911,    eval_acc=0.528038
# epoch:  17,    lr=0.000300,    loss=0.267267,    train_acc=0.897537,    eval_loss=2.557689,    eval_acc=0.521453
# epoch:  18,    lr=0.000300,    loss=0.249701,    train_acc=0.904326,    eval_loss=2.515914,    eval_acc=0.521093
# epoch:  19,    lr=0.000300,    loss=0.232946,    train_acc=0.910591,    eval_loss=2.978130,    eval_acc=0.524848
# epoch:  20,    lr=0.000300,    loss=0.221760,    train_acc=0.915086,    eval_loss=2.929284,    eval_acc=0.532051
# Saving checkpoint ./without_fa/CLDNN_cv3_step1_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.210067,    train_acc=0.919723,    eval_loss=2.924511,    eval_acc=0.512295
# epoch:  22,    lr=0.000300,    loss=0.197231,    train_acc=0.924890,    eval_loss=3.126677,    eval_acc=0.519035
# epoch:  23,    lr=0.000300,    loss=0.186708,    train_acc=0.928189,    eval_loss=3.020649,    eval_acc=0.525929
# epoch:  24,    lr=0.000300,    loss=0.177388,    train_acc=0.931876,    eval_loss=3.082798,    eval_acc=0.528192
# epoch:  25,    lr=0.000300,    loss=0.168246,    train_acc=0.935878,    eval_loss=3.354085,    eval_acc=0.541568
# Saving checkpoint ./without_fa/CLDNN_cv3_step1_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.162842,    train_acc=0.937710,    eval_loss=3.028264,    eval_acc=0.528295
# epoch:  27,    lr=0.000300,    loss=0.151142,    train_acc=0.942088,    eval_loss=3.124121,    eval_acc=0.522585
# epoch:  28,    lr=0.000300,    loss=0.145793,    train_acc=0.945041,    eval_loss=3.242506,    eval_acc=0.534520
# epoch:  29,    lr=0.000300,    loss=0.136425,    train_acc=0.948618,    eval_loss=3.560952,    eval_acc=0.520578
# epoch:  30,    lr=0.000300,    loss=0.129745,    train_acc=0.951331,    eval_loss=3.374059,    eval_acc=0.534520
# Saving checkpoint ./without_fa/CLDNN_cv3_step1_epoch30.pt
# Start training
# epoch:   1,    lr=0.000300,    loss=0.956458,    train_acc=0.609097,    eval_loss=1.078577,    eval_acc=0.556487
# epoch:   2,    lr=0.000300,    loss=0.864354,    train_acc=0.654117,    eval_loss=1.021836,    eval_acc=0.578094
# epoch:   3,    lr=0.000300,    loss=0.806522,    train_acc=0.679108,    eval_loss=1.064464,    eval_acc=0.571509
# epoch:   4,    lr=0.000300,    loss=0.752752,    train_acc=0.701602,    eval_loss=1.182460,    eval_acc=0.568474
# epoch:   5,    lr=0.000300,    loss=0.697588,    train_acc=0.725224,    eval_loss=1.237425,    eval_acc=0.541362
# Saving checkpoint ./without_fa/CLDNN_cv3_step2_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.642179,    train_acc=0.747268,    eval_loss=1.242908,    eval_acc=0.588898
# epoch:   7,    lr=0.000300,    loss=0.591115,    train_acc=0.767382,    eval_loss=1.490704,    eval_acc=0.570429
# epoch:   8,    lr=0.000300,    loss=0.539524,    train_acc=0.788859,    eval_loss=1.389438,    eval_acc=0.558802
# epoch:   9,    lr=0.000300,    loss=0.494088,    train_acc=0.806457,    eval_loss=1.630957,    eval_acc=0.573619
# epoch:  10,    lr=0.000300,    loss=0.449154,    train_acc=0.824283,    eval_loss=1.678625,    eval_acc=0.532308
# Saving checkpoint ./without_fa/CLDNN_cv3_step2_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.408060,    train_acc=0.842202,    eval_loss=1.989131,    eval_acc=0.556282
# epoch:  12,    lr=0.000300,    loss=0.378630,    train_acc=0.853647,    eval_loss=1.972120,    eval_acc=0.559523
# epoch:  13,    lr=0.000300,    loss=0.345711,    train_acc=0.865930,    eval_loss=2.113517,    eval_acc=0.567548
# epoch:  14,    lr=0.000300,    loss=0.318253,    train_acc=0.877109,    eval_loss=2.103820,    eval_acc=0.553040
# epoch:  15,    lr=0.000300,    loss=0.294963,    train_acc=0.886198,    eval_loss=2.317332,    eval_acc=0.553092
# Saving checkpoint ./without_fa/CLDNN_cv3_step2_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.274590,    train_acc=0.895188,    eval_loss=2.269202,    eval_acc=0.545169
# epoch:  17,    lr=0.000300,    loss=0.256925,    train_acc=0.901773,    eval_loss=2.477375,    eval_acc=0.549388
# epoch:  18,    lr=0.000300,    loss=0.237514,    train_acc=0.909062,    eval_loss=2.589384,    eval_acc=0.545118
# epoch:  19,    lr=0.000300,    loss=0.221926,    train_acc=0.915148,    eval_loss=2.749193,    eval_acc=0.532462
# epoch:  20,    lr=0.000300,    loss=0.209237,    train_acc=0.920321,    eval_loss=2.661900,    eval_acc=0.543832
# Saving checkpoint ./without_fa/CLDNN_cv3_step2_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.197814,    train_acc=0.925211,    eval_loss=2.707922,    eval_acc=0.542237
# epoch:  22,    lr=0.000300,    loss=0.185056,    train_acc=0.930181,    eval_loss=2.878858,    eval_acc=0.528552
# epoch:  23,    lr=0.000300,    loss=0.171658,    train_acc=0.935114,    eval_loss=2.941924,    eval_acc=0.542237
# epoch:  24,    lr=0.000300,    loss=0.162834,    train_acc=0.938813,    eval_loss=3.055964,    eval_acc=0.539767
# epoch:  25,    lr=0.000300,    loss=0.154681,    train_acc=0.942310,    eval_loss=3.179458,    eval_acc=0.532617
# Saving checkpoint ./without_fa/CLDNN_cv3_step2_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.145775,    train_acc=0.944782,    eval_loss=3.138960,    eval_acc=0.540488
# epoch:  27,    lr=0.000300,    loss=0.138785,    train_acc=0.948260,    eval_loss=3.084289,    eval_acc=0.552680
# epoch:  28,    lr=0.000300,    loss=0.130653,    train_acc=0.951639,    eval_loss=3.334645,    eval_acc=0.534314
# epoch:  29,    lr=0.000300,    loss=0.123058,    train_acc=0.954192,    eval_loss=3.357846,    eval_acc=0.509312
# 5it [00:00, 45.24it/s]
# epoch:  30,    lr=0.000300,    loss=0.118115,    train_acc=0.956381,    eval_loss=3.483854,    eval_acc=0.552732
# Saving checkpoint ./without_fa/CLDNN_cv3_step2_epoch30.pt
# 4041it [00:48, 83.77it/s]
# 449it [00:03, 140.86it/s]
# (163779, 40, 50, 1) (163779,) (17881, 40, 50, 1) (17881,)
# Start training
# epoch:   1,    lr=0.000300,    loss=0.968213,    train_acc=0.598044,    eval_loss=0.841609,    eval_acc=0.691684
# epoch:   2,    lr=0.000300,    loss=0.876354,    train_acc=0.643685,    eval_loss=0.896241,    eval_acc=0.651530
# epoch:   3,    lr=0.000300,    loss=0.814743,    train_acc=0.672920,    eval_loss=0.883939,    eval_acc=0.669649
# epoch:   4,    lr=0.000300,    loss=0.757723,    train_acc=0.697640,    eval_loss=0.937736,    eval_acc=0.664113
# epoch:   5,    lr=0.000300,    loss=0.697745,    train_acc=0.723105,    eval_loss=0.990314,    eval_acc=0.650858
# Saving checkpoint ./without_fa/CLDNN_cv4_step1_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.639346,    train_acc=0.746928,    eval_loss=1.045377,    eval_acc=0.625468
# epoch:   7,    lr=0.000300,    loss=0.580890,    train_acc=0.772002,    eval_loss=1.125401,    eval_acc=0.618422
# epoch:   8,    lr=0.000300,    loss=0.528184,    train_acc=0.792019,    eval_loss=1.207822,    eval_acc=0.625636
# epoch:   9,    lr=0.000300,    loss=0.482586,    train_acc=0.810497,    eval_loss=1.307057,    eval_acc=0.632515
# epoch:  10,    lr=0.000300,    loss=0.441815,    train_acc=0.826048,    eval_loss=1.455407,    eval_acc=0.609753
# Saving checkpoint ./without_fa/CLDNN_cv4_step1_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.406349,    train_acc=0.840800,    eval_loss=1.521059,    eval_acc=0.602315
# epoch:  12,    lr=0.000300,    loss=0.375688,    train_acc=0.854159,    eval_loss=1.558350,    eval_acc=0.601532
# epoch:  13,    lr=0.000300,    loss=0.343925,    train_acc=0.866742,    eval_loss=1.870218,    eval_acc=0.580225
# epoch:  14,    lr=0.000300,    loss=0.320885,    train_acc=0.875421,    eval_loss=1.810412,    eval_acc=0.597841
# epoch:  15,    lr=0.000300,    loss=0.297093,    train_acc=0.884553,    eval_loss=1.884672,    eval_acc=0.591578
# Saving checkpoint ./without_fa/CLDNN_cv4_step1_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.277106,    train_acc=0.893203,    eval_loss=1.926362,    eval_acc=0.603713
# epoch:  17,    lr=0.000300,    loss=0.258984,    train_acc=0.900093,    eval_loss=2.069127,    eval_acc=0.612046
# epoch:  18,    lr=0.000300,    loss=0.244284,    train_acc=0.905835,    eval_loss=2.063749,    eval_acc=0.600470
# epoch:  19,    lr=0.000300,    loss=0.231060,    train_acc=0.910391,    eval_loss=2.374131,    eval_acc=0.554947
# epoch:  20,    lr=0.000300,    loss=0.214393,    train_acc=0.917294,    eval_loss=2.323943,    eval_acc=0.567026
# Saving checkpoint ./without_fa/CLDNN_cv4_step1_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.202401,    train_acc=0.922663,    eval_loss=2.245792,    eval_acc=0.600805
# epoch:  22,    lr=0.000300,    loss=0.192167,    train_acc=0.926151,    eval_loss=2.347437,    eval_acc=0.595716
# epoch:  23,    lr=0.000300,    loss=0.183049,    train_acc=0.930347,    eval_loss=2.574513,    eval_acc=0.557407
# epoch:  24,    lr=0.000300,    loss=0.171137,    train_acc=0.935393,    eval_loss=2.476207,    eval_acc=0.575583
# epoch:  25,    lr=0.000300,    loss=0.163149,    train_acc=0.937964,    eval_loss=2.359238,    eval_acc=0.571612
# Saving checkpoint ./without_fa/CLDNN_cv4_step1_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.157543,    train_acc=0.939901,    eval_loss=2.515371,    eval_acc=0.608299
# epoch:  27,    lr=0.000300,    loss=0.147855,    train_acc=0.943767,    eval_loss=2.489630,    eval_acc=0.595604
# epoch:  28,    lr=0.000300,    loss=0.140561,    train_acc=0.946235,    eval_loss=2.562884,    eval_acc=0.608914
# epoch:  29,    lr=0.000300,    loss=0.133326,    train_acc=0.950254,    eval_loss=2.912648,    eval_acc=0.570438
# epoch:  30,    lr=0.000300,    loss=0.127132,    train_acc=0.952258,    eval_loss=2.803630,    eval_acc=0.605950
# Saving checkpoint ./without_fa/CLDNN_cv4_step1_epoch30.pt
# Start training
# epoch:   1,    lr=0.000300,    loss=0.965268,    train_acc=0.597391,    eval_loss=0.868279,    eval_acc=0.689447
# epoch:   2,    lr=0.000300,    loss=0.872763,    train_acc=0.645793,    eval_loss=0.875415,    eval_acc=0.678262
# epoch:   3,    lr=0.000300,    loss=0.810104,    train_acc=0.674080,    eval_loss=0.928928,    eval_acc=0.643085
# epoch:   4,    lr=0.000300,    loss=0.752111,    train_acc=0.699643,    eval_loss=0.947763,    eval_acc=0.657961
# epoch:   5,    lr=0.000300,    loss=0.691475,    train_acc=0.727412,    eval_loss=0.995783,    eval_acc=0.647503
# Saving checkpoint ./without_fa/CLDNN_cv4_step2_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.634814,    train_acc=0.750531,    eval_loss=1.052630,    eval_acc=0.615458
# epoch:   7,    lr=0.000300,    loss=0.582163,    train_acc=0.771770,    eval_loss=1.254246,    eval_acc=0.571948
# epoch:   8,    lr=0.000300,    loss=0.534166,    train_acc=0.791255,    eval_loss=1.283397,    eval_acc=0.603042
# epoch:   9,    lr=0.000300,    loss=0.486591,    train_acc=0.808933,    eval_loss=1.309043,    eval_acc=0.635367
# epoch:  10,    lr=0.000300,    loss=0.443877,    train_acc=0.827215,    eval_loss=1.473055,    eval_acc=0.613948
# Saving checkpoint ./without_fa/CLDNN_cv4_step2_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.411245,    train_acc=0.839340,    eval_loss=1.481035,    eval_acc=0.589676
# epoch:  12,    lr=0.000300,    loss=0.377843,    train_acc=0.853688,    eval_loss=1.702412,    eval_acc=0.617583
# epoch:  13,    lr=0.000300,    loss=0.344562,    train_acc=0.867145,    eval_loss=1.792391,    eval_acc=0.593759
# epoch:  14,    lr=0.000300,    loss=0.324576,    train_acc=0.873821,    eval_loss=1.854707,    eval_acc=0.577373
# epoch:  15,    lr=0.000300,    loss=0.298300,    train_acc=0.883881,    eval_loss=2.012060,    eval_acc=0.563112
# Saving checkpoint ./without_fa/CLDNN_cv4_step2_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.280551,    train_acc=0.891474,    eval_loss=1.921839,    eval_acc=0.587998
# epoch:  17,    lr=0.000300,    loss=0.263674,    train_acc=0.897759,    eval_loss=1.990037,    eval_acc=0.572731
# epoch:  18,    lr=0.000300,    loss=0.246185,    train_acc=0.905236,    eval_loss=2.203405,    eval_acc=0.577037
# epoch:  19,    lr=0.000300,    loss=0.230941,    train_acc=0.910862,    eval_loss=2.294678,    eval_acc=0.611543
# epoch:  20,    lr=0.000300,    loss=0.214814,    train_acc=0.918045,    eval_loss=2.276533,    eval_acc=0.600246
# Saving checkpoint ./without_fa/CLDNN_cv4_step2_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.204565,    train_acc=0.921600,    eval_loss=2.311254,    eval_acc=0.597002
# epoch:  22,    lr=0.000300,    loss=0.191623,    train_acc=0.927012,    eval_loss=2.451054,    eval_acc=0.586097
# epoch:  23,    lr=0.000300,    loss=0.181162,    train_acc=0.931257,    eval_loss=2.426810,    eval_acc=0.596835
# epoch:  24,    lr=0.000300,    loss=0.168171,    train_acc=0.936162,    eval_loss=2.504289,    eval_acc=0.576702
# epoch:  25,    lr=0.000300,    loss=0.161524,    train_acc=0.938960,    eval_loss=2.430729,    eval_acc=0.580393
# Saving checkpoint ./without_fa/CLDNN_cv4_step2_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.150376,    train_acc=0.943052,    eval_loss=2.599729,    eval_acc=0.582406
# epoch:  27,    lr=0.000300,    loss=0.140831,    train_acc=0.946333,    eval_loss=2.642066,    eval_acc=0.571668
# epoch:  28,    lr=0.000300,    loss=0.136759,    train_acc=0.948226,    eval_loss=2.806614,    eval_acc=0.585370
# epoch:  29,    lr=0.000300,    loss=0.129429,    train_acc=0.951635,    eval_loss=2.775235,    eval_acc=0.574576
# 11it [00:00, 106.76it/s]
# epoch:  30,    lr=0.000300,    loss=0.122739,    train_acc=0.953895,    eval_loss=2.655960,    eval_acc=0.589620
# Saving checkpoint ./without_fa/CLDNN_cv4_step2_epoch30.pt
# 4041it [00:28, 141.77it/s]
# 449it [00:03, 139.29it/s]
# (164646, 40, 50, 1) (164646,) (17014, 40, 50, 1) (17014,)
# Start training
# epoch:   1,    lr=0.000300,    loss=0.950255,    train_acc=0.611696,    eval_loss=1.076237,    eval_acc=0.530034
# epoch:   2,    lr=0.000300,    loss=0.856248,    train_acc=0.657022,    eval_loss=1.015628,    eval_acc=0.580522
# epoch:   3,    lr=0.000300,    loss=0.798171,    train_acc=0.682956,    eval_loss=1.093912,    eval_acc=0.549841
# epoch:   4,    lr=0.000300,    loss=0.744014,    train_acc=0.706454,    eval_loss=1.127306,    eval_acc=0.576114
# epoch:   5,    lr=0.000300,    loss=0.697456,    train_acc=0.725937,    eval_loss=1.257701,    eval_acc=0.518984
# Saving checkpoint ./without_fa/CLDNN_cv5_step1_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.642484,    train_acc=0.747163,    eval_loss=1.211593,    eval_acc=0.556718
# epoch:   7,    lr=0.000300,    loss=0.594002,    train_acc=0.766895,    eval_loss=1.203899,    eval_acc=0.573057
# epoch:   8,    lr=0.000300,    loss=0.550636,    train_acc=0.784300,    eval_loss=1.275417,    eval_acc=0.527801
# epoch:   9,    lr=0.000300,    loss=0.505117,    train_acc=0.802112,    eval_loss=1.454296,    eval_acc=0.533090
# epoch:  10,    lr=0.000300,    loss=0.464949,    train_acc=0.819650,    eval_loss=1.449929,    eval_acc=0.558481
# Saving checkpoint ./without_fa/CLDNN_cv5_step1_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.433328,    train_acc=0.831290,    eval_loss=1.577436,    eval_acc=0.546138
# epoch:  12,    lr=0.000300,    loss=0.398014,    train_acc=0.845828,    eval_loss=1.703369,    eval_acc=0.527154
# epoch:  13,    lr=0.000300,    loss=0.369664,    train_acc=0.856981,    eval_loss=1.751356,    eval_acc=0.524744
# epoch:  14,    lr=0.000300,    loss=0.342638,    train_acc=0.868032,    eval_loss=1.884649,    eval_acc=0.514282
# epoch:  15,    lr=0.000300,    loss=0.321015,    train_acc=0.876482,    eval_loss=1.905983,    eval_acc=0.539262
# Saving checkpoint ./without_fa/CLDNN_cv5_step1_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.299025,    train_acc=0.884556,    eval_loss=1.949792,    eval_acc=0.541907
# epoch:  17,    lr=0.000300,    loss=0.279909,    train_acc=0.892435,    eval_loss=2.170480,    eval_acc=0.533972
# epoch:  18,    lr=0.000300,    loss=0.261325,    train_acc=0.899841,    eval_loss=2.078283,    eval_acc=0.528330
# epoch:  19,    lr=0.000300,    loss=0.244685,    train_acc=0.905436,    eval_loss=2.218760,    eval_acc=0.525567
# epoch:  20,    lr=0.000300,    loss=0.230860,    train_acc=0.911262,    eval_loss=2.428669,    eval_acc=0.507171
# Saving checkpoint ./without_fa/CLDNN_cv5_step1_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.219641,    train_acc=0.915593,    eval_loss=2.444353,    eval_acc=0.510403
# epoch:  22,    lr=0.000300,    loss=0.208171,    train_acc=0.919980,    eval_loss=2.474078,    eval_acc=0.482426
# epoch:  23,    lr=0.000300,    loss=0.192924,    train_acc=0.926535,    eval_loss=2.683545,    eval_acc=0.525038
# epoch:  24,    lr=0.000300,    loss=0.185864,    train_acc=0.929177,    eval_loss=2.541072,    eval_acc=0.483308
# epoch:  25,    lr=0.000300,    loss=0.172994,    train_acc=0.935094,    eval_loss=2.700864,    eval_acc=0.477724
# Saving checkpoint ./without_fa/CLDNN_cv5_step1_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.170156,    train_acc=0.936267,    eval_loss=2.627225,    eval_acc=0.495180
# epoch:  27,    lr=0.000300,    loss=0.158019,    train_acc=0.940689,    eval_loss=2.790537,    eval_acc=0.528388
# epoch:  28,    lr=0.000300,    loss=0.148849,    train_acc=0.943429,    eval_loss=2.816973,    eval_acc=0.498707
# epoch:  29,    lr=0.000300,    loss=0.145677,    train_acc=0.945677,    eval_loss=3.220367,    eval_acc=0.492477
# epoch:  30,    lr=0.000300,    loss=0.136881,    train_acc=0.948563,    eval_loss=3.011023,    eval_acc=0.519219
# Saving checkpoint ./without_fa/CLDNN_cv5_step1_epoch30.pt
# Start training
# epoch:   1,    lr=0.000300,    loss=0.947527,    train_acc=0.613786,    eval_loss=1.037940,    eval_acc=0.567004
# epoch:   2,    lr=0.000300,    loss=0.852072,    train_acc=0.660108,    eval_loss=1.030821,    eval_acc=0.588457
# epoch:   3,    lr=0.000300,    loss=0.791899,    train_acc=0.686747,    eval_loss=1.146078,    eval_acc=0.555425
# epoch:   4,    lr=0.000300,    loss=0.736705,    train_acc=0.709777,    eval_loss=1.137629,    eval_acc=0.568120
# epoch:   5,    lr=0.000300,    loss=0.678701,    train_acc=0.734211,    eval_loss=1.172171,    eval_acc=0.570706
# Saving checkpoint ./without_fa/CLDNN_cv5_step2_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.626244,    train_acc=0.754666,    eval_loss=1.315526,    eval_acc=0.537792
# epoch:   7,    lr=0.000300,    loss=0.573833,    train_acc=0.775934,    eval_loss=1.311078,    eval_acc=0.548078
# epoch:   8,    lr=0.000300,    loss=0.524523,    train_acc=0.795569,    eval_loss=1.360300,    eval_acc=0.561773
# epoch:   9,    lr=0.000300,    loss=0.478355,    train_acc=0.814894,    eval_loss=1.474373,    eval_acc=0.530152
# epoch:  10,    lr=0.000300,    loss=0.439984,    train_acc=0.829638,    eval_loss=1.562325,    eval_acc=0.559069
# Saving checkpoint ./without_fa/CLDNN_cv5_step2_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.400113,    train_acc=0.844321,    eval_loss=1.655005,    eval_acc=0.541672
# epoch:  12,    lr=0.000300,    loss=0.373565,    train_acc=0.856028,    eval_loss=1.779982,    eval_acc=0.524098
# epoch:  13,    lr=0.000300,    loss=0.341371,    train_acc=0.867728,    eval_loss=1.813191,    eval_acc=0.534325
# epoch:  14,    lr=0.000300,    loss=0.317012,    train_acc=0.878372,    eval_loss=1.801108,    eval_acc=0.544493
# epoch:  15,    lr=0.000300,    loss=0.294741,    train_acc=0.886385,    eval_loss=2.087204,    eval_acc=0.530387
# Saving checkpoint ./without_fa/CLDNN_cv5_step2_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.275188,    train_acc=0.894367,    eval_loss=2.219190,    eval_acc=0.524039
# epoch:  17,    lr=0.000300,    loss=0.254890,    train_acc=0.902490,    eval_loss=2.087536,    eval_acc=0.541554
# epoch:  18,    lr=0.000300,    loss=0.238992,    train_acc=0.908425,    eval_loss=2.322900,    eval_acc=0.537557
# epoch:  19,    lr=0.000300,    loss=0.225093,    train_acc=0.913194,    eval_loss=2.314484,    eval_acc=0.556071
# epoch:  20,    lr=0.000300,    loss=0.209921,    train_acc=0.919888,    eval_loss=2.287058,    eval_acc=0.538028
# Saving checkpoint ./without_fa/CLDNN_cv5_step2_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.198900,    train_acc=0.923126,    eval_loss=2.478405,    eval_acc=0.538380
# epoch:  22,    lr=0.000300,    loss=0.188630,    train_acc=0.928296,    eval_loss=2.518662,    eval_acc=0.524157
# epoch:  23,    lr=0.000300,    loss=0.179640,    train_acc=0.931662,    eval_loss=2.692543,    eval_acc=0.514753
# epoch:  24,    lr=0.000300,    loss=0.169412,    train_acc=0.936006,    eval_loss=2.664570,    eval_acc=0.519866
# epoch:  25,    lr=0.000300,    loss=0.159922,    train_acc=0.939371,    eval_loss=2.886207,    eval_acc=0.493241
# Saving checkpoint ./without_fa/CLDNN_cv5_step2_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.148698,    train_acc=0.943733,    eval_loss=2.819077,    eval_acc=0.544845
# epoch:  27,    lr=0.000300,    loss=0.144906,    train_acc=0.945713,    eval_loss=2.871617,    eval_acc=0.530269
# epoch:  28,    lr=0.000300,    loss=0.136132,    train_acc=0.948945,    eval_loss=3.093530,    eval_acc=0.530269
# epoch:  29,    lr=0.000300,    loss=0.128889,    train_acc=0.951685,    eval_loss=2.824617,    eval_acc=0.530975
# 13it [00:00, 122.97it/s]
# epoch:  30,    lr=0.000300,    loss=0.126328,    train_acc=0.953161,    eval_loss=3.000361,    eval_acc=0.518808
# Saving checkpoint ./without_fa/CLDNN_cv5_step2_epoch30.pt
# 4041it [00:26, 152.31it/s]
# 449it [00:02, 171.47it/s]
# (164203, 40, 50, 1) (164203,) (17457, 40, 50, 1) (17457,)
# Start training
# epoch:   1,    lr=0.000300,    loss=0.963012,    train_acc=0.603817,    eval_loss=0.982421,    eval_acc=0.584866
# epoch:   2,    lr=0.000300,    loss=0.873073,    train_acc=0.648419,    eval_loss=1.044571,    eval_acc=0.558973
# epoch:   3,    lr=0.000300,    loss=0.816475,    train_acc=0.674459,    eval_loss=1.057210,    eval_acc=0.580913
# epoch:   4,    lr=0.000300,    loss=0.760338,    train_acc=0.699682,    eval_loss=1.093211,    eval_acc=0.576216
# epoch:   5,    lr=0.000300,    loss=0.707037,    train_acc=0.721498,    eval_loss=1.200287,    eval_acc=0.554906
# Saving checkpoint ./without_fa/CLDNN_cv6_step1_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.654998,    train_acc=0.743022,    eval_loss=1.225720,    eval_acc=0.585324
# epoch:   7,    lr=0.000300,    loss=0.600655,    train_acc=0.764443,    eval_loss=1.354677,    eval_acc=0.558229
# epoch:   8,    lr=0.000300,    loss=0.553672,    train_acc=0.783730,    eval_loss=1.291769,    eval_acc=0.579481
# epoch:   9,    lr=0.000300,    loss=0.507194,    train_acc=0.802110,    eval_loss=1.446117,    eval_acc=0.563155
# epoch:  10,    lr=0.000300,    loss=0.467070,    train_acc=0.819307,    eval_loss=1.532907,    eval_acc=0.547746
# Saving checkpoint ./without_fa/CLDNN_cv6_step1_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.425587,    train_acc=0.835931,    eval_loss=1.609621,    eval_acc=0.538180
# epoch:  12,    lr=0.000300,    loss=0.394965,    train_acc=0.846462,    eval_loss=1.645564,    eval_acc=0.534972
# epoch:  13,    lr=0.000300,    loss=0.361565,    train_acc=0.860149,    eval_loss=1.791681,    eval_acc=0.551584
# epoch:  14,    lr=0.000300,    loss=0.338680,    train_acc=0.869107,    eval_loss=1.943392,    eval_acc=0.532738
# epoch:  15,    lr=0.000300,    loss=0.312835,    train_acc=0.879686,    eval_loss=2.049972,    eval_acc=0.532680
# Saving checkpoint ./without_fa/CLDNN_cv6_step1_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.293125,    train_acc=0.886524,    eval_loss=2.043844,    eval_acc=0.530905
# epoch:  17,    lr=0.000300,    loss=0.269974,    train_acc=0.896061,    eval_loss=2.041669,    eval_acc=0.540986
# epoch:  18,    lr=0.000300,    loss=0.255126,    train_acc=0.902295,    eval_loss=2.343595,    eval_acc=0.519906
# epoch:  19,    lr=0.000300,    loss=0.239437,    train_acc=0.908462,    eval_loss=2.505516,    eval_acc=0.500659
# epoch:  20,    lr=0.000300,    loss=0.227339,    train_acc=0.913410,    eval_loss=2.495426,    eval_acc=0.521395
# Saving checkpoint ./without_fa/CLDNN_cv6_step1_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.211442,    train_acc=0.918993,    eval_loss=2.389613,    eval_acc=0.553532
# epoch:  22,    lr=0.000300,    loss=0.199294,    train_acc=0.923825,    eval_loss=2.529021,    eval_acc=0.548261
# epoch:  23,    lr=0.000300,    loss=0.190811,    train_acc=0.928042,    eval_loss=2.663090,    eval_acc=0.512975
# epoch:  24,    lr=0.000300,    loss=0.180215,    train_acc=0.931540,    eval_loss=2.752790,    eval_acc=0.513204
# epoch:  25,    lr=0.000300,    loss=0.168974,    train_acc=0.936214,    eval_loss=2.689873,    eval_acc=0.539783
# Saving checkpoint ./without_fa/CLDNN_cv6_step1_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.158216,    train_acc=0.940358,    eval_loss=2.956172,    eval_acc=0.518359
# epoch:  27,    lr=0.000300,    loss=0.154735,    train_acc=0.941479,    eval_loss=3.011077,    eval_acc=0.510225
# epoch:  28,    lr=0.000300,    loss=0.142216,    train_acc=0.946732,    eval_loss=2.973570,    eval_acc=0.515323
# epoch:  29,    lr=0.000300,    loss=0.136973,    train_acc=0.948518,    eval_loss=3.478224,    eval_acc=0.525233
# epoch:  30,    lr=0.000300,    loss=0.130939,    train_acc=0.950779,    eval_loss=2.941693,    eval_acc=0.548204
# Saving checkpoint ./without_fa/CLDNN_cv6_step1_epoch30.pt
# Start training
# epoch:   1,    lr=0.000300,    loss=0.954496,    train_acc=0.606962,    eval_loss=1.040245,    eval_acc=0.559775
# epoch:   2,    lr=0.000300,    loss=0.866336,    train_acc=0.651862,    eval_loss=1.027066,    eval_acc=0.571404
# epoch:   3,    lr=0.000300,    loss=0.806382,    train_acc=0.679322,    eval_loss=1.058241,    eval_acc=0.562869
# epoch:   4,    lr=0.000300,    loss=0.750410,    train_acc=0.704252,    eval_loss=1.131033,    eval_acc=0.566879
# epoch:   5,    lr=0.000300,    loss=0.691127,    train_acc=0.729609,    eval_loss=1.303218,    eval_acc=0.520422
# Saving checkpoint ./without_fa/CLDNN_cv6_step2_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.636792,    train_acc=0.751042,    eval_loss=1.396742,    eval_acc=0.532165
# epoch:   7,    lr=0.000300,    loss=0.584350,    train_acc=0.771969,    eval_loss=1.277138,    eval_acc=0.553703
# epoch:   8,    lr=0.000300,    loss=0.532450,    train_acc=0.793694,    eval_loss=1.396766,    eval_acc=0.541502
# epoch:   9,    lr=0.000300,    loss=0.488376,    train_acc=0.810446,    eval_loss=1.618183,    eval_acc=0.541788
# epoch:  10,    lr=0.000300,    loss=0.447961,    train_acc=0.827065,    eval_loss=1.602993,    eval_acc=0.548491
# Saving checkpoint ./without_fa/CLDNN_cv6_step2_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.410055,    train_acc=0.841879,    eval_loss=1.788770,    eval_acc=0.523687
# epoch:  12,    lr=0.000300,    loss=0.378457,    train_acc=0.853775,    eval_loss=1.711244,    eval_acc=0.540929
# epoch:  13,    lr=0.000300,    loss=0.350501,    train_acc=0.864750,    eval_loss=2.074632,    eval_acc=0.524260
# epoch:  14,    lr=0.000300,    loss=0.322354,    train_acc=0.876523,    eval_loss=1.934785,    eval_acc=0.529186
# epoch:  15,    lr=0.000300,    loss=0.303804,    train_acc=0.883465,    eval_loss=2.111252,    eval_acc=0.517271
# Saving checkpoint ./without_fa/CLDNN_cv6_step2_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.282099,    train_acc=0.891570,    eval_loss=2.076827,    eval_acc=0.541330
# epoch:  17,    lr=0.000300,    loss=0.261165,    train_acc=0.899638,    eval_loss=2.278946,    eval_acc=0.522197
# epoch:  18,    lr=0.000300,    loss=0.246398,    train_acc=0.906213,    eval_loss=2.425667,    eval_acc=0.514063
# epoch:  19,    lr=0.000300,    loss=0.227489,    train_acc=0.912844,    eval_loss=2.534946,    eval_acc=0.515782
# epoch:  20,    lr=0.000300,    loss=0.216496,    train_acc=0.917359,    eval_loss=2.577957,    eval_acc=0.518990
# Saving checkpoint ./without_fa/CLDNN_cv6_step2_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.207690,    train_acc=0.920540,    eval_loss=2.912002,    eval_acc=0.497164
# epoch:  22,    lr=0.000300,    loss=0.192421,    train_acc=0.927158,    eval_loss=2.796096,    eval_acc=0.487598
# epoch:  23,    lr=0.000300,    loss=0.183079,    train_acc=0.930431,    eval_loss=2.980435,    eval_acc=0.490978
# epoch:  24,    lr=0.000300,    loss=0.171483,    train_acc=0.935580,    eval_loss=2.845908,    eval_acc=0.519791
# epoch:  25,    lr=0.000300,    loss=0.164085,    train_acc=0.937378,    eval_loss=2.923075,    eval_acc=0.505127
# Saving checkpoint ./without_fa/CLDNN_cv6_step2_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.152766,    train_acc=0.942131,    eval_loss=2.898864,    eval_acc=0.529873
# epoch:  27,    lr=0.000300,    loss=0.147329,    train_acc=0.944636,    eval_loss=2.899492,    eval_acc=0.528441
# epoch:  28,    lr=0.000300,    loss=0.141860,    train_acc=0.946775,    eval_loss=3.169783,    eval_acc=0.523229
# epoch:  29,    lr=0.000300,    loss=0.131888,    train_acc=0.950334,    eval_loss=3.248082,    eval_acc=0.495847
# 10it [00:00, 98.95it/s]
# epoch:  30,    lr=0.000300,    loss=0.124966,    train_acc=0.953418,    eval_loss=3.168618,    eval_acc=0.519906
# Saving checkpoint ./without_fa/CLDNN_cv6_step2_epoch30.pt
# 4041it [00:27, 146.96it/s]
# 449it [00:02, 162.15it/s]
# (162851, 40, 50, 1) (162851,) (18809, 40, 50, 1) (18809,)
# Start training
# epoch:   1,    lr=0.000300,    loss=0.949125,    train_acc=0.608779,    eval_loss=1.075618,    eval_acc=0.569515
# epoch:   2,    lr=0.000300,    loss=0.853187,    train_acc=0.656668,    eval_loss=1.159178,    eval_acc=0.579191
# epoch:   3,    lr=0.000300,    loss=0.798412,    train_acc=0.681198,    eval_loss=1.104127,    eval_acc=0.565952
# epoch:   4,    lr=0.000300,    loss=0.740460,    train_acc=0.705367,    eval_loss=1.240762,    eval_acc=0.551598
# epoch:   5,    lr=0.000300,    loss=0.682399,    train_acc=0.731163,    eval_loss=1.258379,    eval_acc=0.541230
# Saving checkpoint ./without_fa/CLDNN_cv7_step1_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.630139,    train_acc=0.751990,    eval_loss=1.285888,    eval_acc=0.553139
# epoch:   7,    lr=0.000300,    loss=0.577977,    train_acc=0.773536,    eval_loss=1.431580,    eval_acc=0.568239
# epoch:   8,    lr=0.000300,    loss=0.529204,    train_acc=0.792815,    eval_loss=1.414052,    eval_acc=0.568239
# epoch:   9,    lr=0.000300,    loss=0.484661,    train_acc=0.811358,    eval_loss=1.696777,    eval_acc=0.540539
# epoch:  10,    lr=0.000300,    loss=0.444336,    train_acc=0.827099,    eval_loss=1.645666,    eval_acc=0.545484
# Saving checkpoint ./without_fa/CLDNN_cv7_step1_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.411426,    train_acc=0.839960,    eval_loss=1.757524,    eval_acc=0.548461
# epoch:  12,    lr=0.000300,    loss=0.376462,    train_acc=0.854044,    eval_loss=2.023173,    eval_acc=0.547982
# epoch:  13,    lr=0.000300,    loss=0.351486,    train_acc=0.863945,    eval_loss=2.035107,    eval_acc=0.531714
# epoch:  14,    lr=0.000300,    loss=0.326712,    train_acc=0.873686,    eval_loss=1.838221,    eval_acc=0.534319
# epoch:  15,    lr=0.000300,    loss=0.303566,    train_acc=0.882591,    eval_loss=2.158753,    eval_acc=0.543197
# Saving checkpoint ./without_fa/CLDNN_cv7_step1_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.282165,    train_acc=0.891178,    eval_loss=2.216292,    eval_acc=0.544633
# ...
# epoch:  27,    lr=0.000300,    loss=0.159948,    train_acc=0.940279,    eval_loss=3.068773,    eval_acc=0.515316
# epoch:  28,    lr=0.000300,    loss=0.152628,    train_acc=0.942839,    eval_loss=3.077938,    eval_acc=0.524237
# epoch:  29,    lr=0.000300,    loss=0.146245,    train_acc=0.945343,    eval_loss=3.225513,    eval_acc=0.535963
# 13it [00:00, 127.33it/s]
# epoch:  30,    lr=0.000300,    loss=0.137870,    train_acc=0.948373,    eval_loss=3.024223,    eval_acc=0.512960
# Saving checkpoint ./without_fa/CLDNN_cv8_step2_epoch30.pt
# 4041it [00:32, 122.78it/s]
# 449it [00:02, 159.24it/s]
# (164704, 40, 50, 1) (164704,) (16956, 40, 50, 1) (16956,)
# Start training
# epoch:   1,    lr=0.000300,    loss=0.960736,    train_acc=0.604351,    eval_loss=1.030538,    eval_acc=0.562869
# epoch:   2,    lr=0.000300,    loss=0.864636,    train_acc=0.651147,    eval_loss=0.997738,    eval_acc=0.588818
# epoch:   3,    lr=0.000300,    loss=0.800115,    train_acc=0.680198,    eval_loss=1.019605,    eval_acc=0.589408
# epoch:   4,    lr=0.000300,    loss=0.741715,    train_acc=0.705828,    eval_loss=1.035297,    eval_acc=0.611701
# epoch:   5,    lr=0.000300,    loss=0.683605,    train_acc=0.731204,    eval_loss=1.076464,    eval_acc=0.599670
# Saving checkpoint ./without_fa/CLDNN_cv9_step1_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.627608,    train_acc=0.753657,    eval_loss=1.063668,    eval_acc=0.612880
# epoch:   7,    lr=0.000300,    loss=0.572264,    train_acc=0.776694,    eval_loss=1.251726,    eval_acc=0.589054
# epoch:   8,    lr=0.000300,    loss=0.523704,    train_acc=0.796954,    eval_loss=1.322014,    eval_acc=0.583274
# epoch:   9,    lr=0.000300,    loss=0.479028,    train_acc=0.814110,    eval_loss=1.335764,    eval_acc=0.584277
# epoch:  10,    lr=0.000300,    loss=0.437971,    train_acc=0.831290,    eval_loss=1.386285,    eval_acc=0.583038
# Saving checkpoint ./without_fa/CLDNN_cv9_step1_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.402378,    train_acc=0.844594,    eval_loss=1.516479,    eval_acc=0.580031
# epoch:  12,    lr=0.000300,    loss=0.371059,    train_acc=0.857067,    eval_loss=1.675261,    eval_acc=0.562102
# epoch:  13,    lr=0.000300,    loss=0.344123,    train_acc=0.867722,    eval_loss=1.684526,    eval_acc=0.563576
# epoch:  14,    lr=0.000300,    loss=0.319019,    train_acc=0.877655,    eval_loss=1.803240,    eval_acc=0.578320
# epoch:  15,    lr=0.000300,    loss=0.297388,    train_acc=0.885540,    eval_loss=1.942755,    eval_acc=0.567823
# Saving checkpoint ./without_fa/CLDNN_cv9_step1_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.279414,    train_acc=0.892855,    eval_loss=1.882079,    eval_acc=0.563576
# epoch:  17,    lr=0.000300,    loss=0.261013,    train_acc=0.899877,    eval_loss=2.089434,    eval_acc=0.550955
# epoch:  18,    lr=0.000300,    loss=0.243938,    train_acc=0.906669,    eval_loss=1.959532,    eval_acc=0.562456
# epoch:  19,    lr=0.000300,    loss=0.229245,    train_acc=0.912112,    eval_loss=2.135019,    eval_acc=0.560745
# epoch:  20,    lr=0.000300,    loss=0.215753,    train_acc=0.917853,    eval_loss=2.520716,    eval_acc=0.577908
# Saving checkpoint ./without_fa/CLDNN_cv9_step1_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.204303,    train_acc=0.922167,    eval_loss=2.275866,    eval_acc=0.559330
# epoch:  22,    lr=0.000300,    loss=0.195364,    train_acc=0.925016,    eval_loss=2.540666,    eval_acc=0.544173
# epoch:  23,    lr=0.000300,    loss=0.181938,    train_acc=0.930854,    eval_loss=2.477181,    eval_acc=0.545412
# epoch:  24,    lr=0.000300,    loss=0.173637,    train_acc=0.934250,    eval_loss=2.480710,    eval_acc=0.569592
# epoch:  25,    lr=0.000300,    loss=0.164775,    train_acc=0.937421,    eval_loss=2.438632,    eval_acc=0.565758
# Saving checkpoint ./without_fa/CLDNN_cv9_step1_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.154750,    train_acc=0.941801,    eval_loss=2.680094,    eval_acc=0.558209
# epoch:  27,    lr=0.000300,    loss=0.149014,    train_acc=0.943423,    eval_loss=2.684451,    eval_acc=0.550837
# epoch:  28,    lr=0.000300,    loss=0.137973,    train_acc=0.948131,    eval_loss=2.715188,    eval_acc=0.559035
# epoch:  29,    lr=0.000300,    loss=0.132156,    train_acc=0.950792,    eval_loss=2.756799,    eval_acc=0.544232
# epoch:  30,    lr=0.000300,    loss=0.126093,    train_acc=0.952773,    eval_loss=2.841085,    eval_acc=0.566407
# Saving checkpoint ./without_fa/CLDNN_cv9_step1_epoch30.pt
# Start training
# epoch:   1,    lr=0.000300,    loss=0.958679,    train_acc=0.604236,    eval_loss=0.948587,    eval_acc=0.618070
# epoch:   2,    lr=0.000300,    loss=0.863811,    train_acc=0.650242,    eval_loss=0.980542,    eval_acc=0.603503
# epoch:   3,    lr=0.000300,    loss=0.802729,    train_acc=0.677932,    eval_loss=1.021434,    eval_acc=0.596190
# epoch:   4,    lr=0.000300,    loss=0.747017,    train_acc=0.704826,    eval_loss=1.027161,    eval_acc=0.585103
# epoch:   5,    lr=0.000300,    loss=0.688494,    train_acc=0.729120,    eval_loss=1.031540,    eval_acc=0.598431
# Saving checkpoint ./without_fa/CLDNN_cv9_step2_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.635599,    train_acc=0.750978,    eval_loss=1.100662,    eval_acc=0.604093
# epoch:   7,    lr=0.000300,    loss=0.583311,    train_acc=0.771931,    eval_loss=1.287555,    eval_acc=0.575902
# epoch:   8,    lr=0.000300,    loss=0.537248,    train_acc=0.790691,    eval_loss=1.264925,    eval_acc=0.587285
# epoch:   9,    lr=0.000300,    loss=0.494949,    train_acc=0.807938,    eval_loss=1.431400,    eval_acc=0.568471
# epoch:  10,    lr=0.000300,    loss=0.454872,    train_acc=0.823787,    eval_loss=1.414021,    eval_acc=0.596662
# Saving checkpoint ./without_fa/CLDNN_cv9_step2_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.422647,    train_acc=0.837128,    eval_loss=1.477461,    eval_acc=0.579913
# epoch:  12,    lr=0.000300,    loss=0.387624,    train_acc=0.849789,    eval_loss=1.618647,    eval_acc=0.576138
# epoch:  13,    lr=0.000300,    loss=0.357744,    train_acc=0.862121,    eval_loss=1.661259,    eval_acc=0.577731
# epoch:  14,    lr=0.000300,    loss=0.334614,    train_acc=0.870839,    eval_loss=1.691306,    eval_acc=0.572659
# epoch:  15,    lr=0.000300,    loss=0.311159,    train_acc=0.880334,    eval_loss=1.817187,    eval_acc=0.566643
# Saving checkpoint ./without_fa/CLDNN_cv9_step2_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.289832,    train_acc=0.888207,    eval_loss=1.845029,    eval_acc=0.571125
# epoch:  17,    lr=0.000300,    loss=0.272279,    train_acc=0.895473,    eval_loss=2.092607,    eval_acc=0.555379
# epoch:  18,    lr=0.000300,    loss=0.255324,    train_acc=0.902617,    eval_loss=2.096240,    eval_acc=0.574782
# epoch:  19,    lr=0.000300,    loss=0.238724,    train_acc=0.909263,    eval_loss=2.085955,    eval_acc=0.567941
# epoch:  20,    lr=0.000300,    loss=0.221193,    train_acc=0.915490,    eval_loss=2.048008,    eval_acc=0.558681
# Saving checkpoint ./without_fa/CLDNN_cv9_step2_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.213306,    train_acc=0.919111,    eval_loss=2.289457,    eval_acc=0.576551
# epoch:  22,    lr=0.000300,    loss=0.200617,    train_acc=0.923922,    eval_loss=2.308166,    eval_acc=0.553196
# epoch:  23,    lr=0.000300,    loss=0.190374,    train_acc=0.928187,    eval_loss=2.329172,    eval_acc=0.552784
# epoch:  24,    lr=0.000300,    loss=0.179296,    train_acc=0.931905,    eval_loss=2.490356,    eval_acc=0.553020
# epoch:  25,    lr=0.000300,    loss=0.173143,    train_acc=0.934578,    eval_loss=2.685282,    eval_acc=0.546591
# Saving checkpoint ./without_fa/CLDNN_cv9_step2_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.159780,    train_acc=0.939839,    eval_loss=2.830775,    eval_acc=0.551958
# epoch:  27,    lr=0.000300,    loss=0.157020,    train_acc=0.941145,    eval_loss=2.677616,    eval_acc=0.558092
# epoch:  28,    lr=0.000300,    loss=0.146983,    train_acc=0.944954,    eval_loss=2.747835,    eval_acc=0.568530
# epoch:  29,    lr=0.000300,    loss=0.140101,    train_acc=0.947384,    eval_loss=2.703696,    eval_acc=0.557207
# 13it [00:00, 126.67it/s]
# epoch:  30,    lr=0.000300,    loss=0.131913,    train_acc=0.950877,    eval_loss=2.679483,    eval_acc=0.571656
# Saving checkpoint ./without_fa/CLDNN_cv9_step2_epoch30.pt
# 4041it [00:25, 157.13it/s]
# 449it [00:02, 160.64it/s]
# (163250, 40, 50, 1) (163250,) (18410, 40, 50, 1) (18410,)
# Start training
# epoch:   1,    lr=0.000300,    loss=0.952879,    train_acc=0.605717,    eval_loss=1.021549,    eval_acc=0.584356
# epoch:   2,    lr=0.000300,    loss=0.855710,    train_acc=0.656618,    eval_loss=1.052291,    eval_acc=0.579576
# epoch:   3,    lr=0.000300,    loss=0.796527,    train_acc=0.682843,    eval_loss=1.079504,    eval_acc=0.573927
# epoch:   4,    lr=0.000300,    loss=0.741664,    train_acc=0.706991,    eval_loss=1.121610,    eval_acc=0.572461
# epoch:   5,    lr=0.000300,    loss=0.684110,    train_acc=0.730919,    eval_loss=1.323383,    eval_acc=0.550896
# Saving checkpoint ./without_fa/CLDNN_cv10_step1_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.630616,    train_acc=0.753180,    eval_loss=1.217440,    eval_acc=0.580554
# epoch:   7,    lr=0.000300,    loss=0.577637,    train_acc=0.775221,    eval_loss=1.321793,    eval_acc=0.549538
# epoch:   8,    lr=0.000300,    loss=0.530293,    train_acc=0.794534,    eval_loss=1.427221,    eval_acc=0.543672
# epoch:   9,    lr=0.000300,    loss=0.487509,    train_acc=0.811036,    eval_loss=1.448579,    eval_acc=0.555187
# epoch:  10,    lr=0.000300,    loss=0.448875,    train_acc=0.826299,    eval_loss=1.524048,    eval_acc=0.542314
# Saving checkpoint ./without_fa/CLDNN_cv10_step1_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.412852,    train_acc=0.840435,    eval_loss=1.606416,    eval_acc=0.554916
# epoch:  12,    lr=0.000300,    loss=0.379186,    train_acc=0.853824,    eval_loss=1.851855,    eval_acc=0.545193
# epoch:  13,    lr=0.000300,    loss=0.354352,    train_acc=0.863995,    eval_loss=1.786744,    eval_acc=0.542151
# epoch:  14,    lr=0.000300,    loss=0.327766,    train_acc=0.873922,    eval_loss=1.858726,    eval_acc=0.521184
# epoch:  15,    lr=0.000300,    loss=0.306005,    train_acc=0.882898,    eval_loss=2.217312,    eval_acc=0.520858
# Saving checkpoint ./without_fa/CLDNN_cv10_step1_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.286502,    train_acc=0.889724,    eval_loss=2.064857,    eval_acc=0.544324
# epoch:  17,    lr=0.000300,    loss=0.268804,    train_acc=0.897108,    eval_loss=2.248974,    eval_acc=0.530310
# epoch:  18,    lr=0.000300,    loss=0.250086,    train_acc=0.904252,    eval_loss=2.291064,    eval_acc=0.520206
# epoch:  19,    lr=0.000300,    loss=0.232161,    train_acc=0.910686,    eval_loss=2.239928,    eval_acc=0.517545
# epoch:  20,    lr=0.000300,    loss=0.221054,    train_acc=0.915306,    eval_loss=2.329865,    eval_acc=0.518686
# Saving checkpoint ./without_fa/CLDNN_cv10_step1_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.208077,    train_acc=0.920343,    eval_loss=2.345405,    eval_acc=0.551711
# epoch:  22,    lr=0.000300,    loss=0.197413,    train_acc=0.925080,    eval_loss=2.637776,    eval_acc=0.533840
# epoch:  23,    lr=0.000300,    loss=0.188035,    train_acc=0.927763,    eval_loss=2.543774,    eval_acc=0.525312
# epoch:  24,    lr=0.000300,    loss=0.174878,    train_acc=0.933995,    eval_loss=2.865679,    eval_acc=0.519174
# epoch:  25,    lr=0.000300,    loss=0.167637,    train_acc=0.936336,    eval_loss=2.873958,    eval_acc=0.515698
# Saving checkpoint ./without_fa/CLDNN_cv10_step1_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.161131,    train_acc=0.938915,    eval_loss=2.867088,    eval_acc=0.539218
# epoch:  27,    lr=0.000300,    loss=0.151709,    train_acc=0.943076,    eval_loss=3.012101,    eval_acc=0.517762
# epoch:  28,    lr=0.000300,    loss=0.141753,    train_acc=0.947004,    eval_loss=2.822701,    eval_acc=0.521401
# epoch:  29,    lr=0.000300,    loss=0.137063,    train_acc=0.948848,    eval_loss=3.079731,    eval_acc=0.508691
# epoch:  30,    lr=0.000300,    loss=0.127767,    train_acc=0.951342,    eval_loss=3.187756,    eval_acc=0.499022
# Saving checkpoint ./without_fa/CLDNN_cv10_step1_epoch30.pt
# Start training
# epoch:   1,    lr=0.000300,    loss=0.956255,    train_acc=0.604908,    eval_loss=1.018030,    eval_acc=0.593482
# epoch:   2,    lr=0.000300,    loss=0.862488,    train_acc=0.651612,    eval_loss=1.036003,    eval_acc=0.586475
# epoch:   3,    lr=0.000300,    loss=0.804819,    train_acc=0.678738,    eval_loss=1.106909,    eval_acc=0.572949
# epoch:   4,    lr=0.000300,    loss=0.751484,    train_acc=0.702482,    eval_loss=1.161812,    eval_acc=0.563498
# epoch:   5,    lr=0.000300,    loss=0.699121,    train_acc=0.723149,    eval_loss=1.194625,    eval_acc=0.563498
# Saving checkpoint ./without_fa/CLDNN_cv10_step2_epoch5.pt
# epoch:   6,    lr=0.000300,    loss=0.645693,    train_acc=0.745956,    eval_loss=1.204478,    eval_acc=0.547800
# epoch:   7,    lr=0.000300,    loss=0.594217,    train_acc=0.767181,    eval_loss=1.356521,    eval_acc=0.546551
# epoch:   8,    lr=0.000300,    loss=0.543355,    train_acc=0.787482,    eval_loss=1.329266,    eval_acc=0.571157
# epoch:   9,    lr=0.000300,    loss=0.502348,    train_acc=0.802763,    eval_loss=1.429058,    eval_acc=0.555133
# epoch:  10,    lr=0.000300,    loss=0.459536,    train_acc=0.820245,    eval_loss=1.642405,    eval_acc=0.542477
# Saving checkpoint ./without_fa/CLDNN_cv10_step2_epoch10.pt
# epoch:  11,    lr=0.000300,    loss=0.424714,    train_acc=0.834013,    eval_loss=1.572692,    eval_acc=0.542423
# epoch:  12,    lr=0.000300,    loss=0.393337,    train_acc=0.847414,    eval_loss=1.965452,    eval_acc=0.506518
# epoch:  13,    lr=0.000300,    loss=0.363085,    train_acc=0.859351,    eval_loss=1.835007,    eval_acc=0.555296
# epoch:  14,    lr=0.000300,    loss=0.338622,    train_acc=0.868738,    eval_loss=2.005733,    eval_acc=0.531450
# epoch:  15,    lr=0.000300,    loss=0.315257,    train_acc=0.878609,    eval_loss=2.125838,    eval_acc=0.531342
# Saving checkpoint ./without_fa/CLDNN_cv10_step2_epoch15.pt
# epoch:  16,    lr=0.000300,    loss=0.292600,    train_acc=0.887580,    eval_loss=2.328090,    eval_acc=0.523303
# epoch:  17,    lr=0.000300,    loss=0.274293,    train_acc=0.894032,    eval_loss=2.196681,    eval_acc=0.560022
# epoch:  18,    lr=0.000300,    loss=0.256792,    train_acc=0.901072,    eval_loss=2.352862,    eval_acc=0.524498
# epoch:  19,    lr=0.000300,    loss=0.244155,    train_acc=0.906158,    eval_loss=2.447992,    eval_acc=0.539978
# epoch:  20,    lr=0.000300,    loss=0.229999,    train_acc=0.911936,    eval_loss=2.686613,    eval_acc=0.531939
# Saving checkpoint ./without_fa/CLDNN_cv10_step2_epoch20.pt
# epoch:  21,    lr=0.000300,    loss=0.212865,    train_acc=0.918762,    eval_loss=2.511658,    eval_acc=0.547203
# epoch:  22,    lr=0.000300,    loss=0.205603,    train_acc=0.921293,    eval_loss=2.461332,    eval_acc=0.526018
# epoch:  23,    lr=0.000300,    loss=0.190528,    train_acc=0.927763,    eval_loss=2.806739,    eval_acc=0.527648
# epoch:  24,    lr=0.000300,    loss=0.181886,    train_acc=0.930913,    eval_loss=2.822897,    eval_acc=0.512493
# epoch:  25,    lr=0.000300,    loss=0.171108,    train_acc=0.934602,    eval_loss=2.866152,    eval_acc=0.531233
# Saving checkpoint ./without_fa/CLDNN_cv10_step2_epoch25.pt
# epoch:  26,    lr=0.000300,    loss=0.164284,    train_acc=0.937880,    eval_loss=2.754128,    eval_acc=0.518360
# epoch:  27,    lr=0.000300,    loss=0.157902,    train_acc=0.940515,    eval_loss=2.941609,    eval_acc=0.520641
# epoch:  28,    lr=0.000300,    loss=0.148678,    train_acc=0.944032,    eval_loss=3.013924,    eval_acc=0.527539
# epoch:  29,    lr=0.000300,    loss=0.142459,    train_acc=0.946360,    eval_loss=2.871436,    eval_acc=0.532808
# epoch:  30,    lr=0.000300,    loss=0.133414,    train_acc=0.949865,    eval_loss=2.987290,    eval_acc=0.525910
# Saving checkpoint ./without_fa/CLDNN_cv10_step2_epoch30.pt
# conv_dim: 1d 	with_focus_attn: False
# Test accuray: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]

# %%
with_focus_attn = [0.6570155902004454, 0.6124721603563474, 0.6347438752783965, 
                   0.6926503340757239, 0.6280623608017817, 0.6169265033407573, 
                   0.5812917594654788, 0.6013363028953229, 0.6948775055679287, 0.6792873051224945]
without_focus_attn = [0.6347438752783965, 0.6258351893095768, 0.6057906458797327, 
                      0.7037861915367484, 0.6035634743875279, 0.5946547884187082, 
                      0.6146993318485523, 0.6325167037861915, 0.688195991091314, 0.6681514476614699]

# %%
print('with_focus_attn:', sum(with_focus_attn) / 10)
print('without_focus_attn:', sum(without_focus_attn) / 10)
# Out:
# with_focus_attn: 0.6398663697104678
# without_focus_attn: 0.6371937639198219

# %%
sum([p.numel() for p in model.parameters()])
# Out:
# 1327044

# %%
model
# Out:
# CLDNN(
#   (conv1): Sequential(
#     (0): Conv1d(1, 64, kernel_size=(3, 1), stride=(1,))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv1d(64, 64, kernel_size=(3, 1), stride=(1,))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#   )
#   (lstm): LSTM(512, 64, num_layers=2, bidirectional=True)
#   (tanh): Tanh()
#   (dropout): Dropout(p=0.5, inplace=False)
#   (attn): MultiHeadedAttention(
#     (query): Linear(in_features=128, out_features=128, bias=True)
#     (key): Linear(in_features=128, out_features=128, bias=True)
#     (value): Linear(in_features=128, out_features=128, bias=True)
#     (o_proj): Linear(in_features=128, out_features=128, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (softmax): Softmax(dim=-1)
#     (tanh): Tanh()
#     (sigmoid): Sigmoid()
#     (linear_focus_query): Linear(in_features=128, out_features=128, bias=True)
#     (linear_focus_global): Linear(in_features=128, out_features=128, bias=True)
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=6400, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=4, bias=True)
#   )
# )

# %%
with_focus_attn = [0.623608017817372, 0.6503340757238307, 0.6280623608017817, 
                   0.7015590200445434, 0.6302895322939867, 0.6057906458797327, 
                   0.6057906458797327, 0.6102449888641426, 0.6547884187082406, 0.6570155902004454]
without_focus_attn = [0.6302895322939867, 0.6391982182628062, 0.623608017817372, 
                      0.7082405345211581, 0.6124721603563474, 0.6035634743875279, 
                      0.6102449888641426, 0.6124721603563474, 0.6547884187082406, 0.6636971046770601]

# %%
print('with_focus_attn:', sum(with_focus_attn) / 10)
print('without_focus_attn:', sum(without_focus_attn) / 10)
# Out:
# with_focus_attn: 0.6367483296213808
# without_focus_attn: 0.6358574610244988

# %%
class CLDNN(nn.Module):
    def __init__(self, conv_dim, checkpoint=None, hidden_size=128, num_layers=2,
                 bidirectional=True, with_focus_attn=False):
        super(CLDNN, self).__init__()
        self.conv_dim = conv_dim
        if(conv_dim == '1d'):
            self.encoder = Encoder(conv_dim)
            if checkpoint:
                self.encoder.load_state_dict(torch.load(checkpoint))
            self.lstm = nn.LSTM(8, hidden_size=hidden_size, num_layers=num_layers, bidirectional=bidirectional)
            self.tanh = nn.Tanh()
            self.dropout = nn.Dropout(0.1)
            self.attn = MultiHeadedAttention(num_attn_heads=4, attn_hidden_size=256, dropout_prob=0.1,
                                             with_focus_attn=with_focus_attn)
            self.fc = nn.Sequential(
                nn.Linear(50*2*hidden_size if bidirectional else 50*hidden_size, 64),
                nn.ReLU(),
                nn.Linear(64, 4)
            )
        elif(conv_dim == '2d'):
            self.encoder = Encoder(conv_dim)
            if checkpoint:
                self.encoder.load_state_dict(torch.load(checkpoint))
            self.attn = MultiHeadedAttention(num_attn_heads=4, attn_hidden_size=176, dropout_prob=0.1, 
                                             with_focus_attn=with_focus_attn)
            self.gap = nn.AdaptiveAvgPool2d((1, 11))
            self.lstm = nn.LSTM(11, hidden_size=hidden_size, num_layers=num_layers, bidirectional=bidirectional) 
            self.fc = nn.Sequential(
                nn.Linear(hidden_size*2 if bidirectional else hidden_size, 4)
            )
        else:
            raise ValueError("Convolution dimension not found: %s" % (conv_dim))
            
    def forward(self, x):
        if(self.conv_dim == '1d'):
            out = self.encoder(x)  # (batch, 1, 40, 50) -> (batch, 8, 1, 50)
            out = torch.squeeze(out, 2)  # (batch, 8, 1, 50) -> (batch, 8, 50)
            out = out.permute(2, 0, 1)  # (batch, 8, 50) -> (50, batch, 8)
            out, _ = self.lstm(out)  # (50, batch, 8) -> (50, batch, num_directions*hidden_size)
            out = self.tanh(out)
            out = self.dropout(out)
            out = out.permute(1, 0, 2)  # (50, batch, num_directions*hidden_size) -> (batch, 50, num_directions*hidden_size)
            h = out
            out = self.attn(out) # (batch, 50, num_directions*hidden_size) -> (batch, 50, num_directions*hidden_size)
            out = h + out
            new_out_shape = out.size()[:1] + (out.size()[1] * out.size()[2],)
            out = out.reshape(*new_out_shape)  # (batch, 50, num_directions*hidden_size) -> (batch, 50*num_directions*hidden_size)
            out = self.fc(out)  # (batch, 50*num_directions*hidden_size) -> (batch, 4)
        elif(self.conv_dim == '2d'):
            out = self.encoder(x)  # (batch, 1, 128, 100) -> (batch, 16, 11, 8)
            out = out.permute(0, 3, 1, 2)  # (batch, 16, 11, 8) -> (batch, 8, 16, 11)
            h = out
            new_out_shape = out.size()[:2] + (out.size()[2] * out.size()[3],)
            out = out.view(*new_out_shape)  # (batch, 8, 16, 11) -> (batch, 8, 176)
            out = self.attn(out)  # (batch, 8, 176) -> (batch, 8, 176)
            out = out.view(h.size())  # (batch, 8, 176) -> (batch, 8, 16, 11)
            out = h + out
            out = self.gap(out)  # (batch, 8, 16, 11) -> (batch, 8, 1, 11)
            out = torch.squeeze(out, 2)  # (batch, 8, 1, 11) -> (batch, 8, 11)
            out = out.permute(1, 0, 2)  # (batch, 8, 11) -> (8, batch, 11)
            out, _ = self.lstm(out)  # (8, batch, 11) -> (8, batch, num_directions*hidden_size)
            out = out[-1]  # (8, batch, num_directions*hidden_size) -> (batch, num_directions*hidden_size)
            out = self.fc(out)  # (batch, num_directions*hidden_size) -> (batch, 1)
        return out

# %%
for with_focus_attn in focus_attn_list:
    cv_eval = []
    #with_focus_attn = True if(with_focus_attn == 'true') else False
    for train_index, eval_index in skf.split(df['sample_name'], df['sample_label']):
        conv_dim = '1d'
        checkpoint = ''
        hidden_size = 128
        num_layers = 2
        bidirectional = 'true'

        batch_size = 256
        num_epochs = 50
        learning_rate = 0.001

        use_warmup = 'true'
        data_dir = './wav_data/pretrain/IEMOCAP_sub/'
        multi_task = 'false'
        augmentation = 'false'
        
        save_checkpoint_steps = 5
        output_dir = './model'

        bidirectional = True if(bidirectional == 'true') else False   
        n_mfcc = 40 if(conv_dim == '1d') else 128

        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        
        train_samples, eval_samples = df['sample_name'][train_index], df['sample_name'][eval_index]
        train_label, eval_label = df['sample_label'][train_index], df['sample_label'][eval_index]
        
        train_samples = [data_dir + train_sample + '.wav' for train_sample in train_samples]
        eval_samples = [data_dir + eval_sample + '.wav' for eval_sample in eval_samples]

        y_train = np.array(train_label)
        y_eval = np.array(eval_label)

        if(multi_task == 'true'):
            speaker = np.array(list(map(lambda x: int(x.split('/')[-1].split('-')[-1].split('.')[0]), sample_datas)))
            y_gender = np.array(list(map(lambda x: 1 if x % 2 ==0 else 0, speaker)))

            y_g_train = y_gender[train_idx]
            y_g_eval = y_gender[eval_idx]

        X_train, y_train = convert_spectrograms(train_samples, conv_dim=conv_dim, sr=16000, labels=y_train)
        X_eval, y_eval = convert_spectrograms(eval_samples, conv_dim=conv_dim, sr=16000, labels=y_eval)

        if(augmentation == 'true'):
            X_train_flip = X_train[:, :, :, ::-1]
            y_train_flip = y_train.copy()

            X_train = np.concatenate((X_train, X_train_flip), axis=0)
            y_train = np.concatenate((y_train, y_train_flip), axis=0)

        X_train, y_train = convert_tensor(X_train, y_train)
        X_eval, y_eval = convert_tensor(X_eval, y_eval)

        y_train = y_train.long()
        y_eval = y_eval.long()

        if(multi_task == 'true'):
            _, y_g_train = convert_spectrograms(train_samples, conv_dim=conv_dim, sr=16000, labels=y_g_train)
            _, y_g_eval = convert_spectrograms(eval_samples, conv_dim=conv_dim, sr=16000, labels=y_g_eval)

            if(augmentation == 'true'):
                y_g_train_flip = y_g_train.copy()
                y_g_train = np.concatenate((y_g_train, y_g_train_flip))

            y_g_train = torch.tensor(y_g_train).float()
            y_g_eval = torch.tensor(y_g_eval).float()

            y_g_train = y_g_train.unsqueeze(-1)
            y_g_eval = y_g_eval.unsqueeze(-1)

        if(multi_task == 'true'):
            train_ds = TensorDataset(X_train, y_train, y_g_train)
            eval_ds = TensorDataset(X_eval, y_eval, y_g_eval)
        else:
            train_ds = TensorDataset(X_train, y_train)
            eval_ds = TensorDataset(X_eval, y_eval)

        train_dataloader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=0, drop_last=True)
        eval_dataloader = DataLoader(eval_ds, batch_size=batch_size, num_workers=0)

        model = CLDNN(conv_dim=conv_dim, checkpoint=checkpoint, hidden_size=hidden_size,
                      num_layers=num_layers, bidirectional=bidirectional,
                      with_focus_attn=with_focus_attn).to(device)

        if(multi_task == 'true'):
            model_g = CLDNN_G(conv_dim=conv_dim, checkpoint=checkpoint, hidden_size=hidden_size,
                                num_layers=num_layers, bidirectional=bidirectional,
                                with_focus_attn=with_focus_attn).to(device)

        if(multi_task == 'true'):
            loss_func = nn.CrossEntropyLoss()
            loss_func_g = nn.BCELoss()
            optimizer = optim.Adam(list(model.parameters()) + list(model_g.parameters()), lr=learning_rate)
        else:
            loss_func = nn.CrossEntropyLoss()
            optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        if(use_warmup == 'true'):
            t_total = len(train_dataloader) // 1 * num_epochs
            opt_scheduler = WarmupLinearSchedule(optimizer, warmup_steps=t_total * 0.1, t_total=t_total)

        eval_acc = train(train_dataloader, eval_dataloader, num_epochs)
        cv_eval.append(eval_acc)

    print('conv_dim:', conv_dim, '\twith_focus_attn:', with_focus_attn)
    print('Test accuray:', cv_eval)
    print()
# Out:
# 4041it [00:28, 141.44it/s]
# 449it [00:03, 139.56it/s]
# Start training
# epoch:   1,    lr=0.000200,    loss=1.145764,    train_acc=0.494389,    eval_loss=0.975452,    eval_acc=0.564436
# epoch:   2,    lr=0.000400,    loss=0.999604,    train_acc=0.592781,    eval_loss=0.927232,    eval_acc=0.603390
# epoch:   3,    lr=0.000600,    loss=0.949947,    train_acc=0.618561,    eval_loss=0.928751,    eval_acc=0.599315
# epoch:   4,    lr=0.000800,    loss=0.923217,    train_acc=0.631525,    eval_loss=0.895027,    eval_acc=0.618005
# epoch:   5,    lr=0.001000,    loss=0.904673,    train_acc=0.640466,    eval_loss=0.982887,    eval_acc=0.582636
# Test accuray: 0.57238
# epoch:   6,    lr=0.000978,    loss=0.889310,    train_acc=0.646794,    eval_loss=0.904333,    eval_acc=0.623492
# epoch:   7,    lr=0.000956,    loss=0.874368,    train_acc=0.653000,    eval_loss=0.917226,    eval_acc=0.616212
# epoch:   8,    lr=0.000933,    loss=0.860490,    train_acc=0.658562,    eval_loss=0.890120,    eval_acc=0.616321
# epoch:   9,    lr=0.000911,    loss=0.846037,    train_acc=0.665246,    eval_loss=0.895317,    eval_acc=0.610073
# epoch:  10,    lr=0.000889,    loss=0.826945,    train_acc=0.671900,    eval_loss=0.909821,    eval_acc=0.617299
# Test accuray: 0.57906
# epoch:  11,    lr=0.000867,    loss=0.808135,    train_acc=0.680773,    eval_loss=0.941112,    eval_acc=0.612463
# epoch:  12,    lr=0.000844,    loss=0.780554,    train_acc=0.689383,    eval_loss=0.964364,    eval_acc=0.600511
# epoch:  13,    lr=0.000822,    loss=0.739217,    train_acc=0.706326,    eval_loss=1.024825,    eval_acc=0.596436
# epoch:  14,    lr=0.000800,    loss=0.689224,    train_acc=0.726697,    eval_loss=1.038567,    eval_acc=0.597251
# epoch:  15,    lr=0.000778,    loss=0.626413,    train_acc=0.752330,    eval_loss=1.150384,    eval_acc=0.593774
# Test accuray: 0.60802
# epoch:  16,    lr=0.000756,    loss=0.560354,    train_acc=0.777957,    eval_loss=1.353483,    eval_acc=0.582636
# epoch:  17,    lr=0.000733,    loss=0.492161,    train_acc=0.805656,    eval_loss=1.390579,    eval_acc=0.589101
# epoch:  18,    lr=0.000711,    loss=0.428529,    train_acc=0.830382,    eval_loss=1.541723,    eval_acc=0.581712
# epoch:  19,    lr=0.000689,    loss=0.373464,    train_acc=0.853506,    eval_loss=1.661980,    eval_acc=0.573889
# epoch:  20,    lr=0.000667,    loss=0.321069,    train_acc=0.874393,    eval_loss=1.884315,    eval_acc=0.554765
# Test accuray: 0.58797
# epoch:  21,    lr=0.000644,    loss=0.278301,    train_acc=0.891796,    eval_loss=2.034026,    eval_acc=0.562914
# epoch:  22,    lr=0.000622,    loss=0.241198,    train_acc=0.906851,    eval_loss=2.154237,    eval_acc=0.563077
# epoch:  23,    lr=0.000600,    loss=0.207713,    train_acc=0.919827,    eval_loss=2.305000,    eval_acc=0.564816
# epoch:  24,    lr=0.000578,    loss=0.179129,    train_acc=0.931368,    eval_loss=2.344684,    eval_acc=0.565576
# epoch:  25,    lr=0.000556,    loss=0.157634,    train_acc=0.940591,    eval_loss=2.534377,    eval_acc=0.564979
# Test accuray: 0.60134
# epoch:  26,    lr=0.000533,    loss=0.131924,    train_acc=0.950997,    eval_loss=2.826271,    eval_acc=0.569054
# epoch:  27,    lr=0.000511,    loss=0.116794,    train_acc=0.957221,    eval_loss=2.754945,    eval_acc=0.575682
# epoch:  28,    lr=0.000489,    loss=0.100044,    train_acc=0.963403,    eval_loss=2.888766,    eval_acc=0.568347
# epoch:  29,    lr=0.000467,    loss=0.084469,    train_acc=0.969474,    eval_loss=3.127480,    eval_acc=0.565196
# epoch:  30,    lr=0.000444,    loss=0.076943,    train_acc=0.972129,    eval_loss=3.254899,    eval_acc=0.564273
# Test accuray: 0.60579
# epoch:  31,    lr=0.000422,    loss=0.068546,    train_acc=0.975729,    eval_loss=3.289328,    eval_acc=0.561719
# epoch:  32,    lr=0.000400,    loss=0.055220,    train_acc=0.980457,    eval_loss=3.403726,    eval_acc=0.559817
# epoch:  33,    lr=0.000378,    loss=0.049804,    train_acc=0.982517,    eval_loss=3.745397,    eval_acc=0.559600
# epoch:  34,    lr=0.000356,    loss=0.045400,    train_acc=0.984289,    eval_loss=3.611315,    eval_acc=0.562317
# epoch:  35,    lr=0.000333,    loss=0.039617,    train_acc=0.986411,    eval_loss=3.827218,    eval_acc=0.564055
# Test accuray: 0.61247
# epoch:  36,    lr=0.000311,    loss=0.033506,    train_acc=0.988416,    eval_loss=3.967992,    eval_acc=0.563675
# epoch:  37,    lr=0.000289,    loss=0.030003,    train_acc=0.989986,    eval_loss=3.921733,    eval_acc=0.559220
# epoch:  38,    lr=0.000267,    loss=0.025743,    train_acc=0.991513,    eval_loss=4.066288,    eval_acc=0.561067
# epoch:  39,    lr=0.000244,    loss=0.023548,    train_acc=0.992053,    eval_loss=4.199607,    eval_acc=0.557481
# epoch:  40,    lr=0.000222,    loss=0.019575,    train_acc=0.993586,    eval_loss=4.311086,    eval_acc=0.554004
# Test accuray: 0.59243
# epoch:  41,    lr=0.000200,    loss=0.016480,    train_acc=0.994732,    eval_loss=4.299868,    eval_acc=0.570086
# epoch:  42,    lr=0.000178,    loss=0.014853,    train_acc=0.995088,    eval_loss=4.404168,    eval_acc=0.563947
# epoch:  43,    lr=0.000156,    loss=0.013035,    train_acc=0.996063,    eval_loss=4.383989,    eval_acc=0.565631
# epoch:  44,    lr=0.000133,    loss=0.010810,    train_acc=0.996658,    eval_loss=4.492995,    eval_acc=0.562806
# epoch:  45,    lr=0.000111,    loss=0.008238,    train_acc=0.997639,    eval_loss=4.605075,    eval_acc=0.563132
# Test accuray: 0.6147
# epoch:  46,    lr=0.000089,    loss=0.007253,    train_acc=0.997940,    eval_loss=4.620021,    eval_acc=0.565848
# epoch:  47,    lr=0.000067,    loss=0.006452,    train_acc=0.998142,    eval_loss=4.768097,    eval_acc=0.560415
# epoch:  48,    lr=0.000044,    loss=0.004615,    train_acc=0.998792,    eval_loss=4.792300,    eval_acc=0.566609
# epoch:  49,    lr=0.000022,    loss=0.003743,    train_acc=0.999092,    eval_loss=4.823821,    eval_acc=0.562860
# epoch:  50,    lr=0.000000,    loss=0.003359,    train_acc=0.999258,    eval_loss=4.805515,    eval_acc=0.565142
# 10it [00:00, 97.14it/s]
# Test accuray: 0.61024
# 4041it [00:26, 150.54it/s]
# 449it [00:02, 152.42it/s]
# Start training
# epoch:   1,    lr=0.000200,    loss=1.134331,    train_acc=0.504795,    eval_loss=1.063269,    eval_acc=0.543951
# epoch:   2,    lr=0.000400,    loss=0.996155,    train_acc=0.591232,    eval_loss=1.031240,    eval_acc=0.554123
# epoch:   3,    lr=0.000600,    loss=0.946596,    train_acc=0.617700,    eval_loss=1.007301,    eval_acc=0.597329
# epoch:   4,    lr=0.000800,    loss=0.926464,    train_acc=0.628752,    eval_loss=1.048615,    eval_acc=0.584536
# epoch:   5,    lr=0.001000,    loss=0.909606,    train_acc=0.635380,    eval_loss=1.017928,    eval_acc=0.591266
# Test accuray: 0.5657
# epoch:   6,    lr=0.000978,    loss=0.895379,    train_acc=0.642174,    eval_loss=1.007189,    eval_acc=0.592859
# epoch:   7,    lr=0.000956,    loss=0.882240,    train_acc=0.648259,    eval_loss=0.974077,    eval_acc=0.604572
# epoch:   8,    lr=0.000933,    loss=0.867170,    train_acc=0.651986,    eval_loss=1.011275,    eval_acc=0.587413
# epoch:   9,    lr=0.000911,    loss=0.852197,    train_acc=0.659706,    eval_loss=1.061467,    eval_acc=0.567994
# epoch:  10,    lr=0.000889,    loss=0.837099,    train_acc=0.665284,    eval_loss=1.052066,    eval_acc=0.570254
# Test accuray: 0.60134
# epoch:  11,    lr=0.000867,    loss=0.819026,    train_acc=0.673060,    eval_loss=1.059901,    eval_acc=0.591164
# epoch:  12,    lr=0.000844,    loss=0.789850,    train_acc=0.683507,    eval_loss=1.067645,    eval_acc=0.603956
# epoch:  13,    lr=0.000822,    loss=0.752551,    train_acc=0.697762,    eval_loss=1.157489,    eval_acc=0.581094
# epoch:  14,    lr=0.000800,    loss=0.703514,    train_acc=0.718769,    eval_loss=1.251168,    eval_acc=0.580529
# epoch:  15,    lr=0.000778,    loss=0.639250,    train_acc=0.743749,    eval_loss=1.482254,    eval_acc=0.554637
# Test accuray: 0.60356
# epoch:  16,    lr=0.000756,    loss=0.567685,    train_acc=0.774363,    eval_loss=1.444173,    eval_acc=0.564552
# epoch:  17,    lr=0.000733,    loss=0.490409,    train_acc=0.805749,    eval_loss=1.744528,    eval_acc=0.554431
# epoch:  18,    lr=0.000711,    loss=0.421948,    train_acc=0.834364,    eval_loss=1.864440,    eval_acc=0.551297
# epoch:  19,    lr=0.000689,    loss=0.353697,    train_acc=0.861985,    eval_loss=2.118635,    eval_acc=0.547598
# epoch:  20,    lr=0.000667,    loss=0.296485,    train_acc=0.885503,    eval_loss=2.258777,    eval_acc=0.534806
# Test accuray: 0.5902
# epoch:  21,    lr=0.000644,    loss=0.246924,    train_acc=0.905904,    eval_loss=2.458648,    eval_acc=0.549294
# epoch:  22,    lr=0.000622,    loss=0.202046,    train_acc=0.923381,    eval_loss=2.852616,    eval_acc=0.529104
# epoch:  23,    lr=0.000600,    loss=0.173467,    train_acc=0.934927,    eval_loss=2.819292,    eval_acc=0.537067
# epoch:  24,    lr=0.000578,    loss=0.146702,    train_acc=0.944948,    eval_loss=3.035652,    eval_acc=0.537015
# epoch:  25,    lr=0.000556,    loss=0.124750,    train_acc=0.954501,    eval_loss=3.256266,    eval_acc=0.542307
# Test accuray: 0.59688
# epoch:  26,    lr=0.000533,    loss=0.104714,    train_acc=0.961684,    eval_loss=3.320112,    eval_acc=0.537426
# epoch:  27,    lr=0.000511,    loss=0.091738,    train_acc=0.967164,    eval_loss=3.594917,    eval_acc=0.537940
# epoch:  28,    lr=0.000489,    loss=0.081291,    train_acc=0.970385,    eval_loss=3.822365,    eval_acc=0.534395
# epoch:  29,    lr=0.000467,    loss=0.070919,    train_acc=0.974545,    eval_loss=3.774105,    eval_acc=0.536707
# epoch:  30,    lr=0.000444,    loss=0.062150,    train_acc=0.977784,    eval_loss=4.047144,    eval_acc=0.533368
# Test accuray: 0.5902
# epoch:  31,    lr=0.000422,    loss=0.053774,    train_acc=0.981086,    eval_loss=4.129672,    eval_acc=0.543231
# epoch:  32,    lr=0.000400,    loss=0.046554,    train_acc=0.983338,    eval_loss=4.210953,    eval_acc=0.538865
# epoch:  33,    lr=0.000378,    loss=0.040258,    train_acc=0.985628,    eval_loss=4.307345,    eval_acc=0.535114
# epoch:  34,    lr=0.000356,    loss=0.037091,    train_acc=0.987121,    eval_loss=4.588994,    eval_acc=0.542255
# epoch:  35,    lr=0.000333,    loss=0.035271,    train_acc=0.987948,    eval_loss=4.587708,    eval_acc=0.541125
# Test accuray: 0.59911
# epoch:  36,    lr=0.000311,    loss=0.029618,    train_acc=0.989880,    eval_loss=4.647336,    eval_acc=0.540406
# epoch:  37,    lr=0.000289,    loss=0.024533,    train_acc=0.991533,    eval_loss=4.838480,    eval_acc=0.540714
# epoch:  38,    lr=0.000267,    loss=0.023927,    train_acc=0.991953,    eval_loss=4.834470,    eval_acc=0.536912
# epoch:  39,    lr=0.000244,    loss=0.020246,    train_acc=0.993224,    eval_loss=4.867358,    eval_acc=0.541844
# epoch:  40,    lr=0.000222,    loss=0.017056,    train_acc=0.994317,    eval_loss=5.157032,    eval_acc=0.535525
# Test accuray: 0.59243
# epoch:  41,    lr=0.000200,    loss=0.014891,    train_acc=0.995125,    eval_loss=5.213437,    eval_acc=0.535782
# epoch:  42,    lr=0.000178,    loss=0.012469,    train_acc=0.995958,    eval_loss=5.200058,    eval_acc=0.539019
# epoch:  43,    lr=0.000156,    loss=0.011822,    train_acc=0.996168,    eval_loss=5.124404,    eval_acc=0.540560
# epoch:  44,    lr=0.000133,    loss=0.009716,    train_acc=0.996902,    eval_loss=5.425433,    eval_acc=0.540303
# epoch:  45,    lr=0.000111,    loss=0.007085,    train_acc=0.997951,    eval_loss=5.461900,    eval_acc=0.543797
# Test accuray: 0.57906
# epoch:  46,    lr=0.000089,    loss=0.005839,    train_acc=0.998396,    eval_loss=5.529992,    eval_acc=0.539481
# epoch:  47,    lr=0.000067,    loss=0.005407,    train_acc=0.998439,    eval_loss=5.528521,    eval_acc=0.539327
# epoch:  48,    lr=0.000044,    loss=0.004319,    train_acc=0.998846,    eval_loss=5.509455,    eval_acc=0.543026
# epoch:  49,    lr=0.000022,    loss=0.003355,    train_acc=0.999222,    eval_loss=5.495588,    eval_acc=0.542872
# epoch:  50,    lr=0.000000,    loss=0.002953,    train_acc=0.999297,    eval_loss=5.516471,    eval_acc=0.543488
# 13it [00:00, 121.48it/s]
# Test accuray: 0.58797
# 4041it [00:26, 152.89it/s]
# 449it [00:03, 133.03it/s]
# Start training
# epoch:   1,    lr=0.000200,    loss=1.122892,    train_acc=0.503592,    eval_loss=1.054889,    eval_acc=0.545941
# epoch:   2,    lr=0.000400,    loss=1.000687,    train_acc=0.591584,    eval_loss=1.028591,    eval_acc=0.559883
# epoch:   3,    lr=0.000600,    loss=0.967778,    train_acc=0.610264,    eval_loss=1.025362,    eval_acc=0.568731
# epoch:   4,    lr=0.000800,    loss=0.942446,    train_acc=0.622525,    eval_loss=1.068094,    eval_acc=0.563124
# epoch:   5,    lr=0.001000,    loss=0.919155,    train_acc=0.634121,    eval_loss=1.103954,    eval_acc=0.570789
# Test accuray: 0.52784
# epoch:   6,    lr=0.000978,    loss=0.897082,    train_acc=0.643957,    eval_loss=1.049303,    eval_acc=0.559317
# epoch:   7,    lr=0.000956,    loss=0.878778,    train_acc=0.651159,    eval_loss=1.242520,    eval_acc=0.538070
# epoch:   8,    lr=0.000933,    loss=0.863506,    train_acc=0.656324,    eval_loss=1.059775,    eval_acc=0.585040
# epoch:   9,    lr=0.000911,    loss=0.848030,    train_acc=0.663223,    eval_loss=1.037811,    eval_acc=0.590596
# epoch:  10,    lr=0.000889,    loss=0.832531,    train_acc=0.668925,    eval_loss=1.083954,    eval_acc=0.576808
# Test accuray: 0.59465
# epoch:  11,    lr=0.000867,    loss=0.811360,    train_acc=0.677768,    eval_loss=1.211808,    eval_acc=0.556642
# epoch:  12,    lr=0.000844,    loss=0.784946,    train_acc=0.687031,    eval_loss=1.139642,    eval_acc=0.580564
# epoch:  13,    lr=0.000822,    loss=0.753201,    train_acc=0.699632,    eval_loss=1.160560,    eval_acc=0.567239
# epoch:  14,    lr=0.000800,    loss=0.707529,    train_acc=0.719398,    eval_loss=1.183276,    eval_acc=0.573259
# epoch:  15,    lr=0.000778,    loss=0.648009,    train_acc=0.742990,    eval_loss=1.317976,    eval_acc=0.544809
# Test accuray: 0.61024
# epoch:  16,    lr=0.000756,    loss=0.582500,    train_acc=0.770426,    eval_loss=1.445963,    eval_acc=0.561683
# epoch:  17,    lr=0.000733,    loss=0.512848,    train_acc=0.798578,    eval_loss=1.730760,    eval_acc=0.541414
# epoch:  18,    lr=0.000711,    loss=0.446003,    train_acc=0.825144,    eval_loss=1.798488,    eval_acc=0.557876
# epoch:  19,    lr=0.000689,    loss=0.380974,    train_acc=0.851038,    eval_loss=1.954166,    eval_acc=0.541259
# epoch:  20,    lr=0.000667,    loss=0.325858,    train_acc=0.874019,    eval_loss=2.138730,    eval_acc=0.525414
# Test accuray: 0.60579
# epoch:  21,    lr=0.000644,    loss=0.276758,    train_acc=0.893383,    eval_loss=2.258972,    eval_acc=0.528552
# epoch:  22,    lr=0.000622,    loss=0.236300,    train_acc=0.909366,    eval_loss=2.543207,    eval_acc=0.535497
# epoch:  23,    lr=0.000600,    loss=0.199736,    train_acc=0.924109,    eval_loss=2.632437,    eval_acc=0.527215
# epoch:  24,    lr=0.000578,    loss=0.170112,    train_acc=0.935550,    eval_loss=2.892369,    eval_acc=0.529221
# epoch:  25,    lr=0.000556,    loss=0.142601,    train_acc=0.946485,    eval_loss=3.079584,    eval_acc=0.527369
# Test accuray: 0.60356
# epoch:  26,    lr=0.000533,    loss=0.123010,    train_acc=0.954705,    eval_loss=3.346986,    eval_acc=0.523974
# epoch:  27,    lr=0.000511,    loss=0.105366,    train_acc=0.961308,    eval_loss=3.378620,    eval_acc=0.527781
# epoch:  28,    lr=0.000489,    loss=0.090738,    train_acc=0.967164,    eval_loss=3.709728,    eval_acc=0.523048
# epoch:  29,    lr=0.000467,    loss=0.078712,    train_acc=0.972113,    eval_loss=3.826569,    eval_acc=0.518418
# epoch:  30,    lr=0.000444,    loss=0.068793,    train_acc=0.975779,    eval_loss=3.990367,    eval_acc=0.528964
# Test accuray: 0.5902
# epoch:  31,    lr=0.000422,    loss=0.063202,    train_acc=0.977858,    eval_loss=3.924314,    eval_acc=0.534108
# epoch:  32,    lr=0.000400,    loss=0.053212,    train_acc=0.981191,    eval_loss=4.255940,    eval_acc=0.525105
# epoch:  33,    lr=0.000378,    loss=0.049355,    train_acc=0.983240,    eval_loss=4.105067,    eval_acc=0.527266
# epoch:  34,    lr=0.000356,    loss=0.040744,    train_acc=0.986220,    eval_loss=4.307399,    eval_acc=0.529067
# epoch:  35,    lr=0.000333,    loss=0.035545,    train_acc=0.988238,    eval_loss=4.538340,    eval_acc=0.530096
# Test accuray: 0.60579
# epoch:  36,    lr=0.000311,    loss=0.029550,    train_acc=0.990077,    eval_loss=4.618293,    eval_acc=0.533440
# epoch:  37,    lr=0.000289,    loss=0.028071,    train_acc=0.990534,    eval_loss=4.735709,    eval_acc=0.534571
# epoch:  38,    lr=0.000267,    loss=0.023908,    train_acc=0.992348,    eval_loss=4.687661,    eval_acc=0.543472
# epoch:  39,    lr=0.000244,    loss=0.019606,    train_acc=0.993749,    eval_loss=4.848760,    eval_acc=0.539767
# epoch:  40,    lr=0.000222,    loss=0.019240,    train_acc=0.993780,    eval_loss=4.933667,    eval_acc=0.529478
# Test accuray: 0.61693
# epoch:  41,    lr=0.000200,    loss=0.016440,    train_acc=0.994742,    eval_loss=5.113806,    eval_acc=0.535755
# epoch:  42,    lr=0.000178,    loss=0.013387,    train_acc=0.995705,    eval_loss=5.144204,    eval_acc=0.534057
# epoch:  43,    lr=0.000156,    loss=0.011539,    train_acc=0.996501,    eval_loss=5.137085,    eval_acc=0.535806
# epoch:  44,    lr=0.000133,    loss=0.009634,    train_acc=0.997032,    eval_loss=5.356976,    eval_acc=0.536526
# epoch:  45,    lr=0.000111,    loss=0.008356,    train_acc=0.997507,    eval_loss=5.421445,    eval_acc=0.534211
# Test accuray: 0.60356
# epoch:  46,    lr=0.000089,    loss=0.007742,    train_acc=0.997815,    eval_loss=5.337639,    eval_acc=0.535086
# epoch:  47,    lr=0.000067,    loss=0.006052,    train_acc=0.998309,    eval_loss=5.456274,    eval_acc=0.537813
# epoch:  48,    lr=0.000044,    loss=0.004767,    train_acc=0.998686,    eval_loss=5.519028,    eval_acc=0.536526
# epoch:  49,    lr=0.000022,    loss=0.004004,    train_acc=0.998982,    eval_loss=5.578330,    eval_acc=0.531793
# epoch:  50,    lr=0.000000,    loss=0.003270,    train_acc=0.999303,    eval_loss=5.576741,    eval_acc=0.534520
# 18it [00:00, 175.54it/s]
# Test accuray: 0.59688
# 4041it [00:26, 150.68it/s]
# 449it [00:03, 139.44it/s]
# Start training
# epoch:   1,    lr=0.000200,    loss=1.144920,    train_acc=0.491032,    eval_loss=1.038871,    eval_acc=0.594206
# epoch:   2,    lr=0.000400,    loss=1.014668,    train_acc=0.578412,    eval_loss=0.944145,    eval_acc=0.663498
# epoch:   3,    lr=0.000600,    loss=0.959869,    train_acc=0.608073,    eval_loss=0.888004,    eval_acc=0.688440
# epoch:   4,    lr=0.000800,    loss=0.932449,    train_acc=0.621681,    eval_loss=0.846709,    eval_acc=0.702869
# epoch:   5,    lr=0.001000,    loss=0.912382,    train_acc=0.631254,    eval_loss=0.886670,    eval_acc=0.673676
# Test accuray: 0.6882
# epoch:   6,    lr=0.000978,    loss=0.892746,    train_acc=0.639714,    eval_loss=0.871824,    eval_acc=0.682121
# epoch:   7,    lr=0.000956,    loss=0.875067,    train_acc=0.647741,    eval_loss=0.919950,    eval_acc=0.651753
# epoch:   8,    lr=0.000933,    loss=0.862153,    train_acc=0.651842,    eval_loss=0.932563,    eval_acc=0.636821
# epoch:   9,    lr=0.000911,    loss=0.849390,    train_acc=0.656635,    eval_loss=0.889354,    eval_acc=0.668419
# epoch:  10,    lr=0.000889,    loss=0.835024,    train_acc=0.664007,    eval_loss=0.908935,    eval_acc=0.656171
# Test accuray: 0.69488
# epoch:  11,    lr=0.000867,    loss=0.819506,    train_acc=0.669057,    eval_loss=0.906433,    eval_acc=0.664616
# epoch:  12,    lr=0.000844,    loss=0.796538,    train_acc=0.678532,    eval_loss=0.968514,    eval_acc=0.637269
# epoch:  13,    lr=0.000822,    loss=0.763903,    train_acc=0.690306,    eval_loss=0.938060,    eval_acc=0.660366
# epoch:  14,    lr=0.000800,    loss=0.722387,    train_acc=0.706952,    eval_loss=1.013623,    eval_acc=0.643309
# epoch:  15,    lr=0.000778,    loss=0.667275,    train_acc=0.729399,    eval_loss=1.040774,    eval_acc=0.643364
# Test accuray: 0.69488
# epoch:  16,    lr=0.000756,    loss=0.601705,    train_acc=0.755734,    eval_loss=1.168423,    eval_acc=0.629663
# epoch:  17,    lr=0.000733,    loss=0.534156,    train_acc=0.783469,    eval_loss=1.260672,    eval_acc=0.605503
# epoch:  18,    lr=0.000711,    loss=0.468762,    train_acc=0.811632,    eval_loss=1.458478,    eval_acc=0.599239
# epoch:  19,    lr=0.000689,    loss=0.406872,    train_acc=0.838175,    eval_loss=1.623781,    eval_acc=0.605503
# epoch:  20,    lr=0.000667,    loss=0.351931,    train_acc=0.860384,    eval_loss=1.742498,    eval_acc=0.583189
# Test accuray: 0.6637
# epoch:  21,    lr=0.000644,    loss=0.302017,    train_acc=0.880814,    eval_loss=1.926068,    eval_acc=0.595157
# epoch:  22,    lr=0.000622,    loss=0.265001,    train_acc=0.895656,    eval_loss=1.983930,    eval_acc=0.604440
# epoch:  23,    lr=0.000600,    loss=0.223690,    train_acc=0.912455,    eval_loss=2.181541,    eval_acc=0.581735
# epoch:  24,    lr=0.000578,    loss=0.194333,    train_acc=0.924589,    eval_loss=2.310862,    eval_acc=0.596331
# epoch:  25,    lr=0.000556,    loss=0.166322,    train_acc=0.936730,    eval_loss=2.491095,    eval_acc=0.593759
# Test accuray: 0.68597
# epoch:  26,    lr=0.000533,    loss=0.141302,    train_acc=0.946969,    eval_loss=2.642813,    eval_acc=0.572787
# epoch:  27,    lr=0.000511,    loss=0.124182,    train_acc=0.953755,    eval_loss=2.832600,    eval_acc=0.581791
# epoch:  28,    lr=0.000489,    loss=0.104787,    train_acc=0.960938,    eval_loss=2.878826,    eval_acc=0.583021
# epoch:  29,    lr=0.000467,    loss=0.095576,    train_acc=0.965155,    eval_loss=3.132247,    eval_acc=0.588222
# epoch:  30,    lr=0.000444,    loss=0.076613,    train_acc=0.971898,    eval_loss=3.391780,    eval_acc=0.580504
# Test accuray: 0.67929
# epoch:  31,    lr=0.000422,    loss=0.070519,    train_acc=0.974722,    eval_loss=3.381475,    eval_acc=0.576086
# epoch:  32,    lr=0.000400,    loss=0.061703,    train_acc=0.978164,    eval_loss=3.440367,    eval_acc=0.586880
# epoch:  33,    lr=0.000378,    loss=0.054450,    train_acc=0.981013,    eval_loss=3.535984,    eval_acc=0.577373
# epoch:  34,    lr=0.000356,    loss=0.047434,    train_acc=0.983458,    eval_loss=3.712489,    eval_acc=0.574073
# epoch:  35,    lr=0.000333,    loss=0.041955,    train_acc=0.985695,    eval_loss=3.719511,    eval_acc=0.584195
# Test accuray: 0.67706
# epoch:  36,    lr=0.000311,    loss=0.035261,    train_acc=0.988018,    eval_loss=3.786251,    eval_acc=0.582518
# epoch:  37,    lr=0.000289,    loss=0.031675,    train_acc=0.989638,    eval_loss=3.961065,    eval_acc=0.583748
# epoch:  38,    lr=0.000267,    loss=0.026461,    train_acc=0.990885,    eval_loss=4.023777,    eval_acc=0.592305
# epoch:  39,    lr=0.000244,    loss=0.023532,    train_acc=0.992151,    eval_loss=4.116130,    eval_acc=0.596443
# epoch:  40,    lr=0.000222,    loss=0.020115,    train_acc=0.993410,    eval_loss=4.189883,    eval_acc=0.585650
# Test accuray: 0.67929
# epoch:  41,    lr=0.000200,    loss=0.016760,    train_acc=0.994828,    eval_loss=4.357636,    eval_acc=0.584755
# epoch:  42,    lr=0.000178,    loss=0.013817,    train_acc=0.995764,    eval_loss=4.402486,    eval_acc=0.590124
# epoch:  43,    lr=0.000156,    loss=0.012433,    train_acc=0.996222,    eval_loss=4.397593,    eval_acc=0.585594
# epoch:  44,    lr=0.000133,    loss=0.010697,    train_acc=0.996907,    eval_loss=4.448533,    eval_acc=0.588278
# epoch:  45,    lr=0.000111,    loss=0.009568,    train_acc=0.997194,    eval_loss=4.512600,    eval_acc=0.584699
# Test accuray: 0.67038
# epoch:  46,    lr=0.000089,    loss=0.007119,    train_acc=0.997958,    eval_loss=4.638918,    eval_acc=0.589788
# epoch:  47,    lr=0.000067,    loss=0.005420,    train_acc=0.998594,    eval_loss=4.724291,    eval_acc=0.586265
# epoch:  48,    lr=0.000044,    loss=0.004569,    train_acc=0.998851,    eval_loss=4.680606,    eval_acc=0.595213
# epoch:  49,    lr=0.000022,    loss=0.003992,    train_acc=0.998997,    eval_loss=4.754178,    eval_acc=0.593479
# epoch:  50,    lr=0.000000,    loss=0.003565,    train_acc=0.999138,    eval_loss=4.744122,    eval_acc=0.592808
# 17it [00:00, 167.14it/s]
# Test accuray: 0.68374
# 4041it [00:27, 146.48it/s]
# 449it [00:02, 150.06it/s]
# Start training
# epoch:   1,    lr=0.000200,    loss=1.137610,    train_acc=0.497965,    eval_loss=1.108246,    eval_acc=0.529388
# epoch:   2,    lr=0.000400,    loss=0.998736,    train_acc=0.587153,    eval_loss=1.098290,    eval_acc=0.537263
# epoch:   3,    lr=0.000600,    loss=0.956651,    train_acc=0.611471,    eval_loss=1.045356,    eval_acc=0.564653
# epoch:   4,    lr=0.000800,    loss=0.931836,    train_acc=0.623530,    eval_loss=1.067405,    eval_acc=0.563947
# epoch:   5,    lr=0.001000,    loss=0.914995,    train_acc=0.632011,    eval_loss=1.103991,    eval_acc=0.551252
# Test accuray: 0.61693
# epoch:   6,    lr=0.000978,    loss=0.895906,    train_acc=0.641348,    eval_loss=1.090756,    eval_acc=0.569296
# epoch:   7,    lr=0.000956,    loss=0.874147,    train_acc=0.652070,    eval_loss=1.072761,    eval_acc=0.562537
# epoch:   8,    lr=0.000933,    loss=0.860043,    train_acc=0.657908,    eval_loss=1.059622,    eval_acc=0.582344
# epoch:   9,    lr=0.000911,    loss=0.846032,    train_acc=0.663880,    eval_loss=1.099452,    eval_acc=0.558951
# epoch:  10,    lr=0.000889,    loss=0.831338,    train_acc=0.669724,    eval_loss=1.056237,    eval_acc=0.577701
# Test accuray: 0.61024
# epoch:  11,    lr=0.000867,    loss=0.813925,    train_acc=0.675307,    eval_loss=1.072469,    eval_acc=0.577877
# epoch:  12,    lr=0.000844,    loss=0.791180,    train_acc=0.684827,    eval_loss=1.098990,    eval_acc=0.565123
# epoch:  13,    lr=0.000822,    loss=0.755394,    train_acc=0.698131,    eval_loss=1.161775,    eval_acc=0.564182
# epoch:  14,    lr=0.000800,    loss=0.706068,    train_acc=0.717912,    eval_loss=1.161554,    eval_acc=0.562478
# epoch:  15,    lr=0.000778,    loss=0.641901,    train_acc=0.743409,    eval_loss=1.288400,    eval_acc=0.554955
# Test accuray: 0.61247
# epoch:  16,    lr=0.000756,    loss=0.563926,    train_acc=0.775849,    eval_loss=1.465981,    eval_acc=0.544375
# epoch:  17,    lr=0.000733,    loss=0.488302,    train_acc=0.807579,    eval_loss=1.612404,    eval_acc=0.524568
# epoch:  18,    lr=0.000711,    loss=0.411410,    train_acc=0.837651,    eval_loss=1.732636,    eval_acc=0.529152
# epoch:  19,    lr=0.000689,    loss=0.345966,    train_acc=0.865268,    eval_loss=1.920476,    eval_acc=0.530622
# epoch:  20,    lr=0.000667,    loss=0.292658,    train_acc=0.886524,    eval_loss=2.174056,    eval_acc=0.528036
# Test accuray: 0.60802
# epoch:  21,    lr=0.000644,    loss=0.243315,    train_acc=0.906268,    eval_loss=2.358404,    eval_acc=0.524979
# epoch:  22,    lr=0.000622,    loss=0.203586,    train_acc=0.922191,    eval_loss=2.591430,    eval_acc=0.523804
# epoch:  23,    lr=0.000600,    loss=0.170098,    train_acc=0.935775,    eval_loss=2.709246,    eval_acc=0.519984
# epoch:  24,    lr=0.000578,    loss=0.147574,    train_acc=0.944231,    eval_loss=2.997692,    eval_acc=0.515223
# epoch:  25,    lr=0.000556,    loss=0.124237,    train_acc=0.953720,    eval_loss=3.100104,    eval_acc=0.520042
# Test accuray: 0.60356
# epoch:  26,    lr=0.000533,    loss=0.103769,    train_acc=0.962450,    eval_loss=3.374180,    eval_acc=0.518984
# epoch:  27,    lr=0.000511,    loss=0.090456,    train_acc=0.967122,    eval_loss=3.526468,    eval_acc=0.530916
# epoch:  28,    lr=0.000489,    loss=0.080029,    train_acc=0.970919,    eval_loss=3.742155,    eval_acc=0.521277
# epoch:  29,    lr=0.000467,    loss=0.068704,    train_acc=0.975451,    eval_loss=3.927246,    eval_acc=0.517045
# epoch:  30,    lr=0.000444,    loss=0.062104,    train_acc=0.978282,    eval_loss=4.060917,    eval_acc=0.531268
# Test accuray: 0.60802
# epoch:  31,    lr=0.000422,    loss=0.052352,    train_acc=0.981824,    eval_loss=4.136580,    eval_acc=0.509639
# epoch:  32,    lr=0.000400,    loss=0.047853,    train_acc=0.983275,    eval_loss=4.218843,    eval_acc=0.523392
# epoch:  33,    lr=0.000378,    loss=0.044033,    train_acc=0.984539,    eval_loss=4.346541,    eval_acc=0.523921
# epoch:  34,    lr=0.000356,    loss=0.035505,    train_acc=0.987765,    eval_loss=4.432868,    eval_acc=0.529152
# epoch:  35,    lr=0.000333,    loss=0.032803,    train_acc=0.988707,    eval_loss=4.712951,    eval_acc=0.518573
# Test accuray: 0.61247
# epoch:  36,    lr=0.000311,    loss=0.026584,    train_acc=0.991045,    eval_loss=4.546662,    eval_acc=0.521629
# epoch:  37,    lr=0.000289,    loss=0.023520,    train_acc=0.992358,    eval_loss=4.786880,    eval_acc=0.520748
# epoch:  38,    lr=0.000267,    loss=0.024146,    train_acc=0.991926,    eval_loss=4.809291,    eval_acc=0.523510
# epoch:  39,    lr=0.000244,    loss=0.018996,    train_acc=0.993755,    eval_loss=4.983460,    eval_acc=0.527742
# epoch:  40,    lr=0.000222,    loss=0.014909,    train_acc=0.995195,    eval_loss=4.997972,    eval_acc=0.522452
# Test accuray: 0.59911
# epoch:  41,    lr=0.000200,    loss=0.014262,    train_acc=0.995286,    eval_loss=5.171876,    eval_acc=0.520219
# epoch:  42,    lr=0.000178,    loss=0.011627,    train_acc=0.996428,    eval_loss=5.268632,    eval_acc=0.525920
# epoch:  43,    lr=0.000156,    loss=0.011344,    train_acc=0.996410,    eval_loss=5.274794,    eval_acc=0.524686
# epoch:  44,    lr=0.000133,    loss=0.008856,    train_acc=0.997357,    eval_loss=5.493480,    eval_acc=0.526449
# epoch:  45,    lr=0.000111,    loss=0.008174,    train_acc=0.997388,    eval_loss=5.436676,    eval_acc=0.527037
# Test accuray: 0.60579
# epoch:  46,    lr=0.000089,    loss=0.005349,    train_acc=0.998572,    eval_loss=5.612425,    eval_acc=0.529917
# epoch:  47,    lr=0.000067,    loss=0.004700,    train_acc=0.998785,    eval_loss=5.691927,    eval_acc=0.528682
# epoch:  48,    lr=0.000044,    loss=0.004226,    train_acc=0.998967,    eval_loss=5.729197,    eval_acc=0.527037
# epoch:  49,    lr=0.000022,    loss=0.003798,    train_acc=0.999077,    eval_loss=5.772602,    eval_acc=0.528095
# epoch:  50,    lr=0.000000,    loss=0.002616,    train_acc=0.999399,    eval_loss=5.809468,    eval_acc=0.526331
# 18it [00:00, 172.26it/s]
# Test accuray: 0.60802
# 4041it [00:26, 154.00it/s]
# 449it [00:02, 171.00it/s]
# Start training
# epoch:   1,    lr=0.000200,    loss=1.128229,    train_acc=0.502992,    eval_loss=1.040221,    eval_acc=0.560176
# epoch:   2,    lr=0.000400,    loss=0.980787,    train_acc=0.599369,    eval_loss=1.002814,    eval_acc=0.590365
# epoch:   3,    lr=0.000600,    loss=0.942731,    train_acc=0.619205,    eval_loss=1.111848,    eval_acc=0.541674
# epoch:   4,    lr=0.000800,    loss=0.921155,    train_acc=0.628352,    eval_loss=1.105911,    eval_acc=0.553016
# epoch:   5,    lr=0.001000,    loss=0.905803,    train_acc=0.636810,    eval_loss=1.117677,    eval_acc=0.558744
# Test accuray: 0.53229
# epoch:   6,    lr=0.000978,    loss=0.892758,    train_acc=0.643501,    eval_loss=1.007829,    eval_acc=0.575242
# epoch:   7,    lr=0.000956,    loss=0.879278,    train_acc=0.648986,    eval_loss=1.007086,    eval_acc=0.590422
# epoch:   8,    lr=0.000933,    loss=0.868656,    train_acc=0.653837,    eval_loss=1.037538,    eval_acc=0.582975
# epoch:   9,    lr=0.000911,    loss=0.857542,    train_acc=0.658639,    eval_loss=1.031530,    eval_acc=0.584350
# epoch:  10,    lr=0.000889,    loss=0.846312,    train_acc=0.662240,    eval_loss=1.078023,    eval_acc=0.569055
# Test accuray: 0.54788
# epoch:  11,    lr=0.000867,    loss=0.830232,    train_acc=0.669163,    eval_loss=1.052741,    eval_acc=0.572836
# epoch:  12,    lr=0.000844,    loss=0.807476,    train_acc=0.677140,    eval_loss=1.064175,    eval_acc=0.586298
# epoch:  13,    lr=0.000822,    loss=0.773255,    train_acc=0.688707,    eval_loss=1.086624,    eval_acc=0.580340
# epoch:  14,    lr=0.000800,    loss=0.721762,    train_acc=0.710846,    eval_loss=1.171748,    eval_acc=0.567222
# epoch:  15,    lr=0.000778,    loss=0.658793,    train_acc=0.735758,    eval_loss=1.274574,    eval_acc=0.555536
# Test accuray: 0.58575
# epoch:  16,    lr=0.000756,    loss=0.583016,    train_acc=0.766813,    eval_loss=1.350328,    eval_acc=0.556510
# epoch:  17,    lr=0.000733,    loss=0.505076,    train_acc=0.798862,    eval_loss=1.460855,    eval_acc=0.565160
# epoch:  18,    lr=0.000711,    loss=0.425277,    train_acc=0.831288,    eval_loss=1.724485,    eval_acc=0.551584
# epoch:  19,    lr=0.000689,    loss=0.361899,    train_acc=0.856852,    eval_loss=1.866176,    eval_acc=0.542934
# epoch:  20,    lr=0.000667,    loss=0.306181,    train_acc=0.879406,    eval_loss=2.052762,    eval_acc=0.538409
# Test accuray: 0.58129
# epoch:  21,    lr=0.000644,    loss=0.254913,    train_acc=0.900382,    eval_loss=2.266580,    eval_acc=0.534456
# epoch:  22,    lr=0.000622,    loss=0.217922,    train_acc=0.916573,    eval_loss=2.453153,    eval_acc=0.549063
# epoch:  23,    lr=0.000600,    loss=0.182351,    train_acc=0.929529,    eval_loss=2.678492,    eval_acc=0.532909
# epoch:  24,    lr=0.000578,    loss=0.158679,    train_acc=0.939694,    eval_loss=2.720302,    eval_acc=0.543679
# epoch:  25,    lr=0.000556,    loss=0.134199,    train_acc=0.949578,    eval_loss=3.194794,    eval_acc=0.529129
# Test accuray: 0.58129
# epoch:  26,    lr=0.000533,    loss=0.115740,    train_acc=0.956769,    eval_loss=3.206123,    eval_acc=0.524546
# epoch:  27,    lr=0.000511,    loss=0.098237,    train_acc=0.963893,    eval_loss=3.242963,    eval_acc=0.538065
# epoch:  28,    lr=0.000489,    loss=0.083896,    train_acc=0.969847,    eval_loss=3.644826,    eval_acc=0.540013
# epoch:  29,    lr=0.000467,    loss=0.076003,    train_acc=0.972480,    eval_loss=3.686256,    eval_acc=0.528155
# epoch:  30,    lr=0.000444,    loss=0.067148,    train_acc=0.975862,    eval_loss=3.984369,    eval_acc=0.532279
# Test accuray: 0.57906
# epoch:  31,    lr=0.000422,    loss=0.057404,    train_acc=0.979731,    eval_loss=3.968446,    eval_acc=0.540356
# epoch:  32,    lr=0.000400,    loss=0.050826,    train_acc=0.982321,    eval_loss=4.161819,    eval_acc=0.527525
# epoch:  33,    lr=0.000378,    loss=0.044406,    train_acc=0.984814,    eval_loss=4.320522,    eval_acc=0.538810
# epoch:  34,    lr=0.000356,    loss=0.036267,    train_acc=0.987641,    eval_loss=4.481558,    eval_acc=0.538351
# epoch:  35,    lr=0.000333,    loss=0.035648,    train_acc=0.987727,    eval_loss=4.445705,    eval_acc=0.535544
# Test accuray: 0.58129
# epoch:  36,    lr=0.000311,    loss=0.029732,    train_acc=0.989988,    eval_loss=4.649396,    eval_acc=0.527467
# epoch:  37,    lr=0.000289,    loss=0.026754,    train_acc=0.991340,    eval_loss=4.793926,    eval_acc=0.533196
# epoch:  38,    lr=0.000267,    loss=0.021923,    train_acc=0.992870,    eval_loss=5.007170,    eval_acc=0.527181
# epoch:  39,    lr=0.000244,    loss=0.020405,    train_acc=0.993437,    eval_loss=4.880344,    eval_acc=0.531248
# epoch:  40,    lr=0.000222,    loss=0.017480,    train_acc=0.994339,    eval_loss=5.154472,    eval_acc=0.534399
# Test accuray: 0.5902
# epoch:  41,    lr=0.000200,    loss=0.014424,    train_acc=0.995454,    eval_loss=5.207837,    eval_acc=0.535945
# epoch:  42,    lr=0.000178,    loss=0.012942,    train_acc=0.995996,    eval_loss=5.201011,    eval_acc=0.530274
# epoch:  43,    lr=0.000156,    loss=0.010028,    train_acc=0.996874,    eval_loss=5.323604,    eval_acc=0.531936
# epoch:  44,    lr=0.000133,    loss=0.009054,    train_acc=0.997325,    eval_loss=5.375872,    eval_acc=0.535888
# epoch:  45,    lr=0.000111,    loss=0.007803,    train_acc=0.997648,    eval_loss=5.482668,    eval_acc=0.528728
# Test accuray: 0.5902
# epoch:  46,    lr=0.000089,    loss=0.005690,    train_acc=0.998391,    eval_loss=5.664146,    eval_acc=0.536346
# epoch:  47,    lr=0.000067,    loss=0.004830,    train_acc=0.998739,    eval_loss=5.640508,    eval_acc=0.540184
# epoch:  48,    lr=0.000044,    loss=0.004048,    train_acc=0.998952,    eval_loss=5.740116,    eval_acc=0.539039
# epoch:  49,    lr=0.000022,    loss=0.003626,    train_acc=0.999141,    eval_loss=5.622464,    eval_acc=0.539211
# epoch:  50,    lr=0.000000,    loss=0.003028,    train_acc=0.999330,    eval_loss=5.651979,    eval_acc=0.538981
# 17it [00:00, 161.29it/s]
# Test accuray: 0.59911
# 4041it [00:25, 156.22it/s]
# 449it [00:02, 159.15it/s]
# Start training
# epoch:   1,    lr=0.000200,    loss=1.162923,    train_acc=0.484762,    eval_loss=1.146793,    eval_acc=0.521399
# epoch:   2,    lr=0.000400,    loss=1.002536,    train_acc=0.583683,    eval_loss=1.127047,    eval_acc=0.558190
# epoch:   3,    lr=0.000600,    loss=0.925923,    train_acc=0.628611,    eval_loss=1.158791,    eval_acc=0.509118
# epoch:   4,    lr=0.000800,    loss=0.896138,    train_acc=0.641012,    eval_loss=1.096435,    eval_acc=0.559466
# epoch:   5,    lr=0.001000,    loss=0.879179,    train_acc=0.648548,    eval_loss=1.071605,    eval_acc=0.565368
# Test accuray: 0.59465
# epoch:   6,    lr=0.000978,    loss=0.862817,    train_acc=0.653314,    eval_loss=1.294675,    eval_acc=0.465788
# epoch:   7,    lr=0.000956,    loss=0.842159,    train_acc=0.662699,    eval_loss=1.231891,    eval_acc=0.541709
# epoch:   8,    lr=0.000933,    loss=0.828345,    train_acc=0.667662,    eval_loss=1.169254,    eval_acc=0.543729
# epoch:   9,    lr=0.000911,    loss=0.812619,    train_acc=0.674792,    eval_loss=1.125507,    eval_acc=0.562231
# epoch:  10,    lr=0.000889,    loss=0.795617,    train_acc=0.680425,    eval_loss=1.229188,    eval_acc=0.511564
# Test accuray: 0.5657
# epoch:  11,    lr=0.000867,    loss=0.770906,    train_acc=0.690964,    eval_loss=1.200308,    eval_acc=0.528311
# epoch:  12,    lr=0.000844,    loss=0.740784,    train_acc=0.703770,    eval_loss=1.303439,    eval_acc=0.525068
# epoch:  13,    lr=0.000822,    loss=0.695682,    train_acc=0.721477,    eval_loss=1.318721,    eval_acc=0.526078
# epoch:  14,    lr=0.000800,    loss=0.636946,    train_acc=0.743293,    eval_loss=1.561396,    eval_acc=0.490669
# epoch:  15,    lr=0.000778,    loss=0.567230,    train_acc=0.774125,    eval_loss=1.560606,    eval_acc=0.538093
# Test accuray: 0.59243
# epoch:  16,    lr=0.000756,    loss=0.494251,    train_acc=0.802704,    eval_loss=1.898377,    eval_acc=0.471476
# epoch:  17,    lr=0.000733,    loss=0.419053,    train_acc=0.835145,    eval_loss=1.873676,    eval_acc=0.502579
# epoch:  18,    lr=0.000711,    loss=0.354127,    train_acc=0.861285,    eval_loss=2.203365,    eval_acc=0.487852
# epoch:  19,    lr=0.000689,    loss=0.298141,    train_acc=0.883918,    eval_loss=2.375127,    eval_acc=0.483545
# epoch:  20,    lr=0.000667,    loss=0.246064,    train_acc=0.905660,    eval_loss=2.622566,    eval_acc=0.469084
# Test accuray: 0.5657
# epoch:  21,    lr=0.000644,    loss=0.208095,    train_acc=0.920597,    eval_loss=2.826168,    eval_acc=0.498910
# epoch:  22,    lr=0.000622,    loss=0.174228,    train_acc=0.933698,    eval_loss=2.986015,    eval_acc=0.495135
# epoch:  23,    lr=0.000600,    loss=0.147305,    train_acc=0.945325,    eval_loss=2.954014,    eval_acc=0.483970
# epoch:  24,    lr=0.000578,    loss=0.128941,    train_acc=0.952038,    eval_loss=3.216240,    eval_acc=0.479292
# epoch:  25,    lr=0.000556,    loss=0.110386,    train_acc=0.959328,    eval_loss=3.334461,    eval_acc=0.496943
# Test accuray: 0.59465
# epoch:  26,    lr=0.000533,    loss=0.091893,    train_acc=0.966275,    eval_loss=3.532235,    eval_acc=0.488490
# epoch:  27,    lr=0.000511,    loss=0.080460,    train_acc=0.970734,    eval_loss=3.757958,    eval_acc=0.488330
# epoch:  28,    lr=0.000489,    loss=0.072865,    train_acc=0.974075,    eval_loss=3.938335,    eval_acc=0.494763
# epoch:  29,    lr=0.000467,    loss=0.063582,    train_acc=0.977545,    eval_loss=4.030635,    eval_acc=0.486735
# epoch:  30,    lr=0.000444,    loss=0.054541,    train_acc=0.980764,    eval_loss=4.064731,    eval_acc=0.492052
# Test accuray: 0.58352
# epoch:  31,    lr=0.000422,    loss=0.049124,    train_acc=0.982975,    eval_loss=4.348486,    eval_acc=0.495401
# epoch:  32,    lr=0.000400,    loss=0.044120,    train_acc=0.984418,    eval_loss=4.415212,    eval_acc=0.502685
# epoch:  33,    lr=0.000378,    loss=0.039249,    train_acc=0.986340,    eval_loss=4.456050,    eval_acc=0.502685
# epoch:  34,    lr=0.000356,    loss=0.034756,    train_acc=0.988042,    eval_loss=4.770016,    eval_acc=0.498644
# epoch:  35,    lr=0.000333,    loss=0.029956,    train_acc=0.989737,    eval_loss=4.744481,    eval_acc=0.504599
# Test accuray: 0.5657
# epoch:  36,    lr=0.000311,    loss=0.025582,    train_acc=0.991450,    eval_loss=4.914252,    eval_acc=0.491998
# epoch:  37,    lr=0.000289,    loss=0.022569,    train_acc=0.992513,    eval_loss=5.166309,    eval_acc=0.484715
# epoch:  38,    lr=0.000267,    loss=0.020904,    train_acc=0.992986,    eval_loss=5.220395,    eval_acc=0.485619
# epoch:  39,    lr=0.000244,    loss=0.017958,    train_acc=0.994018,    eval_loss=5.199823,    eval_acc=0.501887
# epoch:  40,    lr=0.000222,    loss=0.014707,    train_acc=0.995240,    eval_loss=5.395093,    eval_acc=0.489606
# Test accuray: 0.57461
# epoch:  41,    lr=0.000200,    loss=0.014233,    train_acc=0.995265,    eval_loss=5.395459,    eval_acc=0.495507
# epoch:  42,    lr=0.000178,    loss=0.010723,    train_acc=0.996493,    eval_loss=5.449131,    eval_acc=0.492849
# epoch:  43,    lr=0.000156,    loss=0.008952,    train_acc=0.997255,    eval_loss=5.670450,    eval_acc=0.504493
# epoch:  44,    lr=0.000133,    loss=0.007880,    train_acc=0.997617,    eval_loss=5.523621,    eval_acc=0.495720
# epoch:  45,    lr=0.000111,    loss=0.006362,    train_acc=0.998305,    eval_loss=5.891938,    eval_acc=0.493806
# Test accuray: 0.56793
# epoch:  46,    lr=0.000089,    loss=0.005558,    train_acc=0.998446,    eval_loss=5.737709,    eval_acc=0.509650
# epoch:  47,    lr=0.000067,    loss=0.004631,    train_acc=0.998630,    eval_loss=5.833349,    eval_acc=0.499814
# epoch:  48,    lr=0.000044,    loss=0.003735,    train_acc=0.998980,    eval_loss=6.031548,    eval_acc=0.497049
# epoch:  49,    lr=0.000022,    loss=0.002908,    train_acc=0.999208,    eval_loss=5.952449,    eval_acc=0.499016
# epoch:  50,    lr=0.000000,    loss=0.002476,    train_acc=0.999398,    eval_loss=5.934552,    eval_acc=0.498697
# 18it [00:00, 175.17it/s]
# Test accuray: 0.57906
# 4041it [00:25, 159.59it/s]
# 449it [00:02, 164.22it/s]
# Start training
# epoch:   1,    lr=0.000200,    loss=1.139794,    train_acc=0.492432,    eval_loss=1.157606,    eval_acc=0.474192
# epoch:   2,    lr=0.000400,    loss=0.997298,    train_acc=0.588071,    eval_loss=1.117960,    eval_acc=0.526088
# epoch:   3,    lr=0.000600,    loss=0.946873,    train_acc=0.614082,    eval_loss=1.132647,    eval_acc=0.518627
# epoch:   4,    lr=0.000800,    loss=0.919900,    train_acc=0.626565,    eval_loss=1.148605,    eval_acc=0.538095
# epoch:   5,    lr=0.001000,    loss=0.902107,    train_acc=0.635209,    eval_loss=1.183619,    eval_acc=0.519917
# Test accuray: 0.55679
# epoch:   6,    lr=0.000978,    loss=0.885648,    train_acc=0.641817,    eval_loss=1.236310,    eval_acc=0.528333
# epoch:   7,    lr=0.000956,    loss=0.870018,    train_acc=0.649098,    eval_loss=1.110236,    eval_acc=0.548193
# epoch:   8,    lr=0.000933,    loss=0.855397,    train_acc=0.656427,    eval_loss=1.119264,    eval_acc=0.562724
# epoch:   9,    lr=0.000911,    loss=0.841798,    train_acc=0.662406,    eval_loss=1.119232,    eval_acc=0.561097
# epoch:  10,    lr=0.000889,    loss=0.826230,    train_acc=0.668892,    eval_loss=1.188719,    eval_acc=0.544210
# Test accuray: 0.57238
# epoch:  11,    lr=0.000867,    loss=0.804170,    train_acc=0.677041,    eval_loss=1.233021,    eval_acc=0.546791
# epoch:  12,    lr=0.000844,    loss=0.775784,    train_acc=0.687109,    eval_loss=1.231506,    eval_acc=0.557058
# epoch:  13,    lr=0.000822,    loss=0.733024,    train_acc=0.704433,    eval_loss=1.251184,    eval_acc=0.551504
# epoch:  14,    lr=0.000800,    loss=0.677090,    train_acc=0.726593,    eval_loss=1.462014,    eval_acc=0.527098
# epoch:  15,    lr=0.000778,    loss=0.612576,    train_acc=0.753167,    eval_loss=1.533189,    eval_acc=0.526425
# Test accuray: 0.57906
# epoch:  16,    lr=0.000756,    loss=0.541850,    train_acc=0.782393,    eval_loss=1.682892,    eval_acc=0.529904
# epoch:  17,    lr=0.000733,    loss=0.474851,    train_acc=0.810055,    eval_loss=1.936072,    eval_acc=0.515092
# epoch:  18,    lr=0.000711,    loss=0.413194,    train_acc=0.836372,    eval_loss=2.188660,    eval_acc=0.508864
# epoch:  19,    lr=0.000689,    loss=0.355302,    train_acc=0.859962,    eval_loss=2.498549,    eval_acc=0.499663
# epoch:  20,    lr=0.000667,    loss=0.311059,    train_acc=0.877604,    eval_loss=2.477636,    eval_acc=0.502637
# Test accuray: 0.60134
# epoch:  21,    lr=0.000644,    loss=0.271538,    train_acc=0.893999,    eval_loss=2.842521,    eval_acc=0.507742
# epoch:  22,    lr=0.000622,    loss=0.232989,    train_acc=0.909435,    eval_loss=3.120247,    eval_acc=0.495848
# epoch:  23,    lr=0.000600,    loss=0.206499,    train_acc=0.920597,    eval_loss=3.167040,    eval_acc=0.481093
# epoch:  24,    lr=0.000578,    loss=0.173506,    train_acc=0.933306,    eval_loss=3.390394,    eval_acc=0.478007
# epoch:  25,    lr=0.000556,    loss=0.153949,    train_acc=0.941425,    eval_loss=3.665736,    eval_acc=0.492987
# Test accuray: 0.59465
# epoch:  26,    lr=0.000533,    loss=0.131692,    train_acc=0.950068,    eval_loss=3.680121,    eval_acc=0.490294
# epoch:  27,    lr=0.000511,    loss=0.118280,    train_acc=0.955393,    eval_loss=3.992579,    eval_acc=0.494951
# epoch:  28,    lr=0.000489,    loss=0.103504,    train_acc=0.962148,    eval_loss=4.086925,    eval_acc=0.498036
# epoch:  29,    lr=0.000467,    loss=0.085925,    train_acc=0.968004,    eval_loss=4.387236,    eval_acc=0.490855
# epoch:  30,    lr=0.000444,    loss=0.080862,    train_acc=0.970492,    eval_loss=4.382511,    eval_acc=0.492594
# Test accuray: 0.57684
# epoch:  31,    lr=0.000422,    loss=0.069382,    train_acc=0.975077,    eval_loss=4.537295,    eval_acc=0.491416
# epoch:  32,    lr=0.000400,    loss=0.061184,    train_acc=0.978097,    eval_loss=4.763203,    eval_acc=0.491921
# epoch:  33,    lr=0.000378,    loss=0.053403,    train_acc=0.981343,    eval_loss=4.862434,    eval_acc=0.495512
# epoch:  34,    lr=0.000356,    loss=0.043873,    train_acc=0.985011,    eval_loss=5.053376,    eval_acc=0.494165
# epoch:  35,    lr=0.000333,    loss=0.040068,    train_acc=0.986129,    eval_loss=4.909621,    eval_acc=0.504601
# Test accuray: 0.59688
# epoch:  36,    lr=0.000311,    loss=0.038440,    train_acc=0.986967,    eval_loss=5.153357,    eval_acc=0.488611
# epoch:  37,    lr=0.000289,    loss=0.030848,    train_acc=0.989638,    eval_loss=5.180157,    eval_acc=0.490126
# epoch:  38,    lr=0.000267,    loss=0.027123,    train_acc=0.990910,    eval_loss=5.331803,    eval_acc=0.503647
# epoch:  39,    lr=0.000244,    loss=0.024082,    train_acc=0.991961,    eval_loss=5.736695,    eval_acc=0.492650
# epoch:  40,    lr=0.000222,    loss=0.019740,    train_acc=0.993661,    eval_loss=5.781184,    eval_acc=0.495007
# Test accuray: 0.59465
# epoch:  41,    lr=0.000200,    loss=0.019613,    train_acc=0.993636,    eval_loss=5.805263,    eval_acc=0.501795
# epoch:  42,    lr=0.000178,    loss=0.016144,    train_acc=0.994877,    eval_loss=6.048453,    eval_acc=0.495736
# epoch:  43,    lr=0.000156,    loss=0.012217,    train_acc=0.996271,    eval_loss=6.179119,    eval_acc=0.500449
# epoch:  44,    lr=0.000133,    loss=0.011397,    train_acc=0.996687,    eval_loss=6.129762,    eval_acc=0.495343
# epoch:  45,    lr=0.000111,    loss=0.009051,    train_acc=0.997396,    eval_loss=6.413185,    eval_acc=0.494053
# Test accuray: 0.59243
# epoch:  46,    lr=0.000089,    loss=0.008024,    train_acc=0.997738,    eval_loss=6.220050,    eval_acc=0.500729
# epoch:  47,    lr=0.000067,    loss=0.006430,    train_acc=0.998270,    eval_loss=6.473756,    eval_acc=0.495343
# epoch:  48,    lr=0.000044,    loss=0.005302,    train_acc=0.998570,    eval_loss=6.524238,    eval_acc=0.497307
# epoch:  49,    lr=0.000022,    loss=0.004299,    train_acc=0.998863,    eval_loss=6.537619,    eval_acc=0.497588
# epoch:  50,    lr=0.000000,    loss=0.003707,    train_acc=0.999132,    eval_loss=6.564004,    eval_acc=0.496129
# 17it [00:00, 166.92it/s]
# Test accuray: 0.60802
# 4041it [00:26, 153.26it/s]
# 449it [00:02, 163.46it/s]
# Start training
# epoch:   1,    lr=0.000200,    loss=1.159949,    train_acc=0.483385,    eval_loss=1.060162,    eval_acc=0.543996
# epoch:   2,    lr=0.000400,    loss=1.010360,    train_acc=0.583969,    eval_loss=1.011778,    eval_acc=0.582567
# ...
# epoch:  19,    lr=0.000689,    loss=0.346288,    train_acc=0.863715,    eval_loss=2.567865,    eval_acc=0.468526
# epoch:  20,    lr=0.000667,    loss=0.289411,    train_acc=0.887134,    eval_loss=2.753752,    eval_acc=0.476268
# Test accuray: 0.54788
# epoch:  21,    lr=0.000644,    loss=0.249782,    train_acc=0.903267,    eval_loss=2.827174,    eval_acc=0.476212
# epoch:  22,    lr=0.000622,    loss=0.209598,    train_acc=0.919503,    eval_loss=3.096464,    eval_acc=0.465777
# epoch:  23,    lr=0.000600,    loss=0.177252,    train_acc=0.933086,    eval_loss=3.262520,    eval_acc=0.482944
# epoch:  24,    lr=0.000578,    loss=0.155338,    train_acc=0.941247,    eval_loss=3.317325,    eval_acc=0.482776
# epoch:  25,    lr=0.000556,    loss=0.130566,    train_acc=0.951939,    eval_loss=3.711441,    eval_acc=0.489565
# Test accuray: 0.55679
# epoch:  26,    lr=0.000533,    loss=0.112312,    train_acc=0.958022,    eval_loss=4.035261,    eval_acc=0.464430
# epoch:  27,    lr=0.000511,    loss=0.100363,    train_acc=0.963572,    eval_loss=4.098820,    eval_acc=0.484010
# epoch:  28,    lr=0.000489,    loss=0.087614,    train_acc=0.968799,    eval_loss=4.295680,    eval_acc=0.468582
# epoch:  29,    lr=0.000467,    loss=0.074811,    train_acc=0.973188,    eval_loss=4.515354,    eval_acc=0.472846
# epoch:  30,    lr=0.000444,    loss=0.061669,    train_acc=0.977822,    eval_loss=4.530226,    eval_acc=0.484515
# Test accuray: 0.56347
# epoch:  31,    lr=0.000422,    loss=0.058669,    train_acc=0.979332,    eval_loss=4.577366,    eval_acc=0.472116
# epoch:  32,    lr=0.000400,    loss=0.051472,    train_acc=0.981789,    eval_loss=4.784826,    eval_acc=0.489621
# epoch:  33,    lr=0.000378,    loss=0.043889,    train_acc=0.984870,    eval_loss=5.098659,    eval_acc=0.480251
# epoch:  34,    lr=0.000356,    loss=0.040736,    train_acc=0.985653,    eval_loss=5.050720,    eval_acc=0.470545
# epoch:  35,    lr=0.000333,    loss=0.035122,    train_acc=0.988018,    eval_loss=5.416879,    eval_acc=0.479915
# Test accuray: 0.57016
# epoch:  36,    lr=0.000311,    loss=0.029428,    train_acc=0.989681,    eval_loss=5.454070,    eval_acc=0.467796
# epoch:  37,    lr=0.000289,    loss=0.027333,    train_acc=0.991014,    eval_loss=5.553371,    eval_acc=0.474473
# epoch:  38,    lr=0.000267,    loss=0.023732,    train_acc=0.992151,    eval_loss=5.485531,    eval_acc=0.485020
# epoch:  39,    lr=0.000244,    loss=0.019301,    train_acc=0.993649,    eval_loss=5.660133,    eval_acc=0.485020
# epoch:  40,    lr=0.000222,    loss=0.018108,    train_acc=0.994199,    eval_loss=5.980266,    eval_acc=0.483562
# Test accuray: 0.56125
# epoch:  41,    lr=0.000200,    loss=0.016704,    train_acc=0.994468,    eval_loss=5.903028,    eval_acc=0.473687
# epoch:  42,    lr=0.000178,    loss=0.012771,    train_acc=0.995764,    eval_loss=5.925663,    eval_acc=0.485974
# epoch:  43,    lr=0.000156,    loss=0.012137,    train_acc=0.995935,    eval_loss=5.975310,    eval_acc=0.479466
# epoch:  44,    lr=0.000133,    loss=0.009411,    train_acc=0.997060,    eval_loss=6.188796,    eval_acc=0.481149
# epoch:  45,    lr=0.000111,    loss=0.008381,    train_acc=0.997439,    eval_loss=6.288783,    eval_acc=0.483730
# Test accuray: 0.57238
# epoch:  46,    lr=0.000089,    loss=0.006601,    train_acc=0.998105,    eval_loss=6.284329,    eval_acc=0.486816
# epoch:  47,    lr=0.000067,    loss=0.005544,    train_acc=0.998368,    eval_loss=6.496351,    eval_acc=0.480588
# epoch:  48,    lr=0.000044,    loss=0.004474,    train_acc=0.998857,    eval_loss=6.413272,    eval_acc=0.482664
# epoch:  49,    lr=0.000022,    loss=0.003836,    train_acc=0.998967,    eval_loss=6.592639,    eval_acc=0.482271
# epoch:  50,    lr=0.000000,    loss=0.003388,    train_acc=0.999114,    eval_loss=6.680468,    eval_acc=0.480139
# 13it [00:00, 127.38it/s]
# Test accuray: 0.57461
# 4041it [00:29, 137.44it/s]
# 449it [00:02, 160.76it/s]
# Start training
# epoch:   1,    lr=0.000200,    loss=1.129147,    train_acc=0.500917,    eval_loss=1.048761,    eval_acc=0.542522
# epoch:   2,    lr=0.000400,    loss=0.990143,    train_acc=0.591836,    eval_loss=0.998643,    eval_acc=0.586577
# epoch:   3,    lr=0.000600,    loss=0.948823,    train_acc=0.612856,    eval_loss=1.007501,    eval_acc=0.586046
# epoch:   4,    lr=0.000800,    loss=0.919298,    train_acc=0.627770,    eval_loss=0.960853,    eval_acc=0.617363
# epoch:   5,    lr=0.001000,    loss=0.899950,    train_acc=0.636294,    eval_loss=0.987752,    eval_acc=0.598726
# Test accuray: 0.64588
# epoch:   6,    lr=0.000978,    loss=0.883561,    train_acc=0.645655,    eval_loss=0.972180,    eval_acc=0.604270
# epoch:   7,    lr=0.000956,    loss=0.869533,    train_acc=0.651250,    eval_loss=1.003222,    eval_acc=0.589290
# epoch:   8,    lr=0.000933,    loss=0.854317,    train_acc=0.657398,    eval_loss=1.054475,    eval_acc=0.581623
# epoch:   9,    lr=0.000911,    loss=0.842359,    train_acc=0.661590,    eval_loss=1.014132,    eval_acc=0.590057
# epoch:  10,    lr=0.000889,    loss=0.824777,    train_acc=0.669573,    eval_loss=1.013404,    eval_acc=0.586872
# Test accuray: 0.63474
# epoch:  11,    lr=0.000867,    loss=0.805611,    train_acc=0.676340,    eval_loss=1.043234,    eval_acc=0.594244
# epoch:  12,    lr=0.000844,    loss=0.778061,    train_acc=0.686577,    eval_loss=1.037324,    eval_acc=0.589231
# epoch:  13,    lr=0.000822,    loss=0.734746,    train_acc=0.705136,    eval_loss=1.099330,    eval_acc=0.571302
# epoch:  14,    lr=0.000800,    loss=0.679337,    train_acc=0.726799,    eval_loss=1.206311,    eval_acc=0.560510
# epoch:  15,    lr=0.000778,    loss=0.609732,    train_acc=0.756081,    eval_loss=1.268907,    eval_acc=0.560333
# Test accuray: 0.63474
# epoch:  16,    lr=0.000756,    loss=0.540499,    train_acc=0.784707,    eval_loss=1.410331,    eval_acc=0.544409
# epoch:  17,    lr=0.000733,    loss=0.468379,    train_acc=0.814511,    eval_loss=1.607234,    eval_acc=0.546827
# epoch:  18,    lr=0.000711,    loss=0.401290,    train_acc=0.841739,    eval_loss=1.706355,    eval_acc=0.536801
# epoch:  19,    lr=0.000689,    loss=0.343981,    train_acc=0.865614,    eval_loss=1.806963,    eval_acc=0.541283
# epoch:  20,    lr=0.000667,    loss=0.292441,    train_acc=0.885091,    eval_loss=2.187859,    eval_acc=0.508375
# Test accuray: 0.59243
# epoch:  21,    lr=0.000644,    loss=0.247441,    train_acc=0.904027,    eval_loss=2.386561,    eval_acc=0.530491
# epoch:  22,    lr=0.000622,    loss=0.211946,    train_acc=0.918661,    eval_loss=2.429248,    eval_acc=0.532142
# epoch:  23,    lr=0.000600,    loss=0.182832,    train_acc=0.930222,    eval_loss=2.772908,    eval_acc=0.526067
# epoch:  24,    lr=0.000578,    loss=0.155511,    train_acc=0.940689,    eval_loss=2.886943,    eval_acc=0.532968
# epoch:  25,    lr=0.000556,    loss=0.132669,    train_acc=0.950270,    eval_loss=2.927989,    eval_acc=0.520524
# Test accuray: 0.62361
# epoch:  26,    lr=0.000533,    loss=0.117152,    train_acc=0.956849,    eval_loss=3.253343,    eval_acc=0.530078
# epoch:  27,    lr=0.000511,    loss=0.102315,    train_acc=0.962638,    eval_loss=3.341328,    eval_acc=0.522352
# epoch:  28,    lr=0.000489,    loss=0.085953,    train_acc=0.968173,    eval_loss=3.617585,    eval_acc=0.516513
# epoch:  29,    lr=0.000467,    loss=0.077722,    train_acc=0.972553,    eval_loss=3.644995,    eval_acc=0.521998
# epoch:  30,    lr=0.000444,    loss=0.065971,    train_acc=0.976654,    eval_loss=3.867644,    eval_acc=0.525360
# Test accuray: 0.60802
# epoch:  31,    lr=0.000422,    loss=0.058726,    train_acc=0.979217,    eval_loss=3.853455,    eval_acc=0.526244
# epoch:  32,    lr=0.000400,    loss=0.050886,    train_acc=0.982237,    eval_loss=3.975243,    eval_acc=0.527247
# epoch:  33,    lr=0.000378,    loss=0.044767,    train_acc=0.983986,    eval_loss=3.999855,    eval_acc=0.534029
# epoch:  34,    lr=0.000356,    loss=0.041084,    train_acc=0.985967,    eval_loss=4.082426,    eval_acc=0.529370
# epoch:  35,    lr=0.000333,    loss=0.033008,    train_acc=0.988749,    eval_loss=4.390287,    eval_acc=0.519049
# Test accuray: 0.6147
# epoch:  36,    lr=0.000311,    loss=0.031528,    train_acc=0.989454,    eval_loss=4.437626,    eval_acc=0.521055
# epoch:  37,    lr=0.000289,    loss=0.028397,    train_acc=0.990310,    eval_loss=4.558421,    eval_acc=0.530137
# epoch:  38,    lr=0.000267,    loss=0.023558,    train_acc=0.992109,    eval_loss=4.672902,    eval_acc=0.527247
# epoch:  39,    lr=0.000244,    loss=0.021547,    train_acc=0.992971,    eval_loss=4.754159,    eval_acc=0.522942
# epoch:  40,    lr=0.000222,    loss=0.018092,    train_acc=0.994095,    eval_loss=5.023482,    eval_acc=0.528073
# Test accuray: 0.61915
# epoch:  41,    lr=0.000200,    loss=0.016069,    train_acc=0.994739,    eval_loss=5.005848,    eval_acc=0.539219
# epoch:  42,    lr=0.000178,    loss=0.014691,    train_acc=0.995164,    eval_loss=5.106787,    eval_acc=0.529724
# epoch:  43,    lr=0.000156,    loss=0.010588,    train_acc=0.996744,    eval_loss=5.217107,    eval_acc=0.530373
# epoch:  44,    lr=0.000133,    loss=0.010184,    train_acc=0.997060,    eval_loss=5.280457,    eval_acc=0.532968
# epoch:  45,    lr=0.000111,    loss=0.007513,    train_acc=0.997819,    eval_loss=5.399492,    eval_acc=0.528368
# Test accuray: 0.61693
# epoch:  46,    lr=0.000089,    loss=0.007018,    train_acc=0.997977,    eval_loss=5.353961,    eval_acc=0.530078
# epoch:  47,    lr=0.000067,    loss=0.005452,    train_acc=0.998481,    eval_loss=5.559249,    eval_acc=0.535150
# epoch:  48,    lr=0.000044,    loss=0.004485,    train_acc=0.998834,    eval_loss=5.545628,    eval_acc=0.533439
# epoch:  49,    lr=0.000022,    loss=0.003653,    train_acc=0.999071,    eval_loss=5.715155,    eval_acc=0.534029
# epoch:  50,    lr=0.000000,    loss=0.003376,    train_acc=0.999137,    eval_loss=5.623545,    eval_acc=0.534265
# 18it [00:00, 175.68it/s]
# Test accuray: 0.61024
# 4041it [00:26, 152.21it/s]
# 449it [00:02, 161.13it/s]
# Start training
# epoch:   1,    lr=0.000200,    loss=1.125520,    train_acc=0.500184,    eval_loss=1.126347,    eval_acc=0.528246
# epoch:   2,    lr=0.000400,    loss=0.989149,    train_acc=0.594161,    eval_loss=1.145453,    eval_acc=0.553721
# epoch:   3,    lr=0.000600,    loss=0.942636,    train_acc=0.618543,    eval_loss=1.076926,    eval_acc=0.560239
# epoch:   4,    lr=0.000800,    loss=0.914368,    train_acc=0.632996,    eval_loss=1.045484,    eval_acc=0.565345
# epoch:   5,    lr=0.001000,    loss=0.891412,    train_acc=0.645114,    eval_loss=1.101681,    eval_acc=0.555894
# Test accuray: 0.63697
# epoch:   6,    lr=0.000978,    loss=0.875303,    train_acc=0.652442,    eval_loss=1.284294,    eval_acc=0.504834
# epoch:   7,    lr=0.000956,    loss=0.859439,    train_acc=0.658648,    eval_loss=1.131919,    eval_acc=0.558501
# epoch:   8,    lr=0.000933,    loss=0.844609,    train_acc=0.665835,    eval_loss=1.104000,    eval_acc=0.566105
# epoch:   9,    lr=0.000911,    loss=0.831736,    train_acc=0.669845,    eval_loss=1.099026,    eval_acc=0.562955
# epoch:  10,    lr=0.000889,    loss=0.813466,    train_acc=0.678026,    eval_loss=1.214156,    eval_acc=0.543455
# Test accuray: 0.65033
# epoch:  11,    lr=0.000867,    loss=0.792504,    train_acc=0.685366,    eval_loss=1.236485,    eval_acc=0.541391
# epoch:  12,    lr=0.000844,    loss=0.760868,    train_acc=0.698734,    eval_loss=1.316275,    eval_acc=0.535144
# epoch:  13,    lr=0.000822,    loss=0.717861,    train_acc=0.715285,    eval_loss=1.280928,    eval_acc=0.539598
# epoch:  14,    lr=0.000800,    loss=0.659217,    train_acc=0.739054,    eval_loss=1.414021,    eval_acc=0.537534
# epoch:  15,    lr=0.000778,    loss=0.590508,    train_acc=0.766306,    eval_loss=1.610396,    eval_acc=0.519555
# Test accuray: 0.64365
# epoch:  16,    lr=0.000756,    loss=0.519630,    train_acc=0.794949,    eval_loss=1.745362,    eval_acc=0.534818
# epoch:  17,    lr=0.000733,    loss=0.456606,    train_acc=0.819571,    eval_loss=1.852815,    eval_acc=0.527159
# epoch:  18,    lr=0.000711,    loss=0.394458,    train_acc=0.843695,    eval_loss=2.062133,    eval_acc=0.521619
# epoch:  19,    lr=0.000689,    loss=0.339268,    train_acc=0.866899,    eval_loss=2.386708,    eval_acc=0.525312
# epoch:  20,    lr=0.000667,    loss=0.292922,    train_acc=0.885216,    eval_loss=2.616531,    eval_acc=0.521564
# Test accuray: 0.65033
# epoch:  21,    lr=0.000644,    loss=0.247888,    train_acc=0.903374,    eval_loss=2.794232,    eval_acc=0.498045
# epoch:  22,    lr=0.000622,    loss=0.215934,    train_acc=0.916374,    eval_loss=3.009795,    eval_acc=0.499511
# epoch:  23,    lr=0.000600,    loss=0.187118,    train_acc=0.928148,    eval_loss=3.158764,    eval_acc=0.508202
# epoch:  24,    lr=0.000578,    loss=0.163715,    train_acc=0.937206,    eval_loss=3.342313,    eval_acc=0.511896
# epoch:  25,    lr=0.000556,    loss=0.136756,    train_acc=0.948231,    eval_loss=3.617567,    eval_acc=0.499728
# Test accuray: 0.63252
# epoch:  26,    lr=0.000533,    loss=0.120095,    train_acc=0.955676,    eval_loss=3.745452,    eval_acc=0.504671
# epoch:  27,    lr=0.000511,    loss=0.101620,    train_acc=0.962655,    eval_loss=3.751959,    eval_acc=0.504400
# epoch:  28,    lr=0.000489,    loss=0.088385,    train_acc=0.967750,    eval_loss=4.012305,    eval_acc=0.514938
# epoch:  29,    lr=0.000467,    loss=0.077573,    train_acc=0.971779,    eval_loss=4.207428,    eval_acc=0.497610
# epoch:  30,    lr=0.000444,    loss=0.071342,    train_acc=0.974612,    eval_loss=4.161952,    eval_acc=0.501304
# Test accuray: 0.62584
# epoch:  31,    lr=0.000422,    loss=0.057368,    train_acc=0.979451,    eval_loss=4.523422,    eval_acc=0.508365
# epoch:  32,    lr=0.000400,    loss=0.053064,    train_acc=0.981413,    eval_loss=4.530381,    eval_acc=0.507279
# epoch:  33,    lr=0.000378,    loss=0.044338,    train_acc=0.984504,    eval_loss=4.853621,    eval_acc=0.502770
# epoch:  34,    lr=0.000356,    loss=0.042043,    train_acc=0.985467,    eval_loss=4.769717,    eval_acc=0.517002
# epoch:  35,    lr=0.000333,    loss=0.035750,    train_acc=0.987827,    eval_loss=4.952146,    eval_acc=0.505703
# Test accuray: 0.62806
# epoch:  36,    lr=0.000311,    loss=0.030106,    train_acc=0.989845,    eval_loss=5.080839,    eval_acc=0.506355
# epoch:  37,    lr=0.000289,    loss=0.027177,    train_acc=0.990912,    eval_loss=5.266298,    eval_acc=0.514231
# epoch:  38,    lr=0.000267,    loss=0.022717,    train_acc=0.992040,    eval_loss=5.358213,    eval_acc=0.512493
# epoch:  39,    lr=0.000244,    loss=0.021614,    train_acc=0.993021,    eval_loss=5.563715,    eval_acc=0.514938
# epoch:  40,    lr=0.000222,    loss=0.016909,    train_acc=0.994432,    eval_loss=5.650099,    eval_acc=0.504400
# Test accuray: 0.6392
# epoch:  41,    lr=0.000200,    loss=0.014673,    train_acc=0.995340,    eval_loss=5.649903,    eval_acc=0.514340
# epoch:  42,    lr=0.000178,    loss=0.013194,    train_acc=0.995842,    eval_loss=5.721357,    eval_acc=0.507985
# epoch:  43,    lr=0.000156,    loss=0.009903,    train_acc=0.996866,    eval_loss=5.757128,    eval_acc=0.512113
# epoch:  44,    lr=0.000133,    loss=0.010228,    train_acc=0.996873,    eval_loss=6.007143,    eval_acc=0.503476
# epoch:  45,    lr=0.000111,    loss=0.007739,    train_acc=0.997725,    eval_loss=6.078851,    eval_acc=0.508256
# Test accuray: 0.63697
# epoch:  46,    lr=0.000089,    loss=0.005852,    train_acc=0.998301,    eval_loss=6.158581,    eval_acc=0.513743
# epoch:  47,    lr=0.000067,    loss=0.005357,    train_acc=0.998430,    eval_loss=6.197421,    eval_acc=0.514775
# epoch:  48,    lr=0.000044,    loss=0.003622,    train_acc=0.999240,    eval_loss=6.247822,    eval_acc=0.514557
# epoch:  49,    lr=0.000022,    loss=0.003395,    train_acc=0.999154,    eval_loss=6.318490,    eval_acc=0.509397
# epoch:  50,    lr=0.000000,    loss=0.003091,    train_acc=0.999227,    eval_loss=6.356540,    eval_acc=0.511678
# Test accuray: 0.6392
# conv_dim: 1d 	with_focus_attn: False
# Test accuray: [0.6080178173719376, 0.6347438752783965, 0.6191536748329621, 0.6815144766146993, 0.6035634743875279, 0.5835189309576837, 0.5902004454342984, 0.5746102449888641, 0.6458797327394209, 0.6503340757238307]

# %%
with_focus_attn = [0.6146993318485523, 0.6035634743875279, 0.6169265033407573, 
                   0.6948775055679287, 0.6169265033407573, 0.5991091314031181, 
                   0.5946547884187082, 0.6080178173719376, 0.6391982182628062, 0.6592427616926503]
without_focus_attn = [0.6080178173719376, 0.6347438752783965, 0.6191536748329621, 
                      0.6815144766146993, 0.6035634743875279, 0.5835189309576837, 
                      0.5902004454342984, 0.5746102449888641, 0.6458797327394209, 0.6503340757238307]

# %%
print('with_focus_attn:', sum(with_focus_attn) / 10)
print('without_focus_attn:', sum(without_focus_attn) / 10)
# Out:
# with_focus_attn: 0.6247216035634744
# without_focus_attn: 0.6191536748329621

# %%
# 0.70824

# %%
with_focus_attn = [0.6414253897550112, 0.6280623608017817, 0.6169265033407573, 
                   0.6904231625835189, 0.6325167037861915, 0.6458797327394209, 
                   0.6035634743875279, 0.5991091314031181, 0.6614699331848553, 0.6503340757238307]

without_focus_attn = [0.6191536748329621, 0.6080178173719376, 0.6347438752783965, 
                      0.6859688195991092, 0.6302895322939867, 0.6057906458797327, 
                      0.6035634743875279, 0.6102449888641426, 0.6592427616926503, 0.6525612472160356]

# %%
print('with_focus_attn:', sum(with_focus_attn) / 10)
print('without_focus_attn:', sum(without_focus_attn) / 10)
# Out:
# with_focus_attn: 0.6369710467706013
# without_focus_attn: 0.6309576837416481

# %%
for with_focus_attn in focus_attn_list:
    cv_eval = []
    #with_focus_attn = True if(with_focus_attn == 'true') else False
    for train_index, eval_index in skf.split(df['sample_name'], df['sample_label']):
        conv_dim = '1d'
        checkpoint = ''
        hidden_size = 128
        num_layers = 2
        bidirectional = 'true'

        batch_size = 256
        num_epochs = 50
        learning_rate = 0.001

        use_warmup = 'true'
        data_dir = './wav_data/pretrain/IEMOCAP_sub/'
        multi_task = 'false'
        augmentation = 'false'
        
        save_checkpoint_steps = 5
        output_dir = './model'
        
        bidirectional = True if(bidirectional == 'true') else False
        n_mfcc = 40 if(conv_dim == '1d') else 128

        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        
        train_samples, eval_samples = df['sample_name'][train_index], df['sample_name'][eval_index]
        train_label, eval_label = df['sample_label'][train_index], df['sample_label'][eval_index]
        
        train_samples = [data_dir + train_sample + '.wav' for train_sample in train_samples]
        eval_samples = [data_dir + eval_sample + '.wav' for eval_sample in eval_samples]

        y_train = np.array(train_label)
        y_eval = np.array(eval_label)

        if(multi_task == 'true'):
            speaker = np.array(list(map(lambda x: int(x.split('/')[-1].split('-')[-1].split('.')[0]), sample_datas)))
            y_gender = np.array(list(map(lambda x: 1 if x % 2 ==0 else 0, speaker)))

            y_g_train = y_gender[train_idx]
            y_g_eval = y_gender[eval_idx]

        X_train, y_train = convert_spectrograms(train_samples, conv_dim=conv_dim, sr=16000, labels=y_train)
        X_eval, y_eval = convert_spectrograms(eval_samples, conv_dim=conv_dim, sr=16000, labels=y_eval)

        if(augmentation == 'true'):
            X_train_flip = X_train[:, :, :, ::-1]
            y_train_flip = y_train.copy()

            X_train = np.concatenate((X_train, X_train_flip), axis=0)
            y_train = np.concatenate((y_train, y_train_flip), axis=0)

        X_train, y_train = convert_tensor(X_train, y_train)
        X_eval, y_eval = convert_tensor(X_eval, y_eval)

        y_train = y_train.long()
        y_eval = y_eval.long()

        if(multi_task == 'true'):
            _, y_g_train = convert_spectrograms(train_samples, conv_dim=conv_dim, sr=16000, labels=y_g_train)
            _, y_g_eval = convert_spectrograms(eval_samples, conv_dim=conv_dim, sr=16000, labels=y_g_eval)

            if(augmentation == 'true'):
                y_g_train_flip = y_g_train.copy()
                y_g_train = np.concatenate((y_g_train, y_g_train_flip))

            y_g_train = torch.tensor(y_g_train).float()
            y_g_eval = torch.tensor(y_g_eval).float()

            y_g_train = y_g_train.unsqueeze(-1)
            y_g_eval = y_g_eval.unsqueeze(-1)

        if(multi_task == 'true'):
            train_ds = TensorDataset(X_train, y_train, y_g_train)
            eval_ds = TensorDataset(X_eval, y_eval, y_g_eval)
        else:
            train_ds = TensorDataset(X_train, y_train)
            eval_ds = TensorDataset(X_eval, y_eval)

        train_dataloader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=0, drop_last=True)
        eval_dataloader = DataLoader(eval_ds, batch_size=batch_size, num_workers=0)

        model = CLDNN(conv_dim=conv_dim, checkpoint=checkpoint, hidden_size=hidden_size,
                      num_layers=num_layers, bidirectional=bidirectional,
                      with_focus_attn=with_focus_attn).to(device)

        if(multi_task == 'true'):
            model_g = CLDNN_G(conv_dim=conv_dim, checkpoint=checkpoint, hidden_size=hidden_size,
                                num_layers=num_layers, bidirectional=bidirectional,
                                with_focus_attn=with_focus_attn).to(device)

        if(multi_task == 'true'):
            loss_func = nn.CrossEntropyLoss()
            loss_func_g = nn.BCELoss()
            optimizer = optim.Adam(list(model.parameters()) + list(model_g.parameters()), lr=learning_rate)
        else:
            loss_func = nn.CrossEntropyLoss()
            optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        if(use_warmup == 'true'):
            t_total = len(train_dataloader) // 1 * num_epochs
            opt_scheduler = WarmupLinearSchedule(optimizer, warmup_steps=t_total * 0.1, t_total=t_total)

        eval_acc = train(train_dataloader, eval_dataloader, num_epochs)
        cv_eval.append(eval_acc)

    print('conv_dim:', conv_dim, '\twith_focus_attn:', with_focus_attn)
    print('Test accuray:', cv_eval)
    print()
# Out:
# 4041it [00:25, 158.41it/s]
# 449it [00:03, 146.35it/s]
# Start training
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# glo torch.Size([256, 1, 8])
# c_1 torch.Size([256, 50, 8])
# c_2 torch.Size([256, 4, 50, 2])
# up torch.Size([4, 1, 2])
# p torch.Size([256, 4, 50, 2])
# uz torch.Size([4, 1, 2])
# z torch.Size([256, 4, 50, 2])
# P torch.Size([256, 4, 50])
# Z torch.Size([256, 4, 50])
# j torch.Size([1, 1, 1, 50])
# G torch.Size([256, 4, 50, 50])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-10218bca7db8> in <module>
#     103             opt_scheduler = WarmupLinearSchedule(optimizer, warmup_steps=t_total * 0.1, t_total=t_total)
#     104
# --> 105         eval_acc = train(train_dataloader, eval_dataloader, num_epochs)
#     106         cv_eval.append(eval_acc)
#     107
#
# <ipython-input-5-5cc40949aeb3> in train(train_dataloader, eval_dataloader, epochs)
#      77
#      78                 loss = loss_func(outputs, y_batch)
# ---> 79                 loss.backward()
#      80
#      81                 optimizer.step()
#
# ~/.local/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     183                 products. Defaults to ``False``.
#     184         """
# --> 185         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     186
#     187     def register_hook(self, hook):
#
# ~/.local/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     125     Variable._execution_engine.run_backward(
#     126         tensors, grad_tensors, retain_graph, create_graph,
# --> 127         allow_unreachable=True)  # allow_unreachable flag
#     128
#     129
#
# KeyboardInterrupt:

# %%
with_focus_attn
# Out:
# False

# %%
for with_focus_attn in focus_attn_list:
    print(with_focus_attn)
# Out:
# True
# False

# %%
# window_size 25ms, hop_size 10ms
for conv_dim in conv_dim_list:
    for augmentation in augmentation_list:
        for with_focus_attn in focus_attn_list:
            for multi_task in multi_task_list:
                #conv_dim = '1d'
                checkpoint = './output/aae_' + conv_dim + '_step_500.pt'
                hidden_size = 128
                num_layers = 2
                bidirectional = 'true'
                #with_focus_attn = 'false'

                batch_size = 128
                num_epochs = 300
                learning_rate = 0.0001

                use_warmup = 'true'
                data_dir = './wav_data/pretrain/RAVDESS_resample/'
                #multi_task = 'false'
                #augmentation = 'true'

                bidirectional = True if(bidirectional == 'true') else False
                #with_focus_attn = True if(with_focus_attn == 'true') else False
                n_mfcc = 40 if(conv_dim == '1d') else 128

                device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

                sample_datas = glob.glob(os.path.join(data_dir, '**', '*wav'), recursive=True)
                sample_datas = sorted(sample_datas)

                acc_list = []
                for i in range(5):
                    np.random.seed(10 * i + 3)
                    idx = np.random.permutation(len(sample_datas))
                    train_idx = idx[:int(len(sample_datas)*0.75)]
                    eval_idx = idx[int(len(sample_datas)*0.75):]

                    train_samples = list(np.array(sample_datas)[train_idx])
                    eval_samples = list(np.array(sample_datas)[eval_idx])

                    y = np.array(list(map(lambda x: int(x.split('/')[-1].split('-')[2]) - 1, sample_datas)))
                    y_train = y[train_idx]
                    y_eval = y[eval_idx]

                    if(multi_task == 'true'):
                        speaker = np.array(list(map(lambda x: int(x.split('/')[-1].split('-')[-1].split('.')[0]), sample_datas)))
                        y_gender = np.array(list(map(lambda x: 1 if x % 2 ==0 else 0, speaker)))

                        y_g_train = y_gender[train_idx]
                        y_g_eval = y_gender[eval_idx]

                    X_train, y_train = convert_spectrograms(train_samples, conv_dim=conv_dim, sr=16000, labels=y_train)
                    X_eval, y_eval = convert_spectrograms(eval_samples, conv_dim=conv_dim, sr=16000, labels=y_eval)

                    if(augmentation == 'true'):
                        X_train_flip = X_train[:, :, :, ::-1]
                        y_train_flip = y_train.copy()

                        X_train = np.concatenate((X_train, X_train_flip), axis=0)
                        y_train = np.concatenate((y_train, y_train_flip), axis=0)
                    
                    X_train, y_train = convert_tensor(X_train, y_train)
                    X_eval, y_eval = convert_tensor(X_eval, y_eval)

                    y_train = y_train.long()
                    y_eval = y_eval.long()

                    if(multi_task == 'true'):
                        _, y_g_train = convert_spectrograms(train_samples, conv_dim=conv_dim, sr=16000, labels=y_g_train)
                        _, y_g_eval = convert_spectrograms(eval_samples, conv_dim=conv_dim, sr=16000, labels=y_g_eval)

                        if(augmentation == 'true'):
                            y_g_train_flip = y_g_train.copy()
                            y_g_train = np.concatenate((y_g_train, y_g_train_flip))
                        
                        y_g_train = torch.tensor(y_g_train).float()
                        y_g_eval = torch.tensor(y_g_eval).float()

                        y_g_train = y_g_train.unsqueeze(-1)
                        y_g_eval = y_g_eval.unsqueeze(-1)

                    if(multi_task == 'true'):
                        train_ds = TensorDataset(X_train, y_train, y_g_train)
                        eval_ds = TensorDataset(X_eval, y_eval, y_g_eval)
                    else:
                        train_ds = TensorDataset(X_train, y_train)
                        eval_ds = TensorDataset(X_eval, y_eval)

                    train_dataloader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=0, drop_last=True)
                    eval_dataloader = DataLoader(eval_ds, batch_size=batch_size, num_workers=0, drop_last=True)

                    model = CLDNN(conv_dim=conv_dim, checkpoint=checkpoint, hidden_size=hidden_size,
                                  num_layers=num_layers, bidirectional=bidirectional,
                                  with_focus_attn=with_focus_attn).to(device)

                    if(multi_task == 'true'):
                        model_g = CLDNN_G(conv_dim=conv_dim, checkpoint=checkpoint, hidden_size=hidden_size,
                                            num_layers=num_layers, bidirectional=bidirectional,
                                            with_focus_attn=with_focus_attn).to(device)

                    if(multi_task == 'true'):
                        loss_func = nn.CrossEntropyLoss()
                        loss_func_g = nn.BCELoss()
                        optimizer = optim.Adam(list(model.parameters()) + list(model_g.parameters()), lr=learning_rate)
                    else:
                        loss_func = nn.CrossEntropyLoss()
                        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

                    if(use_warmup == 'true'):
                        t_total = len(train_dataloader) // 1 * num_epochs
                        opt_scheduler = WarmupLinearSchedule(optimizer, warmup_steps=t_total * 0.1, t_total=t_total)

                    train(train_dataloader, eval_dataloader, num_epochs)

                    model.eval()
                    if(multi_task == 'true'):
                        model_g.eval()

                    correct = 0
                    n = 0
                    for i in range(len(eval_samples)):
                        try:
                            X_new = preprocessing(eval_samples[i], method='mfcc', sr=16000, n_mfcc=n_mfcc)
                            X_new = convert_tensor(X_new).to(device)
                            y_new = model(X_new)
                            y_new = torch.argmax(nn.Softmax(dim=-1)(torch.mean(y_new, dim=0)))
                            #y_new = sorted(dict(collections.Counter(torch.argmax(nn.Softmax(dim=-1)(y_new), dim=1).cpu().numpy()))
                            #               .items(), key=(lambda x: x[1]), reverse=True)[0][0]
                            y_new = 1 if (y_new.item() == y[eval_idx][i].item()) else 0
                            correct += y_new
                            n += 1
                        except:
                            pass

                    acc = correct / n
                    acc_list.append(acc)

                acc_mean = sum(acc_list) / 5
                print('conv_dim:', conv_dim, '\taugmentation', augmentation, 
                      '\twith_focus_attn:', with_focus_attn, '\tmulti_task:', multi_task)
                print('Test accuray:', round(acc_mean, 5))
                print()

# %%
for conv_dim in conv_dim_list:
    for augmentation in augmentation_list:
        for with_focus_attn in focus_attn_list:
            for multi_task in multi_task_list:
                #conv_dim = '1d'
                checkpoint = './output/aae_' + conv_dim + '_step_300.pt'
                hidden_size = 128
                num_layers = 2
                bidirectional = 'true'
                #with_focus_attn = 'false'

                batch_size = 128
                num_epochs = 300
                learning_rate = 0.0001

                use_warmup = 'true'
                data_dir = './wav_data/pretrain/RAVDESS_resample/'
                #multi_task = 'false'
                #augmentation = 'true'

                bidirectional = True if(bidirectional == 'true') else False
                #with_focus_attn = True if(with_focus_attn == 'true') else False
                n_mfcc = 40 if(conv_dim == '1d') else 128

                device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

                sample_datas = glob.glob(os.path.join(data_dir, '**', '*wav'), recursive=True)
                sample_datas = sorted(sample_datas)

                acc_list = []
                for i in range(5):
                    np.random.seed(10 * i + 3)
                    idx = np.random.permutation(len(sample_datas))
                    train_idx = idx[:int(len(sample_datas)*0.75)]
                    eval_idx = idx[int(len(sample_datas)*0.75):]

                    train_samples = list(np.array(sample_datas)[train_idx])
                    eval_samples = list(np.array(sample_datas)[eval_idx])

                    y = np.array(list(map(lambda x: int(x.split('/')[-1].split('-')[2]) - 1, sample_datas)))
                    y_train = y[train_idx]
                    y_eval = y[eval_idx]

                    if(multi_task == 'true'):
                        speaker = np.array(list(map(lambda x: int(x.split('/')[-1].split('-')[-1].split('.')[0]), sample_datas)))
                        y_gender = np.array(list(map(lambda x: 1 if x % 2 ==0 else 0, speaker)))

                        y_g_train = y_gender[train_idx]
                        y_g_eval = y_gender[eval_idx]

                    X_train, y_train = convert_spectrograms(train_samples, conv_dim=conv_dim, sr=16000, labels=y_train)
                    X_eval, y_eval = convert_spectrograms(eval_samples, conv_dim=conv_dim, sr=16000, labels=y_eval)

                    if(augmentation == 'true'):
                        X_train_flip = X_train[:, :, :, ::-1]
                        y_train_flip = y_train.copy()

                        X_train = np.concatenate((X_train, X_train_flip), axis=0)
                        y_train = np.concatenate((y_train, y_train_flip), axis=0)
                    
                    X_train, y_train = convert_tensor(X_train, y_train)
                    X_eval, y_eval = convert_tensor(X_eval, y_eval)

                    y_train = y_train.long()
                    y_eval = y_eval.long()

                    if(multi_task == 'true'):
                        _, y_g_train = convert_spectrograms(train_samples, conv_dim=conv_dim, sr=16000, labels=y_g_train)
                        _, y_g_eval = convert_spectrograms(eval_samples, conv_dim=conv_dim, sr=16000, labels=y_g_eval)

                        if(augmentation == 'true'):
                            y_g_train_flip = y_g_train.copy()
                            y_g_train = np.concatenate((y_g_train, y_g_train_flip))
                        
                        y_g_train = torch.tensor(y_g_train).float()
                        y_g_eval = torch.tensor(y_g_eval).float()

                        y_g_train = y_g_train.unsqueeze(-1)
                        y_g_eval = y_g_eval.unsqueeze(-1)

                    if(multi_task == 'true'):
                        train_ds = TensorDataset(X_train, y_train, y_g_train)
                        eval_ds = TensorDataset(X_eval, y_eval, y_g_eval)
                    else:
                        train_ds = TensorDataset(X_train, y_train)
                        eval_ds = TensorDataset(X_eval, y_eval)

                    train_dataloader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=0, drop_last=True)
                    eval_dataloader = DataLoader(eval_ds, batch_size=batch_size, num_workers=0, drop_last=True)

                    model = CLDNN(conv_dim=conv_dim, checkpoint=checkpoint, hidden_size=hidden_size,
                                  num_layers=num_layers, bidirectional=bidirectional,
                                  with_focus_attn=with_focus_attn).to(device)

                    if(multi_task == 'true'):
                        model_g = CLDNN_G(conv_dim=conv_dim, checkpoint=checkpoint, hidden_size=hidden_size,
                                            num_layers=num_layers, bidirectional=bidirectional,
                                            with_focus_attn=with_focus_attn).to(device)

                    if(multi_task == 'true'):
                        loss_func = nn.CrossEntropyLoss()
                        loss_func_g = nn.BCELoss()
                        optimizer = optim.Adam(list(model.parameters()) + list(model_g.parameters()), lr=learning_rate)
                    else:
                        loss_func = nn.CrossEntropyLoss()
                        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

                    if(use_warmup == 'true'):
                        t_total = len(train_dataloader) // 1 * num_epochs
                        opt_scheduler = WarmupLinearSchedule(optimizer, warmup_steps=t_total * 0.1, t_total=t_total)

                    train(train_dataloader, eval_dataloader, num_epochs)

                    model.eval()
                    if(multi_task == 'true'):
                        model_g.eval()

                    correct = 0
                    n = 0
                    for i in range(len(eval_samples)):
                        try:
                            X_new = preprocessing(eval_samples[i], method='mfcc', sr=16000, n_mfcc=n_mfcc)
                            X_new = convert_tensor(X_new).to(device)
                            y_new = model(X_new)
                            y_new = torch.argmax(nn.Softmax(dim=-1)(torch.mean(y_new, dim=0)))
                            #y_new = sorted(dict(collections.Counter(torch.argmax(nn.Softmax(dim=-1)(y_new), dim=1).cpu().numpy()))
                            #               .items(), key=(lambda x: x[1]), reverse=True)[0][0]
                            y_new = 1 if (y_new.item() == y[eval_idx][i].item()) else 0
                            correct += y_new
                            n += 1
                        except:
                            pass

                    acc = correct / n
                    acc_list.append(acc)

                acc_mean = sum(acc_list) / 5
                print('conv_dim:', conv_dim, '\taugmentation', augmentation, 
                      '\twith_focus_attn:', with_focus_attn, '\tmulti_task:', multi_task)
                print('Test accuray:', round(acc_mean, 5))
                print()
